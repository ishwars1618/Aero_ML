# %%
# taken from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

#%matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import torchvision.transforms.v2 as v2transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from PIL import Image
import skimage
from skimage import io, transform

# %% [markdown]
# # Definitions

# %%
batch_size = 32
image_size = 324
model_image_size = 128
workers = 2
rootdir = "/Users/ishwar/Desktop/"
output_dir = "model_output_112925_waugmentation_128x128_t6"
if not os.path.isdir(output_dir):
    os.mkdir(output_dir)

# %%
class Prnt(nn.Module):
    def __init__(self):
        super(Prnt, self).__init__()

    def forward(self, x):
        print(x)
        return x
    
NUM_LANDMARKS = 5

class ImgToHeatmap(nn.Module):
    def __init__(self):
        super(ImgToHeatmap, self).__init__()
        
        self.modules = []

        self.kernelSize = 5 # must be odd

        self.internal = 7
        self.layers = 10

        self.num_landmarks = NUM_LANDMARKS

        self.p_dropout = 0.2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.modules.append(nn.Conv2d(3, self.internal, self.kernelSize, stride=2, \
                                      padding=(self.kernelSize-1)//2))
        for i in range(self.layers):
            self.modules.append(nn.Conv2d(self.internal, self.internal, self.kernelSize, stride=1, \
                                      padding=(self.kernelSize-1)//2))
            self.modules.append(nn.BatchNorm2d(self.internal))
            self.modules.append(nn.ReLU())
            self.modules.append(nn.Dropout(p=self.p_dropout))
            
        self.modules.append(nn.Conv2d(self.internal, self.num_landmarks, self.kernelSize, stride=1, \
                                      padding=(self.kernelSize-1)//2))
        
        self.modules.append(nn.Sigmoid())
        
        self.main = nn.Sequential(*self.modules)

    def forward(self, input):
        z = self.main(input)
        return z

# %%
# Old version
class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Up, self).__init__()

        self.up = nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.kernelSize = 3
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)
        self.conv = nn.Conv2d(out_channels*2, out_channels, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(out_channels)
        self.activation1 = nn.ReLU(True)

    def forward(self, x1, x2):
        x = self.up(x1)
        x = self.batch_norm(x)
        x = self.activation(x)
        #print(f"x.shape {x.shape}")
        x = torch.cat([x, x2], dim=1)
        #print(f"x.shape after merge: {x.shape}")
        x = self.conv(x)
        x = self.batch_norm1(x)
        x = self.activation1(x)
        return x

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Down, self).__init__()

        self.kernelSize = 3
        self.conv = nn.Conv2d(in_channels, in_channels, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm0 = nn.BatchNorm2d(in_channels)
        self.activation0 = nn.ReLU(True)
        self.down = nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)

    def forward(self, x):
        x = self.conv(x)
        x = self.batch_norm0(x)
        x = self.activation0(x)
        x = self.down(x)
        x = self.batch_norm(x)
        x = self.activation(x)
        return x

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.modules = []
        self.kernelSize = 3 # must be odd
        self.num_landmarks = NUM_LANDMARKS
        self.p_dropout = 0.2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.init_conv = nn.Conv2d(3, 8, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        
        # downsizing
        channels = (8, 16)
        self.downsize1 = Down(channels[0], channels[1])

        channels = (16, 32)
        self.downsize2 = Down(channels[0], channels[1])

        channels = (32, 64)
        self.downsize3 = Down(channels[0], channels[1])

        channels = (64, 128)
        self.downsize4 = Down(channels[0], channels[1])

        #upsizing
        channels = (128, 64)
        self.upsize4 = Up(channels[0], channels[1])

        channels = (64, 32)
        self.upsize3 = Up(channels[0], channels[1])

        channels = (32, 16)
        self.upsize2 = Up(channels[0], channels[1])

        channels = (16, 8)
        self.upsize1 = Up(channels[0], channels[1])

        self.final_conv = nn.Conv2d(8, self.num_landmarks, self.kernelSize, stride=1, \
                                    padding=(self.kernelSize-1)//2)
        #self.final_activation = nn.Sigmoid()
        

    def forward(self, input):
        x0 = self.init_conv(input)
        #print(x0.shape)
        #print(torch.mean(torch.std(x0, axis=1)))
        x1 = self.downsize1(x0)
        #print(torch.mean(torch.std(x1, axis=1)))
        #x1 = F.dropout(x1, p=self.p_dropout)
        x2 = self.downsize2(x1)
        #print(torch.mean(torch.std(x2, axis=1)))
        #x2 = F.dropout(x2, p=self.p_dropout)
        x3 = self.downsize3(x2)
        #print(torch.mean(torch.std(x3, axis=1)))
        #x3 = F.dropout(x3, p=self.p_dropout)
        x4 = self.downsize4(x3)
        #print(torch.mean(torch.std(x4, axis=1)))
        #x4 = F.dropout(x4, p=self.p_dropout)
        x = self.upsize4(x4, x3)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize3(x, x2)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize2(x, x1)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize1(x, x0)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.final_conv(x)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = self.final_activation(x)
        #print(torch.mean(torch.std(x, axis=1)))
        return x

# %%
class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Up, self).__init__()

        self.up = nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.kernelSize = 3
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)
        self.conv = nn.Conv2d(out_channels*2, out_channels, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(out_channels)
        self.activation1 = nn.ReLU(True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        self.batch_norm2 = nn.BatchNorm2d(out_channels)
        self.activation2 = nn.ReLU(True)

    def forward(self, x1, x2):
        x = self.up(x1)
        x = self.batch_norm(x)
        x = self.activation(x)
        #print(f"x.shape {x.shape}")
        x = torch.cat([x, x2], dim=1)
        #print(f"x.shape after merge: {x.shape}")
        x = self.conv(x)
        x = self.batch_norm1(x)
        x = self.activation1(x)
        return x

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Down, self).__init__()

        self.kernelSize = 3
        self.conv = nn.Conv2d(in_channels, in_channels, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm0 = nn.BatchNorm2d(in_channels)
        self.activation0 = nn.ReLU(True)
        self.conv1 = nn.Conv2d(in_channels, in_channels, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(in_channels)
        self.activation1 = nn.ReLU(True)
        self.down = nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)

    def forward(self, x):
        x = self.conv(x)
        x = self.batch_norm0(x)
        x = self.activation0(x)
        x = self.down(x)
        x = self.batch_norm(x)
        x = self.activation(x)
        return x

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.modules = []
        self.kernelSize = 3 # must be odd
        self.num_landmarks = NUM_LANDMARKS
        self.p_dropout = 0.2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.init_conv = nn.Conv2d(3, 8, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        
        # downsizing
        channels = (8, 16)
        self.downsize1 = Down(channels[0], channels[1])

        channels = (16, 32)
        self.downsize2 = Down(channels[0], channels[1])

        channels = (32, 64)
        self.downsize3 = Down(channels[0], channels[1])

        channels = (64, 128)
        self.downsize4 = Down(channels[0], channels[1])

        self.inter_conv1 = nn.Conv2d(channels[1], channels[1]//16, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(channels[1]//16)
        self.activation1 = nn.ReLU(True)
        self.inter_linear1 = nn.Linear(8*8*128//16, 8*8*128//16, bias=True)
        self.batch_norm1_5 = nn.BatchNorm1d(8*8*128//16)
        self.activation1_5 = nn.ReLU(True)
        self.inter_conv2 = nn.Conv2d(channels[1]//16, channels[1], self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm2 = nn.BatchNorm2d(channels[1])
        self.activation2 = nn.ReLU(True)

        self.inter_conv3 = nn.Conv2d(channels[1]*2, channels[1], self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)

        #upsizing
        channels = (128, 64)
        self.upsize4 = Up(channels[0], channels[1])

        channels = (64, 32)
        self.upsize3 = Up(channels[0], channels[1])

        channels = (32, 16)
        self.upsize2 = Up(channels[0], channels[1])

        channels = (16, 8)
        self.upsize1 = Up(channels[0], channels[1])

        self.final_conv = nn.Conv2d(8, self.num_landmarks, self.kernelSize, stride=1, \
                                    padding=(self.kernelSize-1)//2)
        #self.final_activation = nn.Sigmoid()
        

    def forward(self, input):
        x0 = self.init_conv(input)
        #print(x0.shape)
        #print(torch.mean(torch.std(x0, axis=1)))
        x1 = self.downsize1(x0)
        #print(torch.mean(torch.std(x1, axis=1)))
        #x1 = F.dropout(x1, p=self.p_dropout)
        x2 = self.downsize2(x1)
        #print(torch.mean(torch.std(x2, axis=1)))
        #x2 = F.dropout(x2, p=self.p_dropout)
        x3 = self.downsize3(x2)
        #print(torch.mean(torch.std(x3, axis=1)))
        #x3 = F.dropout(x3, p=self.p_dropout)
        x4 = self.downsize4(x3)
        #print(torch.mean(torch.std(x4, axis=1)))
        #x4 = F.dropout(x4, p=self.p_dropout)


        x5 = self.inter_conv1(x4)
        x5 = self.batch_norm1(x5)
        x5 = self.activation1(x5)
        #print(x5.size())
        x6 = torch.flatten(x5, start_dim=1)
        x6 = self.inter_linear1(x6)
        #print(x6.size())
        x6 = self.batch_norm1_5(x6)
        x6 = self.activation1_5(x6)
        x7 = torch.unflatten(x6, dim=1, sizes=(8, 8, 8))
        #print(x7.size())
        x7 = self.inter_conv2(x7)
        x7 = self.batch_norm2(x7)
        x7 = self.activation2(x7)
        x8 = torch.cat([x7, x4], dim=1)
        x8 = self.inter_conv3(x8)
        #print(x8.size())

        x = self.upsize4(x8, x3)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize3(x, x2)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize2(x, x1)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize1(x, x0)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.final_conv(x)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = self.final_activation(x)
        #print(torch.mean(torch.std(x, axis=1)))
        return x

# %%
class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Up, self).__init__()

        self.up = nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.kernelSize = 3
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)
        self.conv = nn.Conv2d(out_channels*2, out_channels, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(out_channels)
        self.activation1 = nn.ReLU(True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        self.batch_norm2 = nn.BatchNorm2d(out_channels)
        self.activation2 = nn.ReLU(True)

    def forward(self, x1, x2):
        x = self.up(x1)
        x = self.batch_norm(x)
        x = self.activation(x)
        #print(f"x.shape {x.shape}")
        x = torch.cat([x, x2], dim=1)
        #print(f"x.shape after merge: {x.shape}")
        x = self.conv(x)
        x = self.batch_norm1(x)
        x = self.activation1(x)
        x = self.conv2(x)
        x = self.batch_norm2(x)
        x = self.activation2(x)
        return x

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Down, self).__init__()

        self.kernelSize = 3
        self.conv = nn.Conv2d(in_channels, in_channels, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm0 = nn.BatchNorm2d(in_channels)
        self.activation0 = nn.ReLU(True)
        self.conv1 = nn.Conv2d(in_channels, in_channels, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(in_channels)
        self.activation1 = nn.ReLU(True)
        self.down = nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)

    def forward(self, x):
        x = self.conv(x)
        x = self.batch_norm0(x)
        x = self.activation0(x)
        x = self.conv1(x)
        x = self.batch_norm1(x)
        x = self.activation1(x)
        x = self.down(x)
        x = self.batch_norm(x)
        x = self.activation(x)
        return x

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.modules = []
        self.kernelSize = 3 # must be odd
        self.num_landmarks = NUM_LANDMARKS
        self.p_dropout = 0.2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.init_conv = nn.Conv2d(3, 8, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        
        # downsizing
        channels = (8, 16)
        self.downsize1 = Down(channels[0], channels[1])

        channels = (16, 16)
        self.downsize2 = Down(channels[0], channels[1])

        channels = (16, 32)
        self.downsize3 = Down(channels[0], channels[1])

        channels = (32, 32)
        self.downsize4 = Down(channels[0], channels[1])

        channels = (32, 32)
        self.downsize5 = Down(channels[0], channels[1])


        self.inter_conv1 = nn.Conv2d(channels[1], channels[1]//8, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(channels[1]//8)
        self.activation1 = nn.ReLU(True)
        self.inter_linear1 = nn.Linear(4*4*channels[1]//8, 4*4*channels[1]//32, bias=True)
        self.batch_norm1_5 = nn.BatchNorm1d(4*4*channels[1]//32)
        self.activation1_5 = nn.ReLU(True)
        self.inter_linear2 = nn.Linear(4*4*channels[1]//32, 4*4*channels[1]//32, bias=True)
        self.batch_norm2 = nn.BatchNorm1d(4*4*channels[1]//32)
        self.activation2 = nn.ReLU(True)
        self.inter_linear3 = nn.Linear(4*4*channels[1]//32, 4*4*channels[1]//8, bias=True)
        self.batch_norm3 = nn.BatchNorm1d(4*4*channels[1]//8)
        self.activation3 = nn.ReLU(True)
        # self.inter_conv2 = nn.Conv2d(channels[1]//64, channels[1], self.kernelSize, stride=1, \
        #                         padding=(self.kernelSize-1)//2)
        # self.batch_norm2 = nn.BatchNorm2d(channels[1])
        # self.activation2 = nn.ReLU(True)
        self.inter_conv3 = nn.Conv2d(channels[1] + channels[1]//8, channels[1], self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)

        #upsizing
        channels = (32, 32)
        self.upsize5 = Up(channels[0], channels[1])

        channels = (32, 32)
        self.upsize4 = Up(channels[0], channels[1])

        channels = (32, 16)
        self.upsize3 = Up(channels[0], channels[1])

        channels = (16, 16)
        self.upsize2 = Up(channels[0], channels[1])

        channels = (16, 8)
        self.upsize1 = Up(channels[0], channels[1])

        self.final_conv = nn.Conv2d(8, self.num_landmarks, self.kernelSize, stride=1, \
                                    padding=(self.kernelSize-1)//2)
        #self.final_activation = nn.Sigmoid()
        

    def forward(self, input):
        x0 = self.init_conv(input)
        #print(x0.shape)
        #print(torch.mean(torch.std(x0, axis=1)))
        x1 = self.downsize1(x0)
        #print(torch.mean(torch.std(x1, axis=1)))
        x1 = F.dropout(x1, p=self.p_dropout)
        x2 = self.downsize2(x1)
        #print(torch.mean(torch.std(x2, axis=1)))
        x2 = F.dropout(x2, p=self.p_dropout)
        x3 = self.downsize3(x2)
        #print(torch.mean(torch.std(x3, axis=1)))
        x3 = F.dropout(x3, p=self.p_dropout)
        x4 = self.downsize4(x3)
        #print(torch.mean(torch.std(x4, axis=1)))
        x4 = F.dropout(x4, p=self.p_dropout)
        x5 = self.downsize5(x4)


        x6 = self.inter_conv1(x5)
        x6 = self.batch_norm1(x6)
        x6 = self.activation1(x6)
        x6 = F.dropout(x6, p=self.p_dropout)

        f1 = torch.flatten(x6, start_dim=1)
        f1 = self.inter_linear1(f1)
        f1 = self.batch_norm1_5(f1)
        f1 = self.activation1_5(f1)
        f1 = F.dropout(f1, p=self.p_dropout)

        f2 = self.inter_linear2(f1)
        f2 = self.batch_norm2(f2)
        f2 = self.activation2(f2)
        f2 = F.dropout(f2, p=self.p_dropout)


        f3 = self.inter_linear3(f2)
        f3 = self.batch_norm3(f3)
        f3 = self.activation3(f3)
        f3 = F.dropout(f3, p=self.p_dropout)

        x8 = torch.unflatten(f3, dim=1, sizes=(4, 4, 4))
        #print(x7.size())
        # x7 = self.inter_conv2(x7)
        # x7 = self.batch_norm2(x7)
        # x7 = self.activation2(x7)
        x9 = torch.cat([x8, x5], dim=1)
        x9 = self.inter_conv3(x9)
        #print(x8.size())

        x = self.upsize5(x9, x4)
        x = F.dropout(x, p=self.p_dropout)
        x = self.upsize4(x, x3)
        #print(torch.mean(torch.std(x, axis=1)))
        x = F.dropout(x, p=self.p_dropout)
        x = self.upsize3(x, x2)
        #print(torch.mean(torch.std(x, axis=1)))
        x = F.dropout(x, p=self.p_dropout)
        x = self.upsize2(x, x1)
        #print(torch.mean(torch.std(x, axis=1)))
        x = F.dropout(x, p=self.p_dropout)
        x = self.upsize1(x, x0)
        #print(torch.mean(torch.std(x, axis=1)))
        x = F.dropout(x, p=self.p_dropout)
        x = self.final_conv(x)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = self.final_activation(x)
        #print(torch.mean(torch.std(x, axis=1)))
        x = F.sigmoid(x)
        return x

# %%
weight_spread = 0.05
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Linear') != -1:
        #nn.init.normal_(m.weight.data, 0.0, 1/16) # not tried yet
        nn.init.normal_(m.weight.data, 0.0, weight_spread)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, weight_spread)
        nn.init.normal_(m.bias.data, 0.0, weight_spread)
    m = m.to(torch.float32)

clip_value =  5
class WeightConstraint(object):
    def __init__(self):
        pass
    def __call__(self, module):
        # filter the variables to get the ones you want
        if hasattr(module, 'weight'):
            w = module.weight.data
            w = w.clamp(-clip_value, clip_value)
            module.weight.data = w

# %%
# Set random seed for reproducibility
manualSeed = 499
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)

torch.use_deterministic_algorithms(True) # Needed for reproducible resultsStop playing
# Out:
# Random Seed:  499

# %%
MIN_SIGMA = 5
def coord_to_heatmap(coord_array, image_shape, SIGMA_RATIO, device):
    heatmaps = torch.zeros((NUM_LANDMARKS, image_shape[1], image_shape[2]))
    for i in range(NUM_LANDMARKS):
        mu_x, mu_y = coord_array[i][0], coord_array[i][1]   # center (x,y)
        #sigma = sigma_in * model_image_size / image_size
        # calculate average square root distance
        coord_diff = coord_array - torch.stack([coord_array[i],]*NUM_LANDMARKS)
        #print(coord_diff)
        mag = torch.linalg.vector_norm(coord_diff, 2, dim=1)
        mag_remove = torch.cat((mag[:i], mag[i+1:]))
        s = torch.pow(torch.mean(torch.pow(mag_remove + MIN_SIGMA, -1)), -1)
        #print(s)
        sigma = SIGMA_RATIO * s

        ys = torch.arange(image_shape[1], device=device, dtype=torch.float32)
        xs = torch.arange(image_shape[2], device=device, dtype=torch.float32)
        yy, xx = torch.meshgrid(ys, xs, indexing='ij')          # HxW each

        img = torch.exp(-0.5 * ((xx - mu_x)**2 + (yy - mu_y)**2) / (sigma**2))
        #img = torch.sqrt((xx - mu_x)**2 + (yy - mu_y)**2)
        # (optional) normalize to peak (1 / 1 + 1e-3)
        img = img / (img.max() + 1e-5)
        heatmaps[i] = img
    return heatmaps

# %%
SIGMA_RATIO = 0.4
class FramesFromCSV(Dataset):
    def __init__(self, csv_path, images_dir, image_pattern="frame_{frame}.png", transform=None, geo_transform=None, post_geo_transform=None):
        """
        Args:
            csv_path: path to CSV file with header in first row
            images_dir: directory containing frame PNGs
            image_pattern: naming pattern for image files
            transform: optional torchvision transform
        """
        self.images_dir = images_dir
        self.image_pattern = image_pattern
        self.transform = transform
        self.geo_transform = geo_transform
        self.post_geo_transform = post_geo_transform

        # Load CSV into numpy array, skipping header
        self.data = np.loadtxt(csv_path, delimiter=",", skiprows=1)
        # Ensure it's 2D even if only one row
        if self.data.ndim == 1:
            self.data = np.expand_dims(self.data, axis=0)

        self.frame_numbers = self.data[:, 0].astype(int)
        self.points = self.data[:, 1:]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        frame_num = self.frame_numbers[idx]
        coords = self.points[idx]

        # Load image
        img_path = os.path.join(self.images_dir, self.image_pattern.format(frame=frame_num))
        image = Image.open(img_path).convert("RGB")

        # # Reshape coords into N×2 array (x, y)
        coords = coords.reshape(-1, 2)
        coords = torch.tensor(coords, dtype=torch.float32)
        coords = coords * model_image_size/image_size

        if self.transform:
            image = self.transform(image)
        if self.geo_transform:
            image, coords = self.geo_transform(image, coords)
        if self.post_geo_transform:
            image = self.post_geo_transform(image)

        return {
            "image": image,
            "points": coords,
            "heatmaps": coord_to_heatmap(coords, image.shape, SIGMA_RATIO, "cpu"),
            "frame": frame_num
        }

# %%
# ------------ (a) Random noise with p=0.5 -----------------

class RandomAdditiveNoise:
    def __init__(self, p=0.5, mean=0.0, std=0.05):
        self.p = p
        self.mean = mean
        self.std = std

    def __call__(self, x):
        # x: tensor in [0,1], shape (C, H, W)
        if torch.rand(1).item() < self.p:
            noise = torch.randn_like(x) * self.std + self.mean
            x = x + noise
            x = torch.clamp(x, 0.0, 1.0)
        return x

# ------------ (b) Random 3x3 color matrix A -----------------

class RandomColorMatrix:
    """
    Applies x -> A x where A is 3x3 with:
      - rank in {1, 2, 3} (each w.p. 1/3)
      - spectral norm <= max_spectral_norm
    """
    def __init__(self, max_spectral_norm=1.5, min_spectral_norm=0.75):
        self.max_spectral_norm = max_spectral_norm
        self.min_spectral_norm = min_spectral_norm

    def _random_orthonormal(self):
        """Generate a random 3x3 orthonormal matrix via QR."""
        M = torch.randn(3, 3)
        Q, _ = torch.linalg.qr(M)  # Q is orthonormal
        return Q

    def __call__(self, x):
        # x: tensor in [0,1], shape (3, H, W)
        c, h, w = x.shape
        assert c == 3, "RandomColorMatrix expects a 3-channel RGB tensor."

        # Choose rank 1, 2, or 3 with equal probability
        rank = random.choice([1, 2, 3, 3, 3, 3, 3])

        # Random orthonormals U, V
        U = self._random_orthonormal()
        V = self._random_orthonormal()

        # Singular values: only 'rank' non-zero, each ≤ max_spectral_norm
        s = torch.zeros(3)
        nonzero_s = torch.rand(rank)*(self.max_spectral_norm - self.min_spectral_norm) + self.min_spectral_norm  # [min_spectral_norm, max_spectral_norm)
        # Sort descending just for sanity (not required)
        nonzero_s, _ = torch.sort(nonzero_s, descending=True)
        s[:rank] = nonzero_s
        S = torch.diag(s)

        # A = U S V^T; spectral norm = max singular value <= max_spectral_norm
        A = U @ S @ V.T  # shape (3,3)

        # Apply A to each pixel: x_flat is 3 x (H*W)
        x_flat = x.view(3, -1)
        x_transformed = A @ x_flat
        x_out = x_transformed.view(3, h, w)

        # Clamp back to [0,1]
        x_out = torch.clamp(torch.abs(x_out), 0.0, 1.0)
        return x_out

# ------------ (c) Random affine (scale, rotation, shear) ----

# random_affine = transforms.RandomAffine(
#     degrees=(-15, 15),           # rotation range in degrees
#     scale=(0.9, 1.1),            # scaling range
#     shear=(-10, 10),              # shear range in degrees
#     translate=(0.5, 0.5)
# )

# %%
# ---------- Joint compose for (image, points) ----------

class ComposeJoint:
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, img, pts):
        for t in self.transforms:
            img, pts = t(img, pts)
        return img, pts

# # ---------- Resize image + coords -----------------------

# class ResizeWithPoints:
#     def __init__(self, size):
#         """
#         size: (H, W) or int (shorter side)
#         """
#         self.size = size

#     def __call__(self, img, pts):
#         # img.size -> (W, H)
#         old_w, old_h = img.size()

#         img = TF.resize(img, self.size())

#         if isinstance(self.size, tuple):
#             new_h, new_w = self.size()
#         else:
#             # torchvision's int size = shorter side; to keep it simple,
#             # assume you use (H, W) tuple for model_image_size
#             raise ValueError("Use an explicit (H, W) tuple for size")

#         sx = new_w / old_w
#         sy = new_h / old_h

#         scale = torch.tensor([sx, sy], dtype=torch.float32, device=pts.device)
#         pts = pts * scale  # elementwise [x, y] * [sx, sy]
#         return img, pts

# ---------- Random affine image + coords ----------------

class RandomAffineWithPoints:
    """
    Same params as torchvision.transforms.RandomAffine,
    but applied to both image and (N,2) coords.
    """
    def __init__(self, degrees, translate=None, scale=None, shear=None):
        self.degrees = degrees
        self.translate = translate
        self.scale = scale
        self.shear = shear

    def __call__(self, img, pts):
        # img.size is (W, H)
        w, h = img.size()[1:]

        # Sample random params exactly like RandomAffine
        angle, translations, scale, shear = transforms.RandomAffine.get_params(
            self.degrees, self.translate, self.scale, self.shear, (w, h)
        )
        corner_pixel = (img[0, -1, -1].item(), img[1, -1, -1].item(), img[2, -1, -1].item())
        # --- 1) Transform the image ---
        img = TF.affine(
            img,
            angle=angle,
            translate=translations,
            scale=scale,
            shear=shear,
            interpolation = transforms.InterpolationMode.BILINEAR,
            fill=corner_pixel
        )

        # --- 2) Build forward affine matrix for points ---
        # torchvision uses an "inverse" matrix internally. We can get it and invert it.
        center = [w * 0.5, h * 0.5]
        inv_coeffs = TF._get_inverse_affine_matrix(
            center=center,
            angle=angle,
            translate=translations,
            scale=scale,
            shear=shear
        )
        # inv_coeffs = [a, b, c, d, e, f] giving:
        # x_in  = a * x_out + b * y_out + c
        # y_in  = d * x_out + e * y_out + f
        a, b, c, d, e, f = inv_coeffs
        #print(f"{a} {b} {c} {d} {e} {f}")

        M_inv = torch.tensor(
            [[a, b],
             [d, e]],
            dtype=torch.float32,
            device=pts.device,
        )

        # We want forward transform (input -> output) to apply to keypoints
        M = torch.inverse(M_inv)  # 2×2

        # pts: (N,2) in input image coords
        #ones = torch.ones(pts.shape[0], 1, dtype=torch.float32, device=pts.device)
        #hom = torch.cat([pts, ones], dim=1).T  # 3×N

        #pts_out = (M @ hom).T[:, :2]  # back to (N,2)
        translation = torch.tensor([[c, f]]).repeat(pts.size()[0], 1)
        #print("Translation:\n", translation)
        #print("Points:\n", pts)

        pts_tr = pts - translation

        pts_out = (M @ pts_tr.T).T

        return img, pts_out
    
# geom_transform = ComposeJoint([
#     # ResizeWithPoints((model_image_size, model_image_size)),
#     RandomAffineWithPoints(
#         degrees=(-15, 15),
#         translate=(0.5, 0.5),
#         scale=(0.9, 1.1),
#         shear=(-10, 10),
#     ),
# ])

geom_transform = ComposeJoint([
    # ResizeWithPoints((model_image_size, model_image_size)),
    RandomAffineWithPoints(
        degrees=(-180, 180),
        translate=(0.2, 0.2),
        scale=(0.8, 1.4),
        shear=(-40, 40),
    ),
])

# %%
# ------------ Putting it all together in your dataset --------

dataset = FramesFromCSV(
    csv_path="plane_data/labeled_points_mega_grp.csv",
    images_dir="outp",
    image_pattern="frame_{frame}.png",
    transform=transforms.Compose([
        transforms.Resize(model_image_size),  # operates on PIL
        #random_affine,                        # geometric aug (PIL or tensor; works with recent torchvision)
        transforms.ToTensor(),                # -> tensor in [0,1]
        ]),
    geo_transform=geom_transform,
    post_geo_transform=transforms.Compose([RandomColorMatrix(max_spectral_norm=1.5, min_spectral_norm=0.95),
                                           RandomAdditiveNoise(p=0.7, mean=0.0, std=0.025)])
)

# %%
dataset = FramesFromCSV(
    csv_path="plane_data/labeled_points_mega_grp.csv",
    images_dir="outp",
    image_pattern="frame_{frame}.png",
    transform=transforms.Compose([
                               transforms.Resize(model_image_size),
                               transforms.ToTensor(),
                           ])
)

# %%
print(dataset[790]['image'])
# Out:
# tensor([[[0.4375, 0.3928, 0.3786,  ..., 0.3957, 0.4029, 0.3847],
#          [0.3971, 0.4000, 0.4185,  ..., 0.4066, 0.3965, 0.4559],
#          [0.4039, 0.4030, 0.3521,  ..., 0.4227, 0.4295, 0.4135],
#          ...,
#          [0.3780, 0.4204, 0.4290,  ..., 0.4129, 0.4006, 0.3832],
#          [0.3691, 0.3783, 0.3577,  ..., 0.4147, 0.4176, 0.4384],
#          [0.4174, 0.4001, 0.4270,  ..., 0.3961, 0.4093, 0.4407]],
#
#         [[0.8123, 0.8682, 0.7917,  ..., 0.9083, 0.9007, 0.9041],
#          [0.8260, 0.8209, 0.8592,  ..., 0.8994, 0.8884, 0.8973],
#          [0.7920, 0.8317, 0.8330,  ..., 0.9457, 0.8532, 0.9154],
#          ...,
#          [0.8852, 0.8916, 0.8352,  ..., 0.8881, 0.8941, 0.9057],
#          [0.8724, 0.8205, 0.8736,  ..., 0.9294, 0.8454, 0.8666],
#          [0.8690, 0.8990, 0.8652,  ..., 0.9158, 0.9048, 0.8646]],
#
#         [[0.4391, 0.4429, 0.4493,  ..., 0.4932, 0.5140, 0.4938],
#          [0.4311, 0.4191, 0.4046,  ..., 0.4666, 0.3990, 0.4516],
#          [0.4751, 0.4340, 0.4710,  ..., 0.4826, 0.4947, 0.4390],
#          ...,
#          [0.4770, 0.5007, 0.4899,  ..., 0.4645, 0.4893, 0.4702],
#          [0.4420, 0.4474, 0.4526,  ..., 0.4316, 0.5162, 0.4674],
#          [0.5087, 0.5121, 0.4706,  ..., 0.4512, 0.4471, 0.4951]]])

# %%
IMG_IDX = 50
IMG = dataset[IMG_IDX]
plt.imshow(torch.permute(IMG['image'], (1, 2, 0)))
# Unpack points into two lists: xs, ys
xs = [p[0] for p in IMG['points']]
ys = [p[1] for p in IMG['points']]
# Plot points as red circles
plt.scatter(xs, ys, c='red', s=10)  # s = point size

# %%
print(torch.min(IMG['heatmaps']), torch.max(IMG['heatmaps']))
print(IMG['heatmaps'].shape)
plt.imshow(IMG['heatmaps'][2])
plt.colorbar()
# Out:
# tensor(2.0934e-14) tensor(1.0000)
# torch.Size([5, 128, 128])

# %%
print(torch.min(IMG['heatmaps']), torch.max(IMG['heatmaps']))
plt.imshow(torch.sum(IMG['heatmaps'], axis=0))
plt.colorbar()
# Out:
# tensor(2.0934e-14) tensor(1.0000)

# %%
loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

for batch in loader:
    print(batch["frame"])
    print(batch["points"].shape)  # (B, N, 2)
    break
# Out:
# tensor([   0,    1,   29,   50,   63,   79,  103,  139,  181,  216,  248,  273,
#          296,  325,  347,  366,  378,  420,  441,  480,  521,  557,  620,  743,
#          831,  857,  879,  929, 1015, 1056, 1065, 1077])
# torch.Size([32, 5, 2])

# %%
trial_number = 0

from datetime import datetime
import time

# instantiate generator, discriminator
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

# if not os.path.exists(datapath+"/trial_"+str(trial_number)):
#     os.mkdir(datapath+"/trial_"+str(trial_number))

device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")
print("device: ", device)

#print("Instantiating ImgToHeatmap")
print("Instantiating UNet")
# Create the generator
#model = ImgToHeatmap().to(device, dtype=torch.float32)
model = UNet().to(device, dtype=torch.float32)
model.apply(weights_init)
print(model)

# Setup Adam optimizers for both G and D
optimizer = optim.Adam(model.parameters(), lr=0.002, betas=(0.5, 0.999))
print("Model optimizer: \n", optimizer)

#criterion = nn.BCELoss()
criterion = nn.BCELoss()
error_kind = "BCE"

clipper = WeightConstraint()
# Out:
# device:  cpu
# Instantiating UNet
# UNet(
#   (init_conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsize1): Down(
#     (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize2): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(16, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize3): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize4): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize5): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (inter_conv1): Conv2d(32, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batch_norm1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1): ReLU(inplace=True)
#   (inter_linear1): Linear(in_features=64, out_features=16, bias=True)
#   (batch_norm1_5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1_5): ReLU(inplace=True)
#   (inter_linear2): Linear(in_features=16, out_features=16, bias=True)
#   (batch_norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation2): ReLU(inplace=True)
#   (inter_linear3): Linear(in_features=16, out_features=64, bias=True)
#   (batch_norm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation3): ReLU(inplace=True)
#   (inter_conv3): Conv2d(36, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsize5): Up(
#     (up): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize4): Up(
#     (up): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize3): Up(
#     (up): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize2): Up(
#     (up): ConvTranspose2d(16, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize1): Up(
#     (up): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(8, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# Model optimizer:
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.5, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.002
#     maximize: False
#     weight_decay: 0
# )

# %%
iters = 0
epoch = 0
num_epochs = 1000
#k=500 # saving images of fixed_noise outputs
last_save = iters
break_flag = False

losses = []

example_idx = 110

# %%
# train the model
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

#train_D_only = False
#train_G_only = False
print("Starting Training Loop...")
while (epoch < num_epochs) and (not break_flag):
    # For each batch in the dataloader
    should_break = False
    
    for i, data in enumerate(loader, 0):
        print("Epoch\t"+str(epoch)+", batch\t"+str(i)+".", end="\n")
         # Check how the generator is doing by saving G's output on fixed_noise
        #if (epoch % k == 0) and (i == len(dataloader)-1):
        data_input = data['image']
        output = data['heatmaps']

        data_input = data_input.to(device, dtype=torch.float32)
        batch_size = data_input.size(0)
        print("Batch size: ", batch_size)
        print(data_input.dtype)

        # print(dataseq.shape)

        heatmap_predicted = model(data_input) # outputs logits

        model.zero_grad()

        y_err = 1
        # for i in range(NUM_LANDMARKS):
        #     print(torch.argmax(torch.reshape(output[0, i, :, :], (model_image_size*model_image_size,))))
        #print(data['points'])
        err = criterion(heatmap_predicted.flatten(), output.flatten())
        err.backward()

        optimizer.step()

        #time.sleep(1.00)

        print(f"\t {error_kind}: {err.item()}")
        losses.append((epoch, i, iters, {f"{error_kind}_error": err.item()},
                                        {f"y_{error_kind}_error": y_err} ))

        iters += 1
    
        # if iters > 1000: # stop to quickly see results
        #     should_break = True
        #     break
    
    if should_break:
        break

    # if (epoch+1) % 1 == 0:
    #     print(f"Saving results for example index {example_idx}")
    #     # output example output from model
    #     example_point = dataset[example_idx]
    #     image = torch.permute(example_point['image'], (1, 2, 0))
    #     plt.imshow(image.numpy())
    #     plt.savefig(f"{output_dir}/epoch{epoch}_in.png")
    #     plt.clf()

    #     input_example = example_point['image'].to(dtype=torch.float32)
    #     print(torch.min(input_example), torch.max(input_example))
    #     print(input_example.shape)
    #     heatmap_pred = model( torch.stack((input_example,)) ).detach()
    #     heatmap_actual = example_point['heatmaps']
    #     print(heatmap_pred.shape)
    #     for i in range(NUM_LANDMARKS):
    #         plt.imshow(heatmap_pred.numpy()[0][i], vmin=0, vmax=1)
    #         plt.colorbar()
    #         plt.savefig(f"{output_dir}/epoch{epoch}_out_{i}.png")
    #         plt.clf()
    #         plt.imshow(heatmap_actual.numpy()[i], vmin=0, vmax=1)
    #         plt.colorbar()
    #         plt.savefig(f"{output_dir}/epoch{epoch}_out_{i}_real.png")
    #         plt.clf()

    epoch += 1
    SIGMA_RATIO = ((SIGMA_RATIO - 0.05) * 0.996) + 0.05
    print(f"New SIGMA_RATIO: {SIGMA_RATIO}")
# Out:
# Starting Training Loop...
# Epoch	0, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.774791955947876
# Epoch	0, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.7312891483306885
# Epoch	0, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.7106741070747375
# Epoch	0, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.7002919316291809
# Epoch	0, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.6856981515884399
# Epoch	0, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.6679285168647766
# Epoch	0, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.6502240896224976
# Epoch	0, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.6305733919143677
# Epoch	0, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.6146637201309204
# Epoch	0, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.590043842792511
# Epoch	0, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.5693773031234741
# Epoch	0, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.5513738393783569
# Epoch	0, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.53671795129776
# Epoch	0, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.5080307722091675
# Epoch	0, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.4926721155643463
# Epoch	0, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.49050450325012207
# Epoch	0, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.47271594405174255
# Epoch	0, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.45221394300460815
# Epoch	0, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.4479305148124695
# Epoch	0, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.41499391198158264
# Epoch	0, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.41411441564559937
# Epoch	0, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.41266098618507385
# Epoch	0, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3969314992427826
# Epoch	0, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3987533152103424
# Epoch	0, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3877595067024231
# Epoch	0, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3855704367160797
# Epoch	0, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3703130781650543
# Epoch	0, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3724204897880554
# Epoch	0, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.33312851190567017
# New SIGMA_RATIO: 0.3986
# Epoch	1, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3561803698539734
# Epoch	1, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.370074599981308
# Epoch	1, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3655467629432678
# Epoch	1, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.35526490211486816
# Epoch	1, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.345278263092041
# Epoch	1, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31670963764190674
# Epoch	1, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33307260274887085
# Epoch	1, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3423078656196594
# Epoch	1, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.330782949924469
# Epoch	1, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.299648642539978
# Epoch	1, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3253924250602722
# Epoch	1, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.34530460834503174
# Epoch	1, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3479502499103546
# Epoch	1, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.305223673582077
# Epoch	1, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32086771726608276
# Epoch	1, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3453124761581421
# Epoch	1, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31316354870796204
# Epoch	1, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32116183638572693
# Epoch	1, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3157832622528076
# Epoch	1, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31089726090431213
# Epoch	1, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.34622594714164734
# Epoch	1, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.34367746114730835
# Epoch	1, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33588266372680664
# Epoch	1, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3449705243110657
# Epoch	1, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3380390703678131
# Epoch	1, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33255186676979065
# Epoch	1, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3260904848575592
# Epoch	1, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3256877362728119
# Epoch	1, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2880420982837677
# New SIGMA_RATIO: 0.3972056
# Epoch	2, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3223971426486969
# Epoch	2, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3345773220062256
# Epoch	2, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3276510238647461
# Epoch	2, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3456675112247467
# Epoch	2, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31686264276504517
# Epoch	2, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27948230504989624
# Epoch	2, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30030906200408936
# Epoch	2, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3153180480003357
# Epoch	2, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3051535189151764
# Epoch	2, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2854105830192566
# Epoch	2, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28795579075813293
# Epoch	2, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31295260787010193
# Epoch	2, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32426297664642334
# Epoch	2, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2663639187812805
# Epoch	2, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.286676824092865
# Epoch	2, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32197079062461853
# Epoch	2, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29443198442459106
# Epoch	2, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3004015386104584
# Epoch	2, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28981637954711914
# Epoch	2, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2773846685886383
# Epoch	2, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3240866959095001
# Epoch	2, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3360781669616699
# Epoch	2, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31803789734840393
# Epoch	2, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33580976724624634
# Epoch	2, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3171602785587311
# Epoch	2, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31871575117111206
# Epoch	2, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30560988187789917
# Epoch	2, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3000974953174591
# Epoch	2, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.25576356053352356
# New SIGMA_RATIO: 0.3958167776
# Epoch	3, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31014543771743774
# Epoch	3, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31578096747398376
# Epoch	3, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3061439096927643
# Epoch	3, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3230579197406769
# Epoch	3, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30769583582878113
# Epoch	3, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2729690372943878
# Epoch	3, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29709482192993164
# Epoch	3, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33533865213394165
# Epoch	3, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29609501361846924
# Epoch	3, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27126288414001465
# Epoch	3, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.293547123670578
# Epoch	3, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3082265853881836
# Epoch	3, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3184592127799988
# Epoch	3, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26054197549819946
# Epoch	3, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28880059719085693
# Epoch	3, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3128863573074341
# Epoch	3, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2815355360507965
# Epoch	3, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28846389055252075
# Epoch	3, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2724606394767761
# Epoch	3, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2753000855445862
# Epoch	3, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3158146142959595
# Epoch	3, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32482975721359253
# Epoch	3, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3057464063167572
# Epoch	3, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3261317312717438
# Epoch	3, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3165047764778137
# Epoch	3, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32017526030540466
# Epoch	3, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3159081041812897
# Epoch	3, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28571727871894836
# Epoch	3, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.27376991510391235
# New SIGMA_RATIO: 0.3944335104896
# Epoch	4, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29774171113967896
# Epoch	4, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3153429627418518
# Epoch	4, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3179546296596527
# Epoch	4, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3292863965034485
# Epoch	4, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29695600271224976
# Epoch	4, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2816076874732971
# Epoch	4, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29664117097854614
# Epoch	4, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3023937940597534
# Epoch	4, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30589818954467773
# Epoch	4, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2742564082145691
# Epoch	4, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30281171202659607
# Epoch	4, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30678725242614746
# Epoch	4, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31550267338752747
# Epoch	4, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.269719660282135
# Epoch	4, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28962817788124084
# Epoch	4, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3219795823097229
# Epoch	4, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2808820605278015
# Epoch	4, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2912308871746063
# Epoch	4, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27589714527130127
# Epoch	4, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.266175240278244
# Epoch	4, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30795878171920776
# Epoch	4, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31269359588623047
# Epoch	4, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3099095821380615
# Epoch	4, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3295281231403351
# Epoch	4, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2837217152118683
# Epoch	4, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3154471218585968
# Epoch	4, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29111236333847046
# Epoch	4, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29117077589035034
# Epoch	4, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2570665776729584
# New SIGMA_RATIO: 0.3930557764476416
# Epoch	5, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2921803593635559
# Epoch	5, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3087770342826843
# Epoch	5, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32955318689346313
# Epoch	5, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32618123292922974
# Epoch	5, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3118787407875061
# Epoch	5, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28411057591438293
# Epoch	5, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31158170104026794
# Epoch	5, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3470225930213928
# Epoch	5, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28610730171203613
# Epoch	5, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2740083336830139
# Epoch	5, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2899508774280548
# Epoch	5, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31638577580451965
# Epoch	5, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31902652978897095
# Epoch	5, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2685842514038086
# Epoch	5, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28083041310310364
# Epoch	5, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2980975806713104
# Epoch	5, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29419368505477905
# Epoch	5, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2886372208595276
# Epoch	5, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2855955958366394
# Epoch	5, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28172123432159424
# Epoch	5, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33031731843948364
# Epoch	5, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32624274492263794
# Epoch	5, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30664515495300293
# Epoch	5, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31703734397888184
# Epoch	5, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3157767653465271
# Epoch	5, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29621821641921997
# Epoch	5, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29432475566864014
# Epoch	5, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27577248215675354
# Epoch	5, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.26611489057540894
# New SIGMA_RATIO: 0.39168355334185107
# Epoch	6, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30713802576065063
# Epoch	6, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30700844526290894
# Epoch	6, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3241274058818817
# Epoch	6, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31669169664382935
# Epoch	6, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3042629361152649
# Epoch	6, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27610525488853455
# Epoch	6, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29365354776382446
# Epoch	6, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31471431255340576
# Epoch	6, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3010326027870178
# Epoch	6, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2762727439403534
# Epoch	6, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2812948524951935
# Epoch	6, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29839321970939636
# Epoch	6, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29969850182533264
# Epoch	6, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25490719079971313
# Epoch	6, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2940022647380829
# Epoch	6, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3174988925457001
# Epoch	6, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2777685523033142
# Epoch	6, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29356810450553894
# Epoch	6, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27951207756996155
# Epoch	6, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27112913131713867
# Epoch	6, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32861047983169556
# Epoch	6, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3221297264099121
# Epoch	6, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3254586160182953
# Epoch	6, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32423633337020874
# Epoch	6, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3023833632469177
# Epoch	6, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30291613936424255
# Epoch	6, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2807905972003937
# Epoch	6, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28124910593032837
# Epoch	6, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2591780126094818
# New SIGMA_RATIO: 0.39031681912848365
# Epoch	7, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31003373861312866
# Epoch	7, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3186766803264618
# Epoch	7, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32041653990745544
# Epoch	7, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31560713052749634
# Epoch	7, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28206977248191833
# Epoch	7, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27732449769973755
# Epoch	7, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29861658811569214
# Epoch	7, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30002105236053467
# Epoch	7, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28246909379959106
# Epoch	7, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26802247762680054
# Epoch	7, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2735995948314667
# Epoch	7, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3146848976612091
# Epoch	7, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2868504524230957
# Epoch	7, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2602803409099579
# Epoch	7, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2725209593772888
# Epoch	7, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3117116093635559
# Epoch	7, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27932292222976685
# Epoch	7, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29669293761253357
# Epoch	7, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27440202236175537
# Epoch	7, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26079490780830383
# Epoch	7, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.33892589807510376
# Epoch	7, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3046286702156067
# Epoch	7, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2899840772151947
# Epoch	7, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32129210233688354
# Epoch	7, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30569833517074585
# Epoch	7, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31692826747894287
# Epoch	7, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2859165072441101
# Epoch	7, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.269198477268219
# Epoch	7, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2539830803871155
# New SIGMA_RATIO: 0.3889555518519697
# Epoch	8, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2910342514514923
# Epoch	8, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2969925105571747
# Epoch	8, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2889593541622162
# Epoch	8, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30368369817733765
# Epoch	8, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30137890577316284
# Epoch	8, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26891547441482544
# Epoch	8, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28324589133262634
# Epoch	8, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3011496961116791
# Epoch	8, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29166197776794434
# Epoch	8, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26543140411376953
# Epoch	8, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2877802550792694
# Epoch	8, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29029831290245056
# Epoch	8, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.307646781206131
# Epoch	8, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2583412528038025
# Epoch	8, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2732453942298889
# Epoch	8, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30076271295547485
# Epoch	8, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27683278918266296
# Epoch	8, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2898581027984619
# Epoch	8, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2724030315876007
# Epoch	8, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2700541615486145
# Epoch	8, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3297348618507385
# Epoch	8, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3146301209926605
# Epoch	8, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3031095564365387
# Epoch	8, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3190099596977234
# Epoch	8, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30156412720680237
# Epoch	8, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3014221787452698
# Epoch	8, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.31557223200798035
# Epoch	8, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2681446671485901
# Epoch	8, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.24407021701335907
# New SIGMA_RATIO: 0.38759972964456185
# Epoch	9, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2788602411746979
# Epoch	9, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3008822500705719
# Epoch	9, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30602362751960754
# Epoch	9, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32978373765945435
# Epoch	9, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2955448031425476
# Epoch	9, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2755722999572754
# Epoch	9, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27750691771507263
# Epoch	9, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30322521924972534
# Epoch	9, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30663853883743286
# Epoch	9, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26837414503097534
# Epoch	9, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2837998569011688
# Epoch	9, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28980404138565063
# Epoch	9, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2889370024204254
# Epoch	9, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2424864023923874
# Epoch	9, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2812099754810333
# Epoch	9, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29788151383399963
# Epoch	9, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2682284414768219
# Epoch	9, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29164260625839233
# Epoch	9, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.285043329000473
# Epoch	9, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26878851652145386
# Epoch	9, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.32098764181137085
# Epoch	9, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2966253161430359
# Epoch	9, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29112499952316284
# Epoch	9, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3199838101863861
# Epoch	9, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3039639890193939
# Epoch	9, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3031729459762573
# Epoch	9, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3011156916618347
# Epoch	9, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28741198778152466
# Epoch	9, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2554851770401001
# New SIGMA_RATIO: 0.3862493307259836
# Epoch	10, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3015254735946655
# Epoch	10, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30073970556259155
# Epoch	10, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28540998697280884
# Epoch	10, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2893213629722595
# Epoch	10, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29391032457351685
# Epoch	10, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2527359127998352
# Epoch	10, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29034218192100525
# Epoch	10, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2983108162879944
# Epoch	10, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2940041124820709
# Epoch	10, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25575825572013855
# Epoch	10, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27065300941467285
# Epoch	10, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29214611649513245
# Epoch	10, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.297092080116272
# Epoch	10, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23719096183776855
# Epoch	10, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2657153606414795
# Epoch	10, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28942248225212097
# Epoch	10, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2767259180545807
# Epoch	10, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28816932439804077
# Epoch	10, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24900004267692566
# Epoch	10, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24982328712940216
# Epoch	10, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3138049244880676
# Epoch	10, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30688637495040894
# Epoch	10, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3005802035331726
# Epoch	10, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.302861750125885
# Epoch	10, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2922529876232147
# Epoch	10, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2897617220878601
# Epoch	10, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.3000168204307556
# Epoch	10, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27452927827835083
# Epoch	10, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2510930597782135
# New SIGMA_RATIO: 0.38490433340307967
# Epoch	11, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.263044536113739
# Epoch	11, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2882065773010254
# Epoch	11, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.307841956615448
# Epoch	11, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29918909072875977
# Epoch	11, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27896904945373535
# Epoch	11, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2602878212928772
# Epoch	11, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27908995747566223
# Epoch	11, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29403549432754517
# Epoch	11, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2673680782318115
# Epoch	11, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2423233687877655
# Epoch	11, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2651362717151642
# Epoch	11, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28224554657936096
# Epoch	11, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2886708676815033
# Epoch	11, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23175711929798126
# Epoch	11, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2621017098426819
# Epoch	11, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.30373629927635193
# Epoch	11, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2691897749900818
# Epoch	11, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27211809158325195
# Epoch	11, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2506740689277649
# Epoch	11, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2671511173248291
# Epoch	11, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29050305485725403
# Epoch	11, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2943480610847473
# Epoch	11, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2808237075805664
# Epoch	11, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2912289500236511
# Epoch	11, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2721578776836395
# Epoch	11, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2927769720554352
# Epoch	11, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27834320068359375
# Epoch	11, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25433528423309326
# Epoch	11, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.23858432471752167
# New SIGMA_RATIO: 0.38356471606946735
# Epoch	12, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.283046156167984
# Epoch	12, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2730120122432709
# Epoch	12, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2686181962490082
# Epoch	12, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27065309882164
# Epoch	12, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26556798815727234
# Epoch	12, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2532784342765808
# Epoch	12, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2635630667209625
# Epoch	12, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28613007068634033
# Epoch	12, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.278491735458374
# Epoch	12, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2605134844779968
# Epoch	12, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2531089782714844
# Epoch	12, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2655564248561859
# Epoch	12, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2904369831085205
# Epoch	12, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23433303833007812
# Epoch	12, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2585330009460449
# Epoch	12, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2725614905357361
# Epoch	12, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2544933557510376
# Epoch	12, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2578448951244354
# Epoch	12, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26432159543037415
# Epoch	12, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23705586791038513
# Epoch	12, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2900843024253845
# Epoch	12, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2743385434150696
# Epoch	12, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.281963974237442
# Epoch	12, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.29916396737098694
# Epoch	12, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27893078327178955
# Epoch	12, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2717317044734955
# Epoch	12, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2652308940887451
# Epoch	12, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2559643089771271
# Epoch	12, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.23919537663459778
# New SIGMA_RATIO: 0.3822304572051895
# Epoch	13, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2519867420196533
# Epoch	13, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.276818186044693
# Epoch	13, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2765611708164215
# Epoch	13, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28475335240364075
# Epoch	13, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2504647970199585
# Epoch	13, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23835062980651855
# Epoch	13, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2523655891418457
# Epoch	13, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25458481907844543
# Epoch	13, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25617605447769165
# Epoch	13, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24058742821216583
# Epoch	13, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2528618574142456
# Epoch	13, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25918272137641907
# Epoch	13, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28330400586128235
# Epoch	13, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22836032509803772
# Epoch	13, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25660309195518494
# Epoch	13, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27607959508895874
# Epoch	13, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24702414870262146
# Epoch	13, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2510151267051697
# Epoch	13, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23989589512348175
# Epoch	13, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23925599455833435
# Epoch	13, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2880029082298279
# Epoch	13, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27508947253227234
# Epoch	13, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2771976590156555
# Epoch	13, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2882842421531677
# Epoch	13, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2872663140296936
# Epoch	13, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2728344202041626
# Epoch	13, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26079386472702026
# Epoch	13, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.252049058675766
# Epoch	13, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.22787369787693024
# New SIGMA_RATIO: 0.3809015353763687
# Epoch	14, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24851636588573456
# Epoch	14, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26919734477996826
# Epoch	14, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2937338948249817
# Epoch	14, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2908303737640381
# Epoch	14, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2549414336681366
# Epoch	14, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2428433895111084
# Epoch	14, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2538036108016968
# Epoch	14, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2725362181663513
# Epoch	14, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25255388021469116
# Epoch	14, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2430347502231598
# Epoch	14, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24142661690711975
# Epoch	14, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26224175095558167
# Epoch	14, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27318039536476135
# Epoch	14, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23730869591236115
# Epoch	14, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2435888797044754
# Epoch	14, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2742307484149933
# Epoch	14, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24687731266021729
# Epoch	14, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25113826990127563
# Epoch	14, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23518939316272736
# Epoch	14, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23628640174865723
# Epoch	14, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.280174195766449
# Epoch	14, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2812923192977905
# Epoch	14, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2640109658241272
# Epoch	14, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2774285674095154
# Epoch	14, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27860498428344727
# Epoch	14, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2686605155467987
# Epoch	14, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25247934460639954
# Epoch	14, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24371889233589172
# Epoch	14, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2263771891593933
# New SIGMA_RATIO: 0.3795779292348633
# Epoch	15, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2421543151140213
# Epoch	15, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2619800865650177
# Epoch	15, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2636934220790863
# Epoch	15, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2617281377315521
# Epoch	15, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27016735076904297
# Epoch	15, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24017472565174103
# Epoch	15, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25321483612060547
# Epoch	15, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27264219522476196
# Epoch	15, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2592625021934509
# Epoch	15, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25488516688346863
# Epoch	15, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23343996703624725
# Epoch	15, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2635500431060791
# Epoch	15, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27551332116127014
# Epoch	15, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2210582196712494
# Epoch	15, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.251459002494812
# Epoch	15, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26546239852905273
# Epoch	15, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22489623725414276
# Epoch	15, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2451336681842804
# Epoch	15, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24295513331890106
# Epoch	15, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23408088088035583
# Epoch	15, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2892301678657532
# Epoch	15, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27753669023513794
# Epoch	15, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2616482675075531
# Epoch	15, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28419366478919983
# Epoch	15, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2749229073524475
# Epoch	15, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.268726646900177
# Epoch	15, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25637418031692505
# Epoch	15, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25514844059944153
# Epoch	15, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.22145572304725647
# New SIGMA_RATIO: 0.3782596175179238
# Epoch	16, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23901458084583282
# Epoch	16, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2574560344219208
# Epoch	16, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24884602427482605
# Epoch	16, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27107468247413635
# Epoch	16, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.264751672744751
# Epoch	16, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.21351608633995056
# Epoch	16, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2537297308444977
# Epoch	16, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25676921010017395
# Epoch	16, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2605982720851898
# Epoch	16, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23358264565467834
# Epoch	16, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23574237525463104
# Epoch	16, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25323501229286194
# Epoch	16, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2709857225418091
# Epoch	16, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2155345231294632
# Epoch	16, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24144139885902405
# Epoch	16, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2857854962348938
# Epoch	16, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22030770778656006
# Epoch	16, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2580433785915375
# Epoch	16, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23235902190208435
# Epoch	16, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22904273867607117
# Epoch	16, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2857188582420349
# Epoch	16, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2731664776802063
# Epoch	16, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2614472806453705
# Epoch	16, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2792779803276062
# Epoch	16, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24633283913135529
# Epoch	16, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2682945132255554
# Epoch	16, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26467397809028625
# Epoch	16, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24931713938713074
# Epoch	16, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2092542201280594
# New SIGMA_RATIO: 0.3769465790478521
# Epoch	17, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24492469429969788
# Epoch	17, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26828721165657043
# Epoch	17, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2737060785293579
# Epoch	17, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26300764083862305
# Epoch	17, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2666105329990387
# Epoch	17, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23570950329303741
# Epoch	17, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24804511666297913
# Epoch	17, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.28630638122558594
# Epoch	17, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2360244244337082
# Epoch	17, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22314071655273438
# Epoch	17, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22979876399040222
# Epoch	17, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2489781379699707
# Epoch	17, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2661752998828888
# Epoch	17, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.20499774813652039
# Epoch	17, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23192647099494934
# Epoch	17, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26155897974967957
# Epoch	17, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2427597939968109
# Epoch	17, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24079927802085876
# Epoch	17, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22524845600128174
# Epoch	17, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23075446486473083
# Epoch	17, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2749670743942261
# Epoch	17, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27976465225219727
# Epoch	17, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26641708612442017
# Epoch	17, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2704407870769501
# Epoch	17, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26205864548683167
# Epoch	17, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2651711106300354
# Epoch	17, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24563594162464142
# Epoch	17, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25522881746292114
# Epoch	17, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.21198689937591553
# New SIGMA_RATIO: 0.37563879273166073
# Epoch	18, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25521305203437805
# Epoch	18, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26325687766075134
# Epoch	18, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26597583293914795
# Epoch	18, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27184027433395386
# Epoch	18, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.258004367351532
# Epoch	18, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23278121650218964
# Epoch	18, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2378500998020172
# Epoch	18, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2601436674594879
# Epoch	18, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2556315064430237
# Epoch	18, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2238336056470871
# Epoch	18, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23018774390220642
# Epoch	18, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2487787902355194
# Epoch	18, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2566646933555603
# Epoch	18, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2099747359752655
# Epoch	18, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24456802010536194
# Epoch	18, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2704882323741913
# Epoch	18, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22950303554534912
# Epoch	18, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24400249123573303
# Epoch	18, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24918422102928162
# Epoch	18, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22518131136894226
# Epoch	18, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25640082359313965
# Epoch	18, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27129608392715454
# Epoch	18, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25558745861053467
# Epoch	18, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2845326066017151
# Epoch	18, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25425004959106445
# Epoch	18, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.251992791891098
# Epoch	18, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23876626789569855
# Epoch	18, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2413719892501831
# Epoch	18, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.2150353044271469
# New SIGMA_RATIO: 0.3743362375607341
# Epoch	19, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2570327818393707
# Epoch	19, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2644672393798828
# Epoch	19, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27741268277168274
# Epoch	19, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2603824734687805
# Epoch	19, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2451551854610443
# Epoch	19, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23149380087852478
# Epoch	19, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2321220189332962
# Epoch	19, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2634761929512024
# Epoch	19, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2556571364402771
# Epoch	19, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22280976176261902
# Epoch	19, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23441603779792786
# Epoch	19, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24566009640693665
# Epoch	19, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2541937828063965
# Epoch	19, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.21481087803840637
# Epoch	19, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24343042075634003
# Epoch	19, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25802576541900635
# Epoch	19, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22349591553211212
# Epoch	19, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24194848537445068
# Epoch	19, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2377350777387619
# Epoch	19, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22569116950035095
# Epoch	19, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2737019658088684
# Epoch	19, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.26179876923561096
# Epoch	19, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2567276358604431
# Epoch	19, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2579723596572876
# Epoch	19, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23990461230278015
# Epoch	19, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.27164924144744873
# Epoch	19, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2482428103685379
# Epoch	19, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24551424384117126
# Epoch	19, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.20406493544578552
# New SIGMA_RATIO: 0.37303889261049117
# Epoch	20, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2320760190486908
# Epoch	20, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25329315662384033
# Epoch	20, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2701927721500397
# Epoch	20, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2519283890724182
# Epoch	20, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24990281462669373
# Epoch	20, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2090669572353363
# Epoch	20, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24224098026752472
# Epoch	20, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.249231219291687
# Epoch	20, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24118272960186005
# Epoch	20, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.21365666389465332
# Epoch	20, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2191922664642334
# Epoch	20, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2475452423095703
# Epoch	20, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25266215205192566
# Epoch	20, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2061069905757904
# Epoch	20, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23218326270580292
# Epoch	20, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2672690749168396
# Epoch	20, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2273176610469818
# Epoch	20, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2443753033876419
# Epoch	20, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24736514687538147
# Epoch	20, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.20828504860401154
# Epoch	20, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2619214951992035
# Epoch	20, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2675172686576843
# Epoch	20, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24293389916419983
# Epoch	20, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2708927094936371
# Epoch	20, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2583823800086975
# Epoch	20, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2705291509628296
# Epoch	20, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24708454310894012
# Epoch	20, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23396825790405273
# Epoch	20, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.20230919122695923
# New SIGMA_RATIO: 0.3717467370400492
# Epoch	21, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24101737141609192
# Epoch	21, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2557385563850403
# Epoch	21, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.25012683868408203
# Epoch	21, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2619796693325043
# Epoch	21, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24558117985725403
# Epoch	21, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.21754665672779083
# Epoch	21, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23945629596710205
# Epoch	21, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.251525342464447
# Epoch	21, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.23634377121925354
# Epoch	21, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22229628264904022
# Epoch	21, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.22472283244132996
# Epoch	21, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.2511088252067566
# Epoch	21, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.24084213376045227
# Epoch	21, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.21663406491279602
# Epoch	21, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.225190669298172
# Epoch	21, batch	15.
# Batch size:  32
# torch.float32
# ...
# Epoch	456, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.024087410420179367
# Epoch	456, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020764252170920372
# Epoch	456, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02071872539818287
# Epoch	456, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01948719471693039
# Epoch	456, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019328875467181206
# Epoch	456, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.024755001068115234
# Epoch	456, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.0230956319719553
# Epoch	456, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01962919346988201
# Epoch	456, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022262802347540855
# Epoch	456, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02086295746266842
# Epoch	456, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022200021892786026
# Epoch	456, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020040122792124748
# Epoch	456, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018365750089287758
# Epoch	456, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.019398046657443047
# New SIGMA_RATIO: 0.10605130184867648
# Epoch	457, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020484881475567818
# Epoch	457, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02174592949450016
# Epoch	457, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020906789228320122
# Epoch	457, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020033108070492744
# Epoch	457, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020121708512306213
# Epoch	457, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017689375206828117
# Epoch	457, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019466903060674667
# Epoch	457, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021169966086745262
# Epoch	457, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018608173355460167
# Epoch	457, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01652469113469124
# Epoch	457, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01887892186641693
# Epoch	457, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019565775990486145
# Epoch	457, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02052384801208973
# Epoch	457, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.015773097053170204
# Epoch	457, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01835654303431511
# Epoch	457, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022210465744137764
# Epoch	457, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01773102767765522
# Epoch	457, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017610624432563782
# Epoch	457, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019720593467354774
# Epoch	457, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017338329926133156
# Epoch	457, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.023364847525954247
# Epoch	457, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02080005779862404
# Epoch	457, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021222170442342758
# Epoch	457, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.023200329393148422
# Epoch	457, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020018432289361954
# Epoch	457, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01948484033346176
# Epoch	457, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01981198601424694
# Epoch	457, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02020292542874813
# Epoch	457, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.016906971111893654
# New SIGMA_RATIO: 0.10582709664128177
# Epoch	458, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021393772214651108
# Epoch	458, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02110378071665764
# Epoch	458, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021346719935536385
# Epoch	458, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02426130697131157
# Epoch	458, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019252438098192215
# Epoch	458, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01635332778096199
# Epoch	458, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018939578905701637
# Epoch	458, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02130449377000332
# Epoch	458, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020027294754981995
# Epoch	458, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.014872631058096886
# Epoch	458, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017877589911222458
# Epoch	458, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020110372453927994
# Epoch	458, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021432258188724518
# Epoch	458, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.016711197793483734
# Epoch	458, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018990781158208847
# Epoch	458, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021808257326483727
# Epoch	458, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018820732831954956
# Epoch	458, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.0220677200704813
# Epoch	458, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017356026917696
# Epoch	458, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017961706966161728
# Epoch	458, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022193532437086105
# Epoch	458, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022150343284010887
# Epoch	458, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021239247173070908
# Epoch	458, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02287040650844574
# Epoch	458, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019934289157390594
# Epoch	458, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022084444761276245
# Epoch	458, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01982239820063114
# Epoch	458, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018937647342681885
# Epoch	458, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.016990790143609047
# New SIGMA_RATIO: 0.10560378825471664
# Epoch	459, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021442711353302002
# Epoch	459, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02124444581568241
# Epoch	459, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019148170948028564
# Epoch	459, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019949276000261307
# Epoch	459, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022128257900476456
# Epoch	459, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.016269125044345856
# Epoch	459, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019352205097675323
# Epoch	459, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.023106243461370468
# Epoch	459, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019915971904993057
# Epoch	459, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019060876220464706
# Epoch	459, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01834098994731903
# Epoch	459, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020716629922389984
# Epoch	459, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020762737840414047
# Epoch	459, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01707257702946663
# Epoch	459, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021494746208190918
# Epoch	459, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02316363714635372
# Epoch	459, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01998031698167324
# Epoch	459, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018971025943756104
# Epoch	459, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020057354122400284
# Epoch	459, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02067103609442711
# Epoch	459, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02327551506459713
# Epoch	459, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020687978714704514
# Epoch	459, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021714989095926285
# Epoch	459, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021193457767367363
# Epoch	459, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021534264087677002
# Epoch	459, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02314641699194908
# Epoch	459, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018490811809897423
# Epoch	459, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018372276797890663
# Epoch	459, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.01830282434821129
# New SIGMA_RATIO: 0.10538137310169778
# Epoch	460, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02110324800014496
# Epoch	460, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021339034661650658
# Epoch	460, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021918147802352905
# Epoch	460, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02188067138195038
# Epoch	460, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.0183677040040493
# Epoch	460, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017785346135497093
# Epoch	460, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017561981454491615
# Epoch	460, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01995261013507843
# Epoch	460, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019387001171708107
# Epoch	460, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.015561336651444435
# Epoch	460, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018521077930927277
# Epoch	460, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022799938917160034
# Epoch	460, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020426709204912186
# Epoch	460, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.016766570508480072
# Epoch	460, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01914832554757595
# Epoch	460, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022669760510325432
# Epoch	460, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019211355596780777
# Epoch	460, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018767766654491425
# Epoch	460, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019939791411161423
# Epoch	460, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01703440025448799
# Epoch	460, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02173946425318718
# Epoch	460, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021170882508158684
# Epoch	460, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020026501268148422
# Epoch	460, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021768875420093536
# Epoch	460, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020413218066096306
# Epoch	460, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02171315625309944
# Epoch	460, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01889721490442753
# Epoch	460, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01920018531382084
# Epoch	460, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.017025845125317574
# New SIGMA_RATIO: 0.10515984760929098
# Epoch	461, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019068321213126183
# Epoch	461, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021218590438365936
# Epoch	461, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021675346419215202
# Epoch	461, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.024286475032567978
# Epoch	461, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021440207958221436
# Epoch	461, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.016689572483301163
# Epoch	461, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020035814493894577
# Epoch	461, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02018236182630062
# Epoch	461, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019795788452029228
# Epoch	461, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017416369169950485
# Epoch	461, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01690545119345188
# Epoch	461, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022276621311903
# Epoch	461, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020216744393110275
# Epoch	461, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.015913665294647217
# Epoch	461, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019740529358386993
# Epoch	461, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02223091945052147
# Epoch	461, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018239710479974747
# Epoch	461, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01971595361828804
# Epoch	461, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.019430723041296005
# Epoch	461, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018179411068558693
# Epoch	461, batch	20.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02401353232562542
# Epoch	461, batch	21.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022187991067767143
# Epoch	461, batch	22.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01908821053802967
# Epoch	461, batch	23.
# Batch size:  32
# torch.float32
# 	 BCE: 0.024108007550239563
# Epoch	461, batch	24.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021495245397090912
# Epoch	461, batch	25.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021549243479967117
# Epoch	461, batch	26.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022592607885599136
# Epoch	461, batch	27.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017326992005109787
# Epoch	461, batch	28.
# Batch size:  19
# torch.float32
# 	 BCE: 0.017106087878346443
# New SIGMA_RATIO: 0.10493920821885382
# Epoch	462, batch	0.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02111758664250374
# Epoch	462, batch	1.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02061440609395504
# Epoch	462, batch	2.
# Batch size:  32
# torch.float32
# 	 BCE: 0.021331779658794403
# Epoch	462, batch	3.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022032462060451508
# Epoch	462, batch	4.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020491482689976692
# Epoch	462, batch	5.
# Batch size:  32
# torch.float32
# 	 BCE: 0.016930734738707542
# Epoch	462, batch	6.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020950941368937492
# Epoch	462, batch	7.
# Batch size:  32
# torch.float32
# 	 BCE: 0.022475112229585648
# Epoch	462, batch	8.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018675411120057106
# Epoch	462, batch	9.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017563479021191597
# Epoch	462, batch	10.
# Batch size:  32
# torch.float32
# 	 BCE: 0.017578590661287308
# Epoch	462, batch	11.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018890995532274246
# Epoch	462, batch	12.
# Batch size:  32
# torch.float32
# 	 BCE: 0.02031962387263775
# Epoch	462, batch	13.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01824021339416504
# Epoch	462, batch	14.
# Batch size:  32
# torch.float32
# 	 BCE: 0.020779656246304512
# Epoch	462, batch	15.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018945999443531036
# Epoch	462, batch	16.
# Batch size:  32
# torch.float32
# 	 BCE: 0.01908199116587639
# Epoch	462, batch	17.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018009698018431664
# Epoch	462, batch	18.
# Batch size:  32
# torch.float32
# 	 BCE: 0.018419351428747177
# Epoch	462, batch	19.
# Batch size:  32
# torch.float32
# 	 BCE: 0.016875749453902245
# Epoch	462, batch	20.
# Batch size:  32
# torch.float32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[345], line 34
#      30 # for i in range(NUM_LANDMARKS):
#      31 #     print(torch.argmax(torch.reshape(output[0, i, :, :], (model_image_size*model_image_size,))))
#      32 #print(data['points'])
#      33 err = criterion(heatmap_predicted.flatten(), output.flatten())
# ---> 34 err.backward()
#      36 optimizer.step()
#      38 #time.sleep(1.00)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
num_epochs = 2000

# %%
losses

# %%
losses[0]

# %%
import math
plt.plot([x[2] for x in losses], [math.log(x[3][f"{error_kind}_error"], 10) for x in losses])
plt.xlabel("Iterations")
plt.ylabel("Log loss")
# Out:
# Text(0, 0.5, 'Log loss')

# %%
losses[-1][3][f"{error_kind}_error"]
# Out:
# 0.00011381893273210153

# %%
torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': losses,
            }, f"{output_dir}/info_model_112925_460.pt")

# %%
model.eval()
# Out:
# UNet(
#   (init_conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsize1): Down(
#     (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize2): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(16, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize3): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize4): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize5): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (inter_conv1): Conv2d(32, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batch_norm1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1): ReLU(inplace=True)
#   (inter_linear1): Linear(in_features=64, out_features=16, bias=True)
#   (batch_norm1_5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1_5): ReLU(inplace=True)
#   (inter_linear2): Linear(in_features=16, out_features=16, bias=True)
#   (batch_norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation2): ReLU(inplace=True)
#   (inter_linear3): Linear(in_features=16, out_features=64, bias=True)
#   (batch_norm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation3): ReLU(inplace=True)
#   (inter_conv3): Conv2d(36, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsize5): Up(
#     (up): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize4): Up(
#     (up): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize3): Up(
#     (up): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize2): Up(
#     (up): ConvTranspose2d(16, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize1): Up(
#     (up): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(8, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
model_dict = torch.load(f"{output_dir}/info_model_112925_460.pt", weights_only=True)
model_dict['loss'][-1]
# Out:
# /Users/ishwar/anaconda3/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# (462, 19, 13417, {'BCE_error': 0.016875749453902245}, {'y_BCE_error': 1})

# %%
model_loaded = UNet()
model_loaded.load_state_dict(model_dict['model_state_dict'])
model_loaded.eval()
model_loaded
# Out:
# UNet(
#   (init_conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsize1): Down(
#     (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize2): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(16, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize3): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize4): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize5): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (down): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (inter_conv1): Conv2d(32, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batch_norm1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1): ReLU(inplace=True)
#   (inter_linear1): Linear(in_features=64, out_features=16, bias=True)
#   (batch_norm1_5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1_5): ReLU(inplace=True)
#   (inter_linear2): Linear(in_features=16, out_features=16, bias=True)
#   (batch_norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation2): ReLU(inplace=True)
#   (inter_linear3): Linear(in_features=16, out_features=64, bias=True)
#   (batch_norm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation3): ReLU(inplace=True)
#   (inter_conv3): Conv2d(36, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsize5): Up(
#     (up): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize4): Up(
#     (up): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize3): Up(
#     (up): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize2): Up(
#     (up): ConvTranspose2d(16, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (upsize1): Up(
#     (up): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#     (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation2): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(8, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
example_point = dataset[240]
image = torch.permute(example_point['image'], (1, 2, 0))
plt.imshow(image.numpy())

# %%
plt.imshow(torch.sum(example_point['heatmaps'], dim=0).numpy())

# %%
plt.imshow(example_point['heatmaps'][0].numpy())

# %%
input_example = example_point['image'].to(dtype=torch.float32)
print(torch.min(input_example), torch.max(input_example))
print(input_example.shape)
heatmap_pred = model_loaded( torch.stack((input_example,)) ).detach()
print(heatmap_pred.shape)
plt.imshow(heatmap_pred.numpy()[0][1], vmin=0)
plt.colorbar()
# Out:
# tensor(0.) tensor(1.)
# torch.Size([3, 128, 128])
# torch.Size([1, 5, 128, 128])

# %%
plt.imshow(torch.sum(heatmap_pred[0], dim=0).numpy(), vmin=0)
plt.colorbar()

# %%
plt.hist((heatmap_pred - example_point['heatmaps']).detach().numpy().flatten(), bins=100)
# Out:
# (array([2.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 5.000e+00, 9.000e+00,
#         1.600e+01, 2.400e+01, 1.400e+01, 2.800e+01, 3.400e+01, 2.700e+01,
#         3.700e+01, 3.700e+01, 2.900e+01, 2.600e+01, 2.200e+01, 2.900e+01,
#         2.800e+01, 3.200e+01, 3.500e+01, 2.800e+01, 3.000e+01, 2.800e+01,
#         2.400e+01, 2.100e+01, 2.200e+01, 3.000e+01, 2.000e+01, 2.500e+01,
#         2.700e+01, 2.100e+01, 2.300e+01, 2.600e+01, 2.900e+01, 3.000e+01,
#         2.300e+01, 2.100e+01, 2.400e+01, 2.900e+01, 3.400e+01, 1.900e+01,
#         3.700e+01, 2.800e+01, 2.200e+01, 3.500e+01, 2.000e+01, 2.800e+01,
#         3.900e+01, 3.900e+01, 2.900e+01, 3.600e+01, 4.100e+01, 3.400e+01,
#         4.600e+01, 3.600e+01, 3.200e+01, 3.900e+01, 4.600e+01, 3.700e+01,
#         5.000e+01, 4.800e+01, 5.100e+01, 4.100e+01, 5.900e+01, 5.800e+01,
#         6.500e+01, 6.400e+01, 6.700e+01, 7.500e+01, 7.100e+01, 9.400e+01,
#         8.600e+01, 9.800e+01, 1.110e+02, 1.250e+02, 1.490e+02, 1.800e+02,
#         2.270e+02, 3.870e+02, 1.583e+03, 1.216e+03, 6.780e+02, 1.332e+03,
#         2.202e+03, 1.301e+03, 3.139e+03, 1.500e+03, 4.090e+02, 3.550e+02,
#         4.020e+02, 2.018e+03, 5.220e+02, 6.000e+01, 3.000e+01, 1.100e+01,
#         1.000e+01, 5.000e+00, 2.000e+00, 1.000e+00]),
#  array([-0.74356854, -0.73485547, -0.72614235, -0.71742928, -0.70871621,
#         -0.70000315, -0.69129002, -0.68257695, -0.67386389, -0.66515082,
#         -0.6564377 , -0.64772463, -0.63901156, -0.6302985 , -0.62158537,
#         -0.6128723 , -0.60415924, -0.59544611, -0.58673304, -0.57801998,
#         -0.56930691, -0.56059378, -0.55188072, -0.54316765, -0.53445458,
#         -0.52574146, -0.51702839, -0.50831532, -0.49960223, -0.49088913,
#         -0.48217607, -0.47346297, -0.4647499 , -0.45603681, -0.44732374,
#         -0.43861064, -0.42989758, -0.42118448, -0.41247141, -0.40375832,
#         -0.39504525, -0.38633215, -0.37761909, -0.36890599, -0.36019289,
#         -0.35147983, -0.34276673, -0.33405367, -0.32534057, -0.3166275 ,
#         -0.30791441, -0.29920134, -0.29048824, -0.28177518, -0.27306208,
#         -0.26434901, -0.25563592, -0.24692284, -0.23820975, -0.22949667,
#         -0.22078359, -0.21207051, -0.20335743, -0.19464435, -0.18593127,
#         -0.17721817, -0.16850509, -0.15979201, -0.15107892, -0.14236584,
#         -0.13365276, -0.12493968, -0.1162266 , -0.10751352, -0.09880044,
#         -0.09008735, -0.08137427, -0.07266118, -0.0639481 , -0.05523502,
#         -0.04652194, -0.03780885, -0.02909577, -0.02038269, -0.01166961,
#         -0.00295653,  0.00575656,  0.01446964,  0.02318272,  0.03189581,
#          0.04060889,  0.04932197,  0.05803505,  0.06674813,  0.07546122,
#          0.0841743 ,  0.09288738,  0.10160047,  0.11031355,  0.11902663,
#          0.12773971]),
#  <BarContainer object of 100 artists>)

# %%
plt.imshow(np.sum(example_point['heatmaps'].numpy(), axis=0), vmin=0, vmax=1)

# %%
import frame_manager
import importlib
importlib.reload(frame_manager)
# Out:
# <module 'frame_manager' from '/Users/ishwar/Desktop/Aero_ML/frame_manager.py'>

# %%
SMOOTH_CONST = 1
# ---------- Main runner ----------
@torch.inference_mode()
def run_video_demo(model, source=0, device=None, window_name="Landmark Demo"):
    """
    source: 0 for webcam, or path to video file.
    model: a loaded torch.nn.Module that outputs heatmaps (B,C,Hh,Wh)
    """
    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    model.eval().to(device)

    cap = cv2.VideoCapture(source)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video source: {source}")

    t_prev = time.time()
    fps_ema = None

    try:
        while True:
            ok, frame = cap.read()
            if not ok: break

            # Keep a copy for drawing at native res
            out_frame = frame.copy()

            # Preprocess & infer
            tin, orig_wh = preprocess_frame(frame, device)
            # Optional: mixed precision for speed on GPU
            with torch.cuda.amp.autocast(enabled=(device == "cuda")):
                pred = model(tin)                 # expect (1, C, Hh, Wh)
            if pred.dim() == 5: pred = pred[0]    # in case model returns (pred, aux)
            if pred.shape[0] == 1: pred = pred    # (1,C,Hh,Wh)
            _, C, Hh, Wh = pred.shape

            # Get coords in model-input space
            xs_in, ys_in = heatmaps_to_coords(pred)      # each (1,C)
            xs_in, ys_in = xs_in[0], ys_in[0]            # (C,)

            # Draw
            draw_points(out_frame, xs_in, ys_in, orig_wh)

            # FPS
            t_now = time.time()
            fps = 1.0 / max(t_now - t_prev, 1e-6)
            fps_ema = fps if fps_ema is None else 0.9*fps_ema + 0.1*fps
            t_prev = t_now
            put_fps(out_frame, fps_ema)

            cv2.imshow(window_name, out_frame)
            key = cv2.waitKey(1) & 0xFF
            if key in (27, ord('q')):  # ESC or q
                break
    finally:
        cap.release()
        cv2.destroyAllWindows()


class LatestFrameGrabber:
    """Continuously grabs frames on a background thread and keeps only the most recent one."""
    def __init__(self, source=0):
        self.cap = cv2.VideoCapture(source)
        if not self.cap.isOpened():
            raise RuntimeError(f"Could not open video source: {source}")
        # Best-effort: keep tiny buffer (works on some backends; harmless otherwise)
        try:
            self.cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)
        except Exception:
            pass
        self.lock = threading.Lock()
        self.frame = None
        self.stopped = False
        self.t = threading.Thread(target=self._update, daemon=True)
        self.t.start()

    def _update(self):
        while not self.stopped:
            ok, f = self.cap.read()
            if not ok:
                self.stopped = True
                break
            with self.lock:
                self.frame = f

    def read(self):
        with self.lock:
            return None if self.frame is None else self.frame.copy()

    def release(self):
        self.stopped = True
        try:
            self.t.join(timeout=1.0)
        except Exception:
            pass
        self.cap.release()

import time, cv2, torch

@torch.inference_mode()
def run_video_demo_fixed_rate(model, source=0, device=None, window_name="Landmark Demo",
                              sample_hz=15.0, show_fps=True):
    """
    Samples the *latest* frame every 1/sample_hz seconds, runs inference on that frame,
    and displays only those results. Drops frames between ticks to avoid latency buildup.
    """
    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    model.eval().to(device)

    grab = LatestFrameGrabber(source)  # from previous code: grabs frames on a thread
    dt = 1.0 / float(max(sample_hz, 1e-6))
    next_t = time.perf_counter()  # monotonic clock

    disp_fps_ema = None
    try:
        while True:
            now = time.perf_counter()
            # sleep until the next scheduled tick (keeps rate steady, avoids drift)
            if now < next_t:
                time.sleep(next_t - now)
                continue
            # schedule the following tick
            next_t += dt

            t0 = time.perf_counter()
            frame = grab.read()
            if frame is None:
                # No new frame yet; skip this tick but keep schedule
                continue

            out_frame = frame.copy()

            # Preprocess & infer on the ticked frame
            tin, orig_wh = preprocess_frame(frame, device)
            with torch.cuda.amp.autocast(enabled=(device == "cuda")):
                tin = tin.to(dtype=torch.float32)
                pred = model(tin)  # (1, C, Hh, Wh)

            xs_in, ys_in = heatmaps_to_coords(pred)   # each (1, C) in model-input coords
            xs_in, ys_in = xs_in[0], ys_in[0]
            draw_points(out_frame, xs_in, ys_in, orig_wh)

            # Display + UI FPS (UI FPS may be ~ sample_hz)
            t1 = time.perf_counter()
            ui_fps = 1.0 / max(t1 - t0, 1e-6)
            disp_fps_ema = ui_fps if disp_fps_ema is None else 0.9*disp_fps_ema + 0.1*ui_fps
            if show_fps:
                put_fps(out_frame, disp_fps_ema)
                cv2.putText(out_frame, f"Sample: {sample_hz:.1f} Hz",
                            (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2, cv2.LINE_AA)

            cv2.imshow(window_name, out_frame)
            key = cv2.waitKey(1) & 0xFF
            if key in (27, ord('q')):
                break

            # If inference was slower than dt, catch the schedule up (drop extra ticks)
            # so next tick isn't delayed by accumulated lag.
            now2 = time.perf_counter()
            while next_t < now2 - 1e-4:
                next_t += dt
    finally:
        grab.release()
        cv2.destroyAllWindows()

import time, cv2, torch

@torch.inference_mode()
def run_video_demo_auto(model, source=0, device=None, window_name="Landmark Demo",
                        sample_hz=15.0, show_fps=True):
    """
    - If source is webcam (fps not available) → run at fixed sample_hz (e.g. 15 Hz).
    - If source is video file (fps available) → throttle playback to the file's FPS.
    """

    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    model.eval().to(device)

    cap = cv2.VideoCapture(source)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video source: {source}")

    # Try to read FPS from file
    fps_file = cap.get(cv2.CAP_PROP_FPS)
    if fps_file is None or fps_file <= 1e-2:  # webcams often report 0
        mode = "webcam"
        dt = 1.0 / float(max(sample_hz, 1e-6))   # fixed rate
        print(f"[INFO] Webcam mode: target {sample_hz} Hz")
    else:
        mode = "file"
        dt = 1.0 / fps_file
        print(f"[INFO] Video file mode: target {fps_file:.2f} FPS")

    next_t = time.perf_counter()
    disp_fps_ema = None

    prev_xs_in_smooth, prev_ys_in_smooth = None, None

    try:
        while True:
            ok, frame = cap.read()
            if not ok:
                break
            out_frame = frame.copy()

            # preprocess
            tin, orig_wh = frame_manager.preprocess_frame(frame, device)

            # inference
            with torch.cuda.amp.autocast(enabled=(device == "cuda")):
                pred = model(tin)  # (1, C, H, W)
            xs_in, ys_in = frame_manager.heatmaps_to_coords(pred)
            xs_in, ys_in = xs_in[0], ys_in[0]
            if prev_xs_in_smooth is None:
                xs_in_smooth, ys_in_smooth = xs_in, ys_in
            else:
                xs_in_smooth, ys_in_smooth = xs_in*SMOOTH_CONST + prev_xs_in_smooth*(1-SMOOTH_CONST), ys_in*SMOOTH_CONST + prev_ys_in_smooth*(1-SMOOTH_CONST)
            frame_manager.draw_points(out_frame, xs_in_smooth, ys_in_smooth, orig_wh)
            prev_xs_in_smooth, prev_ys_in_smooth = xs_in_smooth, ys_in_smooth

            # UI FPS
            now = time.perf_counter()
            ui_fps = 1.0 / max(now - next_t + dt, 1e-6)
            disp_fps_ema = ui_fps if disp_fps_ema is None else 0.9*disp_fps_ema + 0.1*ui_fps
            if show_fps:
                frame_manager.put_fps(out_frame, disp_fps_ema)

            cv2.imshow(window_name, out_frame)
            key = cv2.waitKey(1) & 0xFF
            if key in (27, ord('q')):
                break

            # pacing
            if mode == "webcam":
                # sleep until next scheduled tick
                now = time.perf_counter()
                if now < next_t:
                    time.sleep(next_t - now)
                next_t += dt
            else:  # file
                wait_ms = int(max(1, dt * 1000))
                if cv2.waitKey(wait_ms) & 0xFF in (27, ord('q')):
                    break

    finally:
        cap.release()
        cv2.destroyAllWindows()

# %%
# or a file:
run_video_demo_auto(model, source="plane_2.mov", sample_hz=60.0)
# Out:
# [INFO] Video file mode: target 59.85 FPS
