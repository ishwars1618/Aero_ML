# %%
# taken from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

#%matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.transforms.v2 as v2transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from PIL import Image
import skimage
from skimage import io, transform

# %% [markdown]
# # Definitions

# %%
batch_size = 256
image_size = 324
model_image_size = 64
workers = 2
rootdir = "/Users/ishwar/Desktop/"
output_dir = "model_output_082625_2"
if not os.path.isdir(output_dir):
    os.mkdir(output_dir)

# %%
class Prnt(nn.Module):
    def __init__(self):
        super(Prnt, self).__init__()

    def forward(self, x):
        print(x)
        return x
    
NUM_LANDMARKS = 5

class ImgToHeatmap(nn.Module):
    def __init__(self):
        super(ImgToHeatmap, self).__init__()
        
        self.modules = []

        self.kernelSize = 5 # must be odd

        self.internal = 7
        self.layers = 10

        self.num_landmarks = NUM_LANDMARKS

        self.p_dropout = 0.2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.modules.append(nn.Conv2d(3, self.internal, self.kernelSize, stride=2, \
                                      padding=(self.kernelSize-1)//2))
        for i in range(self.layers):
            self.modules.append(nn.Conv2d(self.internal, self.internal, self.kernelSize, stride=1, \
                                      padding=(self.kernelSize-1)//2))
            self.modules.append(nn.BatchNorm2d(self.internal))
            self.modules.append(nn.ReLU())
            self.modules.append(nn.Dropout(p=self.p_dropout))
            
        self.modules.append(nn.Conv2d(self.internal, self.num_landmarks, self.kernelSize, stride=1, \
                                      padding=(self.kernelSize-1)//2))
        
        self.modules.append(nn.Sigmoid())
        
        self.main = nn.Sequential(*self.modules)

    def forward(self, input):
        z = self.main(input)
        return z

# %%
class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Up, self).__init__()

        self.up = nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.kernelSize = 3
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)
        self.conv = nn.Conv2d(out_channels*2, out_channels, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        self.batch_norm1 = nn.BatchNorm2d(out_channels)
        self.activation1 = nn.ReLU(True)

    def forward(self, x1, x2):
        x = self.up(x1)
        x = self.batch_norm(x)
        x = self.activation(x)
        #print(f"x.shape {x.shape}")
        x = torch.cat([x, x2], dim=1)
        #print(f"x.shape after merge: {x.shape}")
        x = self.conv(x)
        x = self.batch_norm1(x)
        x = self.activation1(x)
        return x

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Down, self).__init__()

        self.kernelSize = 3
        self.conv = nn.Conv2d(in_channels, in_channels, self.kernelSize, stride=1, \
                                padding=(self.kernelSize-1)//2)
        self.batch_norm0 = nn.BatchNorm2d(in_channels)
        self.activation0 = nn.ReLU(True)
        self.down = nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU(True)

    def forward(self, x):
        x = self.conv(x)
        x = self.batch_norm0(x)
        x = self.activation0(x)
        x = self.down(x)
        x = self.batch_norm(x)
        x = self.activation(x)
        return x

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.modules = []
        self.kernelSize = 3 # must be odd
        self.num_landmarks = NUM_LANDMARKS
        self.p_dropout = 0.2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.init_conv = nn.Conv2d(3, 8, self.kernelSize, stride=1, \
                            padding=(self.kernelSize-1)//2)
        
        # downsizing
        channels = (8, 16)
        self.downsize1 = Down(channels[0], channels[1])

        channels = (16, 32)
        self.downsize2 = Down(channels[0], channels[1])

        channels = (32, 64)
        self.downsize3 = Down(channels[0], channels[1])

        channels = (64, 128)
        self.downsize4 = Down(channels[0], channels[1])

        #upsizing
        channels = (128, 64)
        self.upsize4 = Up(channels[0], channels[1])

        channels = (64, 32)
        self.upsize3 = Up(channels[0], channels[1])

        channels = (32, 16)
        self.upsize2 = Up(channels[0], channels[1])

        channels = (16, 8)
        self.upsize1 = Up(channels[0], channels[1])

        self.final_conv = nn.Conv2d(8, self.num_landmarks, self.kernelSize, stride=1, \
                                    padding=(self.kernelSize-1)//2)
        #self.final_activation = nn.Sigmoid()
        

    def forward(self, input):
        x0 = self.init_conv(input)
        #print(x0.shape)
        #print(torch.mean(torch.std(x0, axis=1)))
        x1 = self.downsize1(x0)
        #print(torch.mean(torch.std(x1, axis=1)))
        #x1 = F.dropout(x1, p=self.p_dropout)
        x2 = self.downsize2(x1)
        #print(torch.mean(torch.std(x2, axis=1)))
        #x2 = F.dropout(x2, p=self.p_dropout)
        x3 = self.downsize3(x2)
        #print(torch.mean(torch.std(x3, axis=1)))
        #x3 = F.dropout(x3, p=self.p_dropout)
        x4 = self.downsize4(x3)
        #print(torch.mean(torch.std(x4, axis=1)))
        #x4 = F.dropout(x4, p=self.p_dropout)
        x = self.upsize4(x4, x3)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize3(x, x2)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize2(x, x1)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.upsize1(x, x0)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = F.dropout(x, p=self.p_dropout)
        x = self.final_conv(x)
        #print(torch.mean(torch.std(x, axis=1)))
        #x = self.final_activation(x)
        #print(torch.mean(torch.std(x, axis=1)))
        return x

# %%
weight_spread = 0.05
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Linear') != -1:
        #nn.init.normal_(m.weight.data, 0.0, 1/16) # not tried yet
        nn.init.normal_(m.weight.data, 0.0, weight_spread)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, weight_spread)
        nn.init.normal_(m.bias.data, 0.0, weight_spread)
    m = m.to(torch.float32)

clip_value =  5
class WeightConstraint(object):
    def __init__(self):
        pass
    def __call__(self, module):
        # filter the variables to get the ones you want
        if hasattr(module, 'weight'):
            w = module.weight.data
            w = w.clamp(-clip_value, clip_value)
            module.weight.data = w

# %%
# Set random seed for reproducibility
manualSeed = 499
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)

torch.use_deterministic_algorithms(True) # Needed for reproducible resultsStop playing
# Out:
# Random Seed:  499

# %%
def coord_to_heatmap(coord_array, image_shape, sigma_in, device):
    heatmaps = torch.zeros((NUM_LANDMARKS, image_shape[1], image_shape[2]))
    for i in range(NUM_LANDMARKS):
        mu_x, mu_y = coord_array[i][0], coord_array[i][1]   # center (x,y)
        sigma = sigma_in * model_image_size / image_size

        ys = torch.arange(image_shape[1], device=device, dtype=torch.float32)
        xs = torch.arange(image_shape[2], device=device, dtype=torch.float32)
        yy, xx = torch.meshgrid(ys, xs, indexing='ij')          # HxW each

        img = torch.exp(-0.5 * ((xx - mu_x)**2 + (yy - mu_y)**2) / (sigma**2))
        #img = torch.sqrt((xx - mu_x)**2 + (yy - mu_y)**2)
        # (optional) normalize to peak (1 / 1 + 1e-3)
        img = img / img.max()
        heatmaps[i] = img
    return heatmaps

# %%
SIGMA = 30
class FramesFromCSV(Dataset):
    def __init__(self, csv_path, images_dir, image_pattern="frame_{frame}.png", transform=None):
        """
        Args:
            csv_path: path to CSV file with header in first row
            images_dir: directory containing frame PNGs
            image_pattern: naming pattern for image files
            transform: optional torchvision transform
        """
        self.images_dir = images_dir
        self.image_pattern = image_pattern
        self.transform = transform

        # Load CSV into numpy array, skipping header
        self.data = np.loadtxt(csv_path, delimiter=",", skiprows=1)
        # Ensure it's 2D even if only one row
        if self.data.ndim == 1:
            self.data = np.expand_dims(self.data, axis=0)

        self.frame_numbers = self.data[:, 0].astype(int)
        self.points = self.data[:, 1:]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        frame_num = self.frame_numbers[idx]
        coords = self.points[idx]

        # Load image
        img_path = os.path.join(self.images_dir, self.image_pattern.format(frame=frame_num))
        image = Image.open(img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        # Reshape coords into N×2 array (x, y)
        coords = coords.reshape(-1, 2)
        coords_tensor = torch.tensor(coords, dtype=torch.float32)
        coords_tensor = coords_tensor * model_image_size/image_size

        return {
            "image": image,
            "points": coords_tensor,
            "heatmaps": coord_to_heatmap(coords_tensor, image.shape, SIGMA, "cpu"),
            "frame": frame_num
        }

# %%
dataset = FramesFromCSV(
    csv_path="plane_data/labeled_points_mega_grp.csv",
    images_dir="outp",
    image_pattern="frame_{frame}.png",
    transform=transforms.Compose([
                               transforms.Resize(model_image_size),
                               transforms.ToTensor(),
                           ])
)

# %%
print(dataset[11])
# Out:
# {'image': tensor([[[0.2471, 0.2471, 0.2471,  ..., 0.2588, 0.2588, 0.2588],
#          [0.2471, 0.2471, 0.2471,  ..., 0.2588, 0.2588, 0.2667],
#          [0.2471, 0.2471, 0.2471,  ..., 0.2588, 0.2588, 0.2588],
#          ...,
#          [0.2824, 0.2824, 0.2824,  ..., 0.3020, 0.3020, 0.3020],
#          [0.2824, 0.2824, 0.2824,  ..., 0.3020, 0.3020, 0.3020],
#          [0.2824, 0.2824, 0.2824,  ..., 0.2980, 0.2980, 0.2980]],
#
#         [[0.3765, 0.3765, 0.3765,  ..., 0.3725, 0.3725, 0.3686],
#          [0.3765, 0.3765, 0.3765,  ..., 0.3725, 0.3569, 0.3412],
#          [0.3765, 0.3765, 0.3765,  ..., 0.3725, 0.3725, 0.3686],
#          ...,
#          [0.4039, 0.4039, 0.4039,  ..., 0.4196, 0.4196, 0.4235],
#          [0.4039, 0.4039, 0.4039,  ..., 0.4196, 0.4196, 0.4235],
#          [0.4039, 0.4039, 0.4039,  ..., 0.4235, 0.4235, 0.4235]],
#
#         [[0.5373, 0.5373, 0.5373,  ..., 0.5569, 0.5686, 0.5922],
#          [0.5373, 0.5373, 0.5373,  ..., 0.5569, 0.6392, 0.7020],
#          [0.5373, 0.5373, 0.5373,  ..., 0.5569, 0.5686, 0.5882],
#          ...,
#          [0.5765, 0.5765, 0.5765,  ..., 0.5961, 0.5961, 0.5922],
#          [0.5765, 0.5765, 0.5765,  ..., 0.5961, 0.5961, 0.5922],
#          [0.5843, 0.5843, 0.5843,  ..., 0.5961, 0.5961, 0.5961]]]), 'points': tensor([[35.1605, 33.1852],
#         [18.1728, 34.9630],
#         [48.0000, 35.7531],
#         [32.1975, 35.9506],
#         [32.5926, 26.0741]]), 'heatmaps': tensor([[[3.5163e-15, 9.4349e-15, 2.4605e-14,  ..., 1.1534e-11,
#           5.4477e-12, 2.5009e-12],
#          [8.9189e-15, 2.3931e-14, 6.2409e-14,  ..., 2.9254e-11,
#           1.3818e-11, 6.3435e-12],
#          [2.1987e-14, 5.8996e-14, 1.5385e-13,  ..., 7.2118e-11,
#           3.4064e-11, 1.5638e-11],
#          ...,
#          [3.7307e-13, 1.0010e-12, 2.6105e-12,  ..., 1.2237e-09,
#           5.7799e-10, 2.6534e-10],
#          [1.6658e-13, 4.4696e-13, 1.1656e-12,  ..., 5.4637e-10,
#           2.5807e-10, 1.1848e-10],
#          [7.2289e-14, 1.9397e-13, 5.0584e-13,  ..., 2.3711e-10,
#           1.1200e-10, 5.1415e-11]],
#
#         [[2.5070e-10, 4.1468e-10, 6.6667e-10,  ..., 1.2576e-19,
#           3.6619e-20, 1.0363e-20],
#          [6.6890e-10, 1.1064e-09, 1.7788e-09,  ..., 3.3554e-19,
#           9.7704e-20, 2.7651e-20],
#          [1.7346e-09, 2.8692e-09, 4.6128e-09,  ..., 8.7015e-19,
#           2.5337e-19, 7.1705e-20],
#          ...,
#          [5.8346e-07, 9.6510e-07, 1.5516e-06,  ..., 2.9268e-16,
#           8.5224e-17, 2.4119e-17],
#          [2.7404e-07, 4.5330e-07, 7.2875e-07,  ..., 1.3747e-16,
#           4.0029e-17, 1.1328e-17],
#          [1.2510e-07, 2.0693e-07, 3.3268e-07,  ..., 6.2755e-17,
#           1.8273e-17, 5.1714e-18]],
#
#         [[7.0623e-23, 2.7314e-22, 1.0267e-21,  ..., 1.1245e-09,
#           7.6558e-10, 5.0660e-10],
#          [1.9272e-22, 7.4537e-22, 2.8019e-21,  ..., 3.0685e-09,
#           2.0892e-09, 1.3824e-09],
#          [5.1114e-22, 1.9769e-21, 7.4312e-21,  ..., 8.1385e-09,
#           5.5410e-09, 3.6666e-09],
#          ...,
#          [6.4845e-19, 2.5079e-18, 9.4274e-18,  ..., 1.0325e-05,
#           7.0294e-06, 4.6515e-06],
#          [3.1150e-19, 1.2048e-18, 4.5287e-18,  ..., 4.9597e-06,
#           3.3768e-06, 2.2345e-06],
#          [1.4544e-19, 5.6249e-19, 2.1144e-18,  ..., 2.3156e-06,
#           1.5766e-06, 1.0433e-06]],
#
#         [[3.9613e-15, 9.7691e-15, 2.3415e-14,  ..., 7.5589e-14,
#           3.2815e-14, 1.3846e-14],
#          [1.0871e-14, 2.6809e-14, 6.4257e-14,  ..., 2.0744e-13,
#           9.0053e-14, 3.7996e-14],
#          [2.8995e-14, 7.1505e-14, 1.7139e-13,  ..., 5.5328e-13,
#           2.4019e-13, 1.0134e-13],
#          ...,
#          [5.1261e-11, 1.2642e-10, 3.0300e-10,  ..., 9.7816e-10,
#           4.2464e-10, 1.7917e-10],
#          [2.4764e-11, 6.1070e-11, 1.4638e-10,  ..., 4.7254e-10,
#           2.0514e-10, 8.6554e-11],
#          [1.1627e-11, 2.8674e-11, 6.8727e-11,  ..., 2.2187e-10,
#           9.6317e-11, 4.0639e-11]],
#
#         [[1.6919e-11, 4.2197e-11, 1.0228e-10,  ..., 6.4127e-10,
#           2.8154e-10, 1.2013e-10],
#          [3.5048e-11, 8.7410e-11, 2.1188e-10,  ..., 1.3284e-09,
#           5.8320e-10, 2.4885e-10],
#          [7.0563e-11, 1.7598e-10, 4.2658e-10,  ..., 2.6744e-09,
#           1.1742e-09, 5.0102e-10],
#          ...,
#          [7.7529e-15, 1.9336e-14, 4.6870e-14,  ..., 2.9385e-13,
#           1.2901e-13, 5.5048e-14],
#          [2.8271e-15, 7.0508e-15, 1.7091e-14,  ..., 1.0715e-13,
#           4.7043e-14, 2.0074e-14],
#          [1.0020e-15, 2.4989e-15, 6.0574e-15,  ..., 3.7976e-14,
#           1.6673e-14, 7.1144e-15]]]), 'frame': 273}

# %%
IMG_IDX = 790
plt.imshow(torch.permute(dataset[IMG_IDX]['image'], (1, 2, 0)))
# Unpack points into two lists: xs, ys
xs = [p[0] for p in dataset[IMG_IDX]['points']]
ys = [p[1] for p in dataset[IMG_IDX]['points']]
# Plot points as red circles
plt.scatter(xs, ys, c='yellow', s=10)  # s = point size

# %%
print(torch.min(dataset[IMG_IDX]['heatmaps']), torch.max(dataset[IMG_IDX]['heatmaps']))
print(dataset[IMG_IDX]['heatmaps'].shape)
plt.imshow(dataset[IMG_IDX]['heatmaps'][0])
plt.colorbar()
# Out:
# tensor(4.2492e-22) tensor(1.)
# torch.Size([5, 64, 64])

# %%
print(torch.min(dataset[IMG_IDX]['heatmaps']), torch.max(dataset[IMG_IDX]['heatmaps']))
plt.imshow(torch.sum(dataset[IMG_IDX]['heatmaps'], axis=0))
plt.colorbar()
# Out:
# tensor(4.2492e-22) tensor(1.)

# %%
loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

for batch in loader:
    print(batch["frame"])
    print(batch["points"].shape)  # (B, N, 2)
    break
# Out:
# tensor([   0,    1,   29,   50,   63,   79,  103,  139,  181,  216,  248,  273,
#          296,  325,  347,  366,  378,  420,  441,  480,  521,  557,  620,  743,
#          831,  857,  879,  929, 1015, 1056, 1065, 1077, 1080, 1082, 1084, 1086,
#         1088, 1090, 1095, 1102, 1105, 1111, 1122, 1130, 1141, 1155, 1165, 1187,
#         1198, 1218, 1227, 1240, 1248, 1255, 1269, 1287, 1302, 1324, 1350, 1360,
#         1372, 1392, 1402, 1431, 1444, 1446, 1450, 1453, 1457, 1463, 1466, 1469,
#         1473, 1479, 1485, 1489, 1496, 1499, 1503, 1511, 1520, 1540, 1549, 1566,
#         1572, 1579, 1601, 1621, 1641, 1653, 1663, 1676, 1686, 1709, 1784, 1862,
#         1884, 1908, 1929, 1962, 2045, 2074, 2087, 2094, 2104, 2115, 2120, 2126,
#         2135, 2148, 2169, 2205, 2224, 2245, 2327, 2375, 2422, 2468, 2505, 2516,
#         2575, 2720, 2766, 2810, 2873, 2903, 2919, 2961, 3002, 3071, 3111, 3142,
#         3227, 3263, 3292, 3364, 3380, 3400, 3420, 3448, 3552, 3570, 3680, 3719,
#         3889, 3951, 4047, 4115, 4182, 4205, 4287, 4302, 4311, 4327, 4369, 4519,
#         4617, 4660, 4723, 4759, 4789, 4813, 4831, 4895, 5025, 5144, 5205, 5279,
#         5309, 5369, 5394, 5410, 5470, 5540, 5670, 5733, 5876, 5903, 5954, 6023,
#         6054, 6132, 6168, 6210, 6268, 6282, 6302, 6346, 6461, 6525, 6625, 6783,
#         6792, 6793, 6794, 6795, 6796, 6798, 6806, 6817, 6822, 6850, 6876, 6905,
#         6910, 6939, 6968, 7131, 7260, 7275, 7313, 7370, 7400, 7500, 7521, 7527,
#         7528, 7531, 7532, 7533, 7538, 7544, 7557, 7560, 7565, 7573, 7583, 7606,
#         7639, 7662, 7719, 7747, 7762, 7786, 7803, 7815, 7828, 7837, 7849, 7860,
#         7876, 7914, 7931, 7968, 8008, 8058, 8145, 8209, 8220, 8223, 8291, 8455,
#         8494, 8496, 8504, 8510])
# torch.Size([256, 5, 2])

# %%
trial_number = 0

from datetime import datetime
import time

# instantiate generator, discriminator
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

# if not os.path.exists(datapath+"/trial_"+str(trial_number)):
#     os.mkdir(datapath+"/trial_"+str(trial_number))

device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")
print("device: ", device)

#print("Instantiating ImgToHeatmap")
print("Instantiating UNet")
# Create the generator
#model = ImgToHeatmap().to(device, dtype=torch.float32)
model = UNet().to(device, dtype=torch.float32)
model.apply(weights_init)
print(model)

# Setup Adam optimizers for both G and D
optimizer = optim.Adam(model.parameters(), lr=0.0005, betas=(0.5, 0.999))
print("Model optimizer: \n", optimizer)

#criterion = nn.BCELoss()
criterion = nn.MSELoss()

clipper = WeightConstraint()
# Out:
# device:  cpu
# Instantiating UNet
# UNet(
#   (init_conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsize1): Down(
#     (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize2): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize3): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize4): Down(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (upsize4): Up(
#     (up): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize3): Up(
#     (up): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize2): Up(
#     (up): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize1): Up(
#     (up): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(8, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# Model optimizer:
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.5, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )

# %%
iters = 0
epoch = 0
num_epochs = 500
#k=500 # saving images of fixed_noise outputs
last_save = iters
break_flag = False

losses = []

example_idx = 110

# %%
# train the model
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

#train_D_only = False
#train_G_only = False
print("Starting Training Loop...")
while (epoch < num_epochs) and (not break_flag):
    # For each batch in the dataloader
    should_break = False
    
    for i, data in enumerate(loader, 0):
        print("Epoch\t"+str(epoch)+", batch\t"+str(i)+".", end="\n")
         # Check how the generator is doing by saving G's output on fixed_noise
        #if (epoch % k == 0) and (i == len(dataloader)-1):
        data_input = data['image']
        output = data['heatmaps']

        data_input = data_input.to(device, dtype=torch.float32)
        batch_size = data_input.size(0)
        print("Batch size: ", batch_size)
        print(data_input.dtype)

        # print(dataseq.shape)

        heatmap_predicted = model(data_input) # outputs logits

        model.zero_grad()

        y_err = 1
        # for i in range(NUM_LANDMARKS):
        #     print(torch.argmax(torch.reshape(output[0, i, :, :], (model_image_size*model_image_size,))))
        #print(data['points'])
        err = criterion(heatmap_predicted.flatten(), output.flatten())
        err.backward()

        optimizer.step()

        #time.sleep(1.00)

        print(f"\t BCE: {err.item()}")
        losses.append((epoch, i, iters, {"bce_error": err.item()},
                                        {"y_bce_error": y_err} ))

        iters += 1
    
        # if iters > 1000: # stop to quickly see results
        #     should_break = True
        #     break
    
    if should_break:
        break

    if (epoch+1) % 1 == 0:
        print(f"Saving results for example index {example_idx}")
        # output example output from model
        example_point = dataset[example_idx]
        image = torch.permute(example_point['image'], (1, 2, 0))
        plt.imshow(image.numpy())
        plt.savefig(f"{output_dir}/epoch{epoch}_in.png")
        plt.clf()

        input_example = example_point['image'].to(dtype=torch.float32)
        print(torch.min(input_example), torch.max(input_example))
        print(input_example.shape)
        heatmap_pred = model( torch.stack((input_example,)) ).detach()
        heatmap_actual = example_point['heatmaps']
        print(heatmap_pred.shape)
        for i in range(NUM_LANDMARKS):
            plt.imshow(heatmap_pred.numpy()[0][i], vmin=0, vmax=1)
            plt.colorbar()
            plt.savefig(f"{output_dir}/epoch{epoch}_out_{i}.png")
            plt.clf()
            plt.imshow(heatmap_actual.numpy()[i], vmin=0, vmax=1)
            plt.colorbar()
            plt.savefig(f"{output_dir}/epoch{epoch}_out_{i}_real.png")
            plt.clf()

    epoch += 1
    SIGMA = ((SIGMA - 4) * 0.997) + 4
# Out:
# Starting Training Loop...
# Epoch	0, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.18327245116233826
# Epoch	0, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.15190698206424713
# Epoch	0, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.13070423901081085
# Epoch	0, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.1119140237569809
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	1, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.09688369929790497
# Epoch	1, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.08393867313861847
# Epoch	1, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.07451501488685608
# Epoch	1, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.06485898792743683
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	2, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.05868322402238846
# Epoch	2, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.053036440163850784
# Epoch	2, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.05005815625190735
# Epoch	2, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.04618142172694206
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	3, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.044276267290115356
# Epoch	3, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.04174825921654701
# Epoch	3, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.04037664458155632
# Epoch	3, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.03857572004199028
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	4, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.037618935108184814
# Epoch	4, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.03622274100780487
# Epoch	4, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.03544851019978523
# Epoch	4, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.03445371985435486
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	5, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.03357889875769615
# Epoch	5, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.03291117399930954
# Epoch	5, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.032447244971990585
# Epoch	5, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.03187709301710129
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	6, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.031131859868764877
# Epoch	6, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.03077920340001583
# Epoch	6, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.030442725867033005
# Epoch	6, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.030054712668061256
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	7, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.029381712898612022
# Epoch	7, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.029190819710493088
# Epoch	7, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02887486293911934
# Epoch	7, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.028551865369081497
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	8, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.027952929958701134
# Epoch	8, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.027774741873145103
# Epoch	8, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02749701403081417
# Epoch	8, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.027185989543795586
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	9, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.026700129732489586
# Epoch	9, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.026515159755945206
# Epoch	9, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.026227885857224464
# Epoch	9, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.025894256308674812
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	10, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.025479143485426903
# Epoch	10, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02520315907895565
# Epoch	10, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.024981971830129623
# Epoch	10, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.024506336078047752
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	11, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02431672252714634
# Epoch	11, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.024357980117201805
# Epoch	11, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.023936962708830833
# Epoch	11, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.023502593860030174
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	12, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.023380063474178314
# Epoch	12, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02304260805249214
# Epoch	12, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.022622156888246536
# Epoch	12, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.02240830287337303
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	13, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.022055763751268387
# Epoch	13, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.021988220512866974
# Epoch	13, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02222861535847187
# Epoch	13, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.02162964828312397
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	14, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.021329578012228012
# Epoch	14, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02082870341837406
# Epoch	14, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.021451346576213837
# Epoch	14, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.020672621205449104
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	15, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02147541753947735
# Epoch	15, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.020992934703826904
# Epoch	15, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.020568212494254112
# Epoch	15, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.020017338916659355
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	16, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.021005406975746155
# Epoch	16, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0202315840870142
# Epoch	16, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.02020750381052494
# Epoch	16, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.020228233188390732
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	17, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.020014692097902298
# Epoch	17, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.019647208973765373
# Epoch	17, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.019242102280259132
# Epoch	17, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01889878138899803
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	18, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01914183422923088
# Epoch	18, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.018686829134821892
# Epoch	18, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.018625397235155106
# Epoch	18, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.018264614045619965
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	19, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.018493104726076126
# Epoch	19, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.018114667385816574
# Epoch	19, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.018050823360681534
# Epoch	19, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01769186742603779
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	20, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01789233461022377
# Epoch	20, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.017565499991178513
# Epoch	20, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.017937038093805313
# Epoch	20, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.017380138859152794
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	21, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.017697200179100037
# Epoch	21, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01724303886294365
# Epoch	21, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.017180243507027626
# Epoch	21, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01687224581837654
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	22, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.017141882330179214
# Epoch	22, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016853373497724533
# Epoch	22, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016912659630179405
# Epoch	22, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01658920757472515
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	23, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016796588897705078
# Epoch	23, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01650807447731495
# Epoch	23, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016498256474733353
# Epoch	23, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.016169937327504158
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	24, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016467001289129257
# Epoch	24, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016345493495464325
# Epoch	24, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016775552183389664
# Epoch	24, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.016194257885217667
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	25, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016606897115707397
# Epoch	25, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016102176159620285
# Epoch	25, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016189876943826675
# Epoch	25, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01583913341164589
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	26, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.016024550423026085
# Epoch	26, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015818318352103233
# Epoch	26, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015892233699560165
# Epoch	26, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.015490329824388027
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	27, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015913590788841248
# Epoch	27, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015521196648478508
# Epoch	27, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015682486817240715
# Epoch	27, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.015389525331556797
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	28, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01569201797246933
# Epoch	28, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01565450057387352
# Epoch	28, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01597645878791809
# Epoch	28, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.015374811366200447
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	29, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015683917328715324
# Epoch	29, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015328744426369667
# Epoch	29, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015510579571127892
# Epoch	29, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.015048573724925518
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	30, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015383700840175152
# Epoch	30, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01519046165049076
# Epoch	30, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01509304903447628
# Epoch	30, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.015083280391991138
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	31, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015478475019335747
# Epoch	31, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015112675726413727
# Epoch	31, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015002752654254436
# Epoch	31, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.014697766862809658
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	32, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015293106436729431
# Epoch	32, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015221035107970238
# Epoch	32, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.015008528716862202
# Epoch	32, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.014627092517912388
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	33, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014862127602100372
# Epoch	33, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014644433744251728
# Epoch	33, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014860780909657478
# Epoch	33, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01430025976151228
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	34, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01477327011525631
# Epoch	34, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014389894902706146
# Epoch	34, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01459222100675106
# Epoch	34, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.014154910109937191
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	35, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014506603591144085
# Epoch	35, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014264103956520557
# Epoch	35, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014332152903079987
# Epoch	35, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.013965451158583164
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	36, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014306792989373207
# Epoch	36, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01414894312620163
# Epoch	36, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014175432734191418
# Epoch	36, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.013781890273094177
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	37, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014068914577364922
# Epoch	37, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013952921144664288
# Epoch	37, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.014065990224480629
# Epoch	37, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01361340656876564
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	38, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013917389325797558
# Epoch	38, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01378698367625475
# Epoch	38, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01383280474692583
# Epoch	38, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01348301861435175
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	39, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013877622783184052
# Epoch	39, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013681326992809772
# Epoch	39, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013742832466959953
# Epoch	39, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.013350337743759155
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	40, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013537256047129631
# Epoch	40, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01348637044429779
# Epoch	40, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013479876331984997
# Epoch	40, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.013011153787374496
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	41, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013688066974282265
# Epoch	41, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01330786943435669
# Epoch	41, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013278260827064514
# Epoch	41, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.012653782963752747
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	42, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01310197077691555
# Epoch	42, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012909570708870888
# Epoch	42, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012949703261256218
# Epoch	42, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.012353741563856602
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	43, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012800398282706738
# Epoch	43, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013036203570663929
# Epoch	43, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013713938184082508
# Epoch	43, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.012821167707443237
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	44, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013172740116715431
# Epoch	44, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012779099866747856
# Epoch	44, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012880268506705761
# Epoch	44, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.012220561504364014
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	45, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01275969110429287
# Epoch	45, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012440922670066357
# Epoch	45, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012248454615473747
# Epoch	45, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.012225460261106491
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	46, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.013661041855812073
# Epoch	46, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01287887804210186
# Epoch	46, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012436764314770699
# Epoch	46, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.011889197863638401
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	47, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012113037519156933
# Epoch	47, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.012117179110646248
# Epoch	47, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01186500396579504
# Epoch	47, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.011123565025627613
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	48, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.011643989011645317
# Epoch	48, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.011382956057786942
# Epoch	48, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.011220205575227737
# Epoch	48, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.01071432139724493
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	49, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.011177916079759598
# Epoch	49, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.010847875848412514
# Epoch	49, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0108442148193717
# Epoch	49, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.010244528762996197
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	50, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.011240603402256966
# Epoch	50, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01151951216161251
# Epoch	50, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01108254212886095
# Epoch	50, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.010231423191726208
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	51, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.010702199302613735
# Epoch	51, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.010746508836746216
# Epoch	51, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.010564313270151615
# Epoch	51, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.009701604954898357
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	52, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.01023593544960022
# Epoch	52, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.010005730204284191
# Epoch	52, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009905792772769928
# Epoch	52, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00938838254660368
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	53, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009757978841662407
# Epoch	53, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009559953585267067
# Epoch	53, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00962966401129961
# Epoch	53, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.009070897474884987
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	54, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0095808831974864
# Epoch	54, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00931562576442957
# Epoch	54, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009241392835974693
# Epoch	54, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.008746223524212837
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	55, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009347288869321346
# Epoch	55, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009030182845890522
# Epoch	55, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009203052148222923
# Epoch	55, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.008469297550618649
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	56, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.009004347026348114
# Epoch	56, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008894023485481739
# Epoch	56, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0087365647777915
# Epoch	56, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00828067772090435
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	57, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008831359446048737
# Epoch	57, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008347900584340096
# Epoch	57, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008386628702282906
# Epoch	57, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.007960572838783264
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	58, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008400755934417248
# Epoch	58, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008318926207721233
# Epoch	58, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.008126841858029366
# Epoch	58, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0077471984550356865
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	59, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00825035385787487
# Epoch	59, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00798457395285368
# Epoch	59, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0080768633633852
# Epoch	59, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.007584210950881243
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	60, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007979799062013626
# Epoch	60, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007734606973826885
# Epoch	60, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007687896490097046
# Epoch	60, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.007291295565664768
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	61, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007916916161775589
# Epoch	61, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007660972885787487
# Epoch	61, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0075981346890330315
# Epoch	61, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.007145001087337732
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	62, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007593909744173288
# Epoch	62, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007378857582807541
# Epoch	62, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00739888334646821
# Epoch	62, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0070420000702142715
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	63, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0077456822618842125
# Epoch	63, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007326322142034769
# Epoch	63, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007212681230157614
# Epoch	63, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0068832202814519405
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	64, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007341120392084122
# Epoch	64, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007051551248878241
# Epoch	64, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007057614624500275
# Epoch	64, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.006694904528558254
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	65, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007231845520436764
# Epoch	65, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0069404779933393
# Epoch	65, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006886677350848913
# Epoch	65, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0065099080093204975
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	66, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.007086445577442646
# Epoch	66, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00683468347415328
# Epoch	66, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006722830235958099
# Epoch	66, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0064890095964074135
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	67, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006973083131015301
# Epoch	67, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0067681847140192986
# Epoch	67, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00669498136267066
# Epoch	67, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.006277174688875675
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	68, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006805206649005413
# Epoch	68, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006780167575925589
# Epoch	68, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006543098948895931
# Epoch	68, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.006252391263842583
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	69, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0065507129766047
# Epoch	69, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006355748511850834
# Epoch	69, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006359304301440716
# Epoch	69, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005996263585984707
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	70, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006603310815989971
# Epoch	70, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006369270384311676
# Epoch	70, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006317260675132275
# Epoch	70, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005943980999290943
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	71, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00633632019162178
# Epoch	71, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006160256452858448
# Epoch	71, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006217045243829489
# Epoch	71, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.006003975868225098
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	72, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006358960177749395
# Epoch	72, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006236547604203224
# Epoch	72, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006229198072105646
# Epoch	72, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005805687513202429
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	73, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006422229111194611
# Epoch	73, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0060488441959023476
# Epoch	73, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006163752172142267
# Epoch	73, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005828028079122305
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	74, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006235470063984394
# Epoch	74, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006030400283634663
# Epoch	74, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0060327742248773575
# Epoch	74, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005758274346590042
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	75, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0061339992098510265
# Epoch	75, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0059116436168551445
# Epoch	75, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0059839049354195595
# Epoch	75, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0056683216243982315
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	76, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.006035116035491228
# Epoch	76, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005835186690092087
# Epoch	76, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005801786202937365
# Epoch	76, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005576385650783777
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	77, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005881921853870153
# Epoch	77, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00574683491140604
# Epoch	77, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005757988430559635
# Epoch	77, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005508734378963709
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	78, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005788991693407297
# Epoch	78, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005672154948115349
# Epoch	78, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0056512486189603806
# Epoch	78, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00544453039765358
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	79, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005814696662127972
# Epoch	79, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005621789488941431
# Epoch	79, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005661866627633572
# Epoch	79, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005355209577828646
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	80, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005792046897113323
# Epoch	80, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005546054802834988
# Epoch	80, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00562225142493844
# Epoch	80, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00537191703915596
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	81, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0057158744893968105
# Epoch	81, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005499822087585926
# Epoch	81, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005536236334592104
# Epoch	81, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00530660804361105
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	82, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0056620710529387
# Epoch	82, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0054733543656766415
# Epoch	82, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0055520492605865
# Epoch	82, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005278849042952061
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	83, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0056160977110266685
# Epoch	83, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005539778154343367
# Epoch	83, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005496736615896225
# Epoch	83, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005279266741126776
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	84, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005670378915965557
# Epoch	84, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005429391749203205
# Epoch	84, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005467638373374939
# Epoch	84, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005226513370871544
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	85, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005534364841878414
# Epoch	85, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005471517331898212
# Epoch	85, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005384971387684345
# Epoch	85, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0051209405064582825
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	86, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005484338849782944
# Epoch	86, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005255787633359432
# Epoch	86, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005478319246321917
# Epoch	86, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005107550881803036
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	87, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005437435582280159
# Epoch	87, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005227932706475258
# Epoch	87, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005299671553075314
# Epoch	87, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.005031525157392025
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	88, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005366225726902485
# Epoch	88, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005152155179530382
# Epoch	88, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005188941955566406
# Epoch	88, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00490826740860939
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	89, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005221535451710224
# Epoch	89, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005056318826973438
# Epoch	89, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005054455250501633
# Epoch	89, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004945308435708284
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	90, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0050911810249090195
# Epoch	90, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005033569876104593
# Epoch	90, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005003381986171007
# Epoch	90, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004770045634359121
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	91, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005168437026441097
# Epoch	91, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00496821291744709
# Epoch	91, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004964071791619062
# Epoch	91, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004716227296739817
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	92, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.005065402947366238
# Epoch	92, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004831389524042606
# Epoch	92, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004934543743729591
# Epoch	92, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004665821325033903
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	93, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004977510776370764
# Epoch	93, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004762318916618824
# Epoch	93, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004749149549752474
# Epoch	93, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004597428720444441
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	94, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004854903556406498
# Epoch	94, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004782105330377817
# Epoch	94, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004718540236353874
# Epoch	94, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004542055074125528
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	95, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004775893874466419
# Epoch	95, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004701583180576563
# Epoch	95, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004661967512220144
# Epoch	95, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004425250459462404
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	96, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004746530205011368
# Epoch	96, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004640174098312855
# Epoch	96, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0046433755196630955
# Epoch	96, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004362485371530056
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	97, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00469980901107192
# Epoch	97, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004536519292742014
# Epoch	97, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004633433185517788
# Epoch	97, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004341519437730312
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	98, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004663538653403521
# Epoch	98, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004482096526771784
# Epoch	98, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004471446853131056
# Epoch	98, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0043335543014109135
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	99, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00455460837110877
# Epoch	99, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004439196083694696
# Epoch	99, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004385409876704216
# Epoch	99, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0041279979050159454
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	100, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0043829199858009815
# Epoch	100, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004274861421436071
# Epoch	100, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004313842859119177
# Epoch	100, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.004073901567608118
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	101, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004322728142142296
# Epoch	101, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004195283632725477
# Epoch	101, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004153127782046795
# Epoch	101, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.003939037676900625
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	102, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004208769649267197
# Epoch	102, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004190961364656687
# Epoch	102, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004201252944767475
# Epoch	102, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0038470139261335135
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	103, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004214718472212553
# Epoch	103, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004195897839963436
# Epoch	103, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0040452079847455025
# Epoch	103, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0038170989137142897
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	104, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.004075371660292149
# Epoch	104, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0039040446281433105
# Epoch	104, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003962819464504719
# Epoch	104, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.003684989409521222
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	105, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003981877584010363
# Epoch	105, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003919386304914951
# Epoch	105, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0038350094109773636
# Epoch	105, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0034972515422850847
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	106, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003958624321967363
# Epoch	106, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0037532143760472536
# Epoch	106, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003748105838894844
# Epoch	106, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0034428781364113092
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	107, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0035646806936711073
# Epoch	107, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0035541183315217495
# Epoch	107, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003398079425096512
# Epoch	107, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0031978951301425695
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	108, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0034733531065285206
# Epoch	108, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003390442579984665
# Epoch	108, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003359966678544879
# Epoch	108, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00317357387393713
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	109, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0033512127120047808
# Epoch	109, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0032027531415224075
# Epoch	109, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00327850878238678
# Epoch	109, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.002940655453130603
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	110, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003526587737724185
# Epoch	110, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0032872329466044903
# Epoch	110, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0031015281565487385
# Epoch	110, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0028597572818398476
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	111, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.003081803908571601
# Epoch	111, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0031672469340264797
# Epoch	111, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0031667803414165974
# Epoch	111, batch	3.
# Batch size:  147
# torch.float32
# ...
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	464, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001358505105599761
# Epoch	464, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001139284431701526
# Epoch	464, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001339500304311514
# Epoch	464, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.687856072559953e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	465, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013750560174230486
# Epoch	465, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011061249824706465
# Epoch	465, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011964509030804038
# Epoch	465, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.918008436216041e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	466, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011688021186273545
# Epoch	466, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010929412383120507
# Epoch	466, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011240020103286952
# Epoch	466, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.755847713677213e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	467, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012004499876638874
# Epoch	467, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010407813533674926
# Epoch	467, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011476765212137252
# Epoch	467, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.242266969522461e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	468, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011970174818998203
# Epoch	468, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010275568638462573
# Epoch	468, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011277598241576925
# Epoch	468, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.399791451869532e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	469, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001074376268661581
# Epoch	469, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001057714325725101
# Epoch	469, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010873639257624745
# Epoch	469, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.349612082587555e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	470, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011189479846507311
# Epoch	470, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 9.984102507587522e-05
# Epoch	470, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010793207911774516
# Epoch	470, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.271724411519244e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	471, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011065322905778885
# Epoch	471, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010077346814796329
# Epoch	471, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010798184666782618
# Epoch	471, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.583494102116674e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	472, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010479561751708388
# Epoch	472, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010854762513190508
# Epoch	472, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010268027835991234
# Epoch	472, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001003518991637975
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	473, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010333780664950609
# Epoch	473, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011107620957773179
# Epoch	473, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011022512626368552
# Epoch	473, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.557813609717414e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	474, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011575706594157964
# Epoch	474, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011257474398007616
# Epoch	474, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011121373245259747
# Epoch	474, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010134911281056702
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	475, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011296888260403648
# Epoch	475, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011904198618140072
# Epoch	475, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011062403063988313
# Epoch	475, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010385596397100016
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	476, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011875922791659832
# Epoch	476, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012282165698707104
# Epoch	476, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011571605136850849
# Epoch	476, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010699393897084519
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	477, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012583208444993943
# Epoch	477, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011668833758449182
# Epoch	477, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012073440302629024
# Epoch	477, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010729562200140208
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	478, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012144341599196196
# Epoch	478, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012391264317557216
# Epoch	478, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011414776236051694
# Epoch	478, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010894764272961766
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	479, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013007519009988755
# Epoch	479, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011859011283377185
# Epoch	479, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001273315428989008
# Epoch	479, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010099153587361798
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	480, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014560295676346868
# Epoch	480, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011069593165302649
# Epoch	480, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013859714090358466
# Epoch	480, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.385642624692991e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	481, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014894871856085956
# Epoch	481, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001044259624904953
# Epoch	481, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013939269410911947
# Epoch	481, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010154811752727255
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	482, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014752322749700397
# Epoch	482, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011413077299948782
# Epoch	482, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012510991655290127
# Epoch	482, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001288336206926033
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	483, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013520571519620717
# Epoch	483, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012787670129910111
# Epoch	483, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001271557848667726
# Epoch	483, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001322272582910955
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	484, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013786419003736228
# Epoch	484, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014892869512550533
# Epoch	484, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013214901264291257
# Epoch	484, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001257389085367322
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	485, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00015483629249501973
# Epoch	485, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001408662647008896
# Epoch	485, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013741428847424686
# Epoch	485, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00013008281530346721
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	486, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.000172400294104591
# Epoch	486, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013061979552730918
# Epoch	486, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012808406609110534
# Epoch	486, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001367029472021386
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	487, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001319250004598871
# Epoch	487, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014189505600370467
# Epoch	487, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001195485019707121
# Epoch	487, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001218174074892886
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	488, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012380287807900459
# Epoch	488, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013734784442931414
# Epoch	488, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011769119737436995
# Epoch	488, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001223758008563891
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	489, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013283154112286866
# Epoch	489, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001378776942146942
# Epoch	489, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012917544518131763
# Epoch	489, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00012062938913004473
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	490, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013058618060313165
# Epoch	490, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001387456723023206
# Epoch	490, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013051673886366189
# Epoch	490, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00011467466538306326
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	491, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00016854071873240173
# Epoch	491, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001275976246688515
# Epoch	491, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014946734881959856
# Epoch	491, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010195410141022876
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	492, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00018301050295121968
# Epoch	492, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011978604743489996
# Epoch	492, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.000143930155900307
# Epoch	492, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00011781636567320675
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	493, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014067787560634315
# Epoch	493, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012905018229503185
# Epoch	493, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012523533951025456
# Epoch	493, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00011844035179819912
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	494, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00014360657951328903
# Epoch	494, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012658578634727746
# Epoch	494, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013348960783332586
# Epoch	494, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010738329001469538
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	495, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001357445289613679
# Epoch	495, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011869143054354936
# Epoch	495, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012449068890418857
# Epoch	495, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.0001176292062154971
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	496, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011431930033722892
# Epoch	496, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012093858094885945
# Epoch	496, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012226701073814183
# Epoch	496, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010343380563426763
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	497, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00013767386553809047
# Epoch	497, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011798646301031113
# Epoch	497, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00012079181760782376
# Epoch	497, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 9.807926835492253e-05
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	498, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.0001189284012070857
# Epoch	498, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010933457815553993
# Epoch	498, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010726878099376336
# Epoch	498, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00010776754788821563
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])
# Epoch	499, batch	0.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010726795153459534
# Epoch	499, batch	1.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00011367999104550108
# Epoch	499, batch	2.
# Batch size:  256
# torch.float32
# 	 BCE: 0.00010549434227868915
# Epoch	499, batch	3.
# Batch size:  147
# torch.float32
# 	 BCE: 0.00011381893273210153
# Saving results for example index 110
# tensor(0.0235) tensor(0.8980)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])

# %%
num_epochs = 2000

# %%
losses
# Out:
# [(0, 0, 0, {'bce_error': 0.18327245116233826}, {'y_bce_error': 1}),
#  (0, 1, 1, {'bce_error': 0.15190698206424713}, {'y_bce_error': 1}),
#  (0, 2, 2, {'bce_error': 0.13070423901081085}, {'y_bce_error': 1}),
#  (0, 3, 3, {'bce_error': 0.1119140237569809}, {'y_bce_error': 1}),
#  (1, 0, 4, {'bce_error': 0.09688369929790497}, {'y_bce_error': 1}),
#  (1, 1, 5, {'bce_error': 0.08393867313861847}, {'y_bce_error': 1}),
#  (1, 2, 6, {'bce_error': 0.07451501488685608}, {'y_bce_error': 1}),
#  (1, 3, 7, {'bce_error': 0.06485898792743683}, {'y_bce_error': 1}),
#  (2, 0, 8, {'bce_error': 0.05868322402238846}, {'y_bce_error': 1}),
#  (2, 1, 9, {'bce_error': 0.053036440163850784}, {'y_bce_error': 1}),
#  (2, 2, 10, {'bce_error': 0.05005815625190735}, {'y_bce_error': 1}),
#  (2, 3, 11, {'bce_error': 0.04618142172694206}, {'y_bce_error': 1}),
#  (3, 0, 12, {'bce_error': 0.044276267290115356}, {'y_bce_error': 1}),
#  (3, 1, 13, {'bce_error': 0.04174825921654701}, {'y_bce_error': 1}),
#  (3, 2, 14, {'bce_error': 0.04037664458155632}, {'y_bce_error': 1}),
#  (3, 3, 15, {'bce_error': 0.03857572004199028}, {'y_bce_error': 1}),
#  (4, 0, 16, {'bce_error': 0.037618935108184814}, {'y_bce_error': 1}),
#  (4, 1, 17, {'bce_error': 0.03622274100780487}, {'y_bce_error': 1}),
#  (245, 3, 983, {'bce_error': 0.0002368968998780474}, {'y_bce_error': 1}),
#  (246, 0, 984, {'bce_error': 0.00026767930830828846}, {'y_bce_error': 1}),
#  (246, 1, 985, {'bce_error': 0.000257092498941347}, {'y_bce_error': 1}),
#  (246, 2, 986, {'bce_error': 0.0002556026738602668}, {'y_bce_error': 1}),
#  (246, 3, 987, {'bce_error': 0.00023252870596479625}, {'y_bce_error': 1}),
#  (247, 0, 988, {'bce_error': 0.000256550672929734}, {'y_bce_error': 1}),
#  (247, 1, 989, {'bce_error': 0.0002488369063939899}, {'y_bce_error': 1}),
#  (247, 2, 990, {'bce_error': 0.00024644689983688295}, {'y_bce_error': 1}),
#  (247, 3, 991, {'bce_error': 0.00023081536346580833}, {'y_bce_error': 1}),
#  (248, 0, 992, {'bce_error': 0.00024801029940135777}, {'y_bce_error': 1}),
#  (248, 1, 993, {'bce_error': 0.00025112746516242623}, {'y_bce_error': 1}),
#  (248, 2, 994, {'bce_error': 0.00024376246437896043}, {'y_bce_error': 1}),
#  (248, 3, 995, {'bce_error': 0.00022509483096655458}, {'y_bce_error': 1}),
#  (249, 0, 996, {'bce_error': 0.0002545309253036976}, {'y_bce_error': 1}),
#  (249, 1, 997, {'bce_error': 0.000243334608967416}, {'y_bce_error': 1}),
#  (249, 2, 998, {'bce_error': 0.0002467149752192199}, {'y_bce_error': 1}),
#  (249, 3, 999, {'bce_error': 0.0002226825017714873}, {'y_bce_error': 1}),
#  ...]

# %%
losses[0]
# Out:
# (0, 0, 0, {'bce_error': 0.18327245116233826}, {'y_bce_error': 1})

# %%
import math
plt.plot([x[2] for x in losses], [math.log(x[3]["bce_error"], 10) for x in losses])
plt.xlabel("Iterations")
plt.ylabel("Log loss")
# Out:
# Text(0, 0.5, 'Log loss')

# %%
losses[-1][3]["bce_error"]
# Out:
# 0.00011381893273210153

# %%
torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': losses,
            }, f"{output_dir}/info_model_082525_500.pt")

# %%
model.eval()
# Out:
# UNet(
#   (init_conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsize1): Down(
#     (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize2): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize3): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize4): Down(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (upsize4): Up(
#     (up): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize3): Up(
#     (up): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize2): Up(
#     (up): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize1): Up(
#     (up): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(8, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
model_dict = torch.load(f"{output_dir}/info_model_082525_flattenerr.pt", weights_only=True)
model_dict['loss'][-1]
# Out:
# /Users/ishwar/anaconda3/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# (143, 4, 1148, {'bce_error': 0.0008947026217356324}, {'y_bce_error': 1})

# %%
model_loaded = UNet()
model_loaded.load_state_dict(model_dict['model_state_dict'])
model_loaded.eval()
model_loaded
# Out:
# UNet(
#   (init_conv): Conv2d(3, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsize1): Down(
#     (conv): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(4, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize2): Down(
#     (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize3): Down(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (downsize4): Down(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation0): ReLU(inplace=True)
#     (down): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#   )
#   (upsize4): Up(
#     (up): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize3): Up(
#     (up): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize2): Up(
#     (up): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (upsize1): Up(
#     (up): ConvTranspose2d(8, 4, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batch_norm): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace=True)
#     (conv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batch_norm1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation1): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(4, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
example_point = dataset[590]
image = torch.permute(example_point['image'], (1, 2, 0))
plt.imshow(image.numpy())

# %%
input_example = example_point['image'].to(dtype=torch.float32)
print(torch.min(input_example), torch.max(input_example))
print(input_example.shape)
heatmap_pred = model( torch.stack((input_example,)) ).detach()
print(heatmap_pred.shape)
plt.imshow(heatmap_pred.numpy()[0][1], vmin=0)
plt.colorbar()
# Out:
# tensor(0.0235) tensor(0.9608)
# torch.Size([3, 64, 64])
# torch.Size([1, 5, 64, 64])

# %%
plt.imshow(torch.sum(heatmap_pred[0], dim=0).numpy(), vmin=0)
plt.colorbar()

# %%
plt.hist((heatmap_pred - example_point['heatmaps']).detach().numpy().flatten(), bins=100)
# Out:
# (array([3.0000e+00, 5.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00,
#         2.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
plt.imshow(np.sum(example_point['heatmaps'].numpy(), axis=0), vmin=0, vmax=1)

# %%
latent_logits_softmax_entropy = torch.mean(-latent_logits_softmax * torch.log(latent_logits_softmax), axis=1)
latent_tr = latent_logits_softmax_entropy
print(latent_tr.shape)
#print(latent_tr)
latent_img = latent_tr
plt.imshow(latent_img.numpy()[0])
plt.colorbar()
# Out:
# torch.Size([1, 128, 128])

# %%
latent_tr = torch.permute(latent_example, (0, 2, 3, 1))
#print(latent_tr.shape)
#print(latent_tr)
latent_img = torch.matmul(latent_tr, colormap_matrix.T).to(torch.int)
plt.imshow(latent_img.numpy()[0])

# %%
output_example = dec(latent_example).detach()
output_tr = torch.permute(output_example, (0, 2, 3, 1))
plt.imshow((output_tr.numpy()[0]/2)+0.5)

# %%
# Step 1: Get the predicted class index for each sample
# torch.argmax returns the index of the maximum value along the specified dimension.
# dim=-1 indicates the last dimension (which represents the classes).
predicted_classes = torch.argmax(torch.permute(latent_logits_softmax, (0, 2, 3, 1)), dim=-1).detach()

# Step 2: Convert the class indices to one-hot vectors
# num_classes should be the total number of possible classes.
num_classes = latent_logits.shape[-3]
z_hard = torch.permute(F.one_hot(predicted_classes, num_classes=num_classes), (0, 3, 1, 2)).to(dtype=torch.float32)

latent_tr = torch.permute(z_hard, (0, 2, 3, 1)).to(dtype=torch.float32)
latent_img = torch.matmul(latent_tr, colormap_matrix.T).to(torch.int)
plt.imshow(latent_img.numpy()[0])

# %%
output_example = dec(z_hard).detach()
output_tr = torch.permute(output_example, (0, 2, 3, 1))
plt.imshow((output_tr.numpy()[0]/3)+0.5)

# %%
import math
# {"mse_error": err.item(), "total_var": err_tv.item(), "determinism:": err_det.item()},
plt.plot([x[2] for x in losses], [math.log(x[3]["mse_error"])/math.log(10) for x in losses], label="log mse")
plt.plot([x[2] for x in losses], [math.log(x[3]["total_var"])/math.log(10) for x in losses], label="log total var")
plt.plot([x[2] for x in losses], [math.log(x[3]["determinism:"])/math.log(10) for x in losses], label="log determinism")
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("Log loss")
plt.figure(dpi=300) # Set DPI to 300 for this figure
plt.show()

# %% [markdown]
# # Read in data

# %%
datapath = "/Users/ishwar/Desktop/Music_DL/other/onehotzig_randstart_dataset/"
filelist_fname = "onehotzig_dataset_files.txt"

filelist = []

f = open(datapath+filelist_fname, "r")
fnames = f.readlines()
f.close()
for i in range(0, len(fnames)):
    fn = fnames[i]
    fn = fn.strip('\n')
    print(i, fn)
    filelist.append(fn)

print(len(filelist))
# Out:
# 0 sample_0.pt
# 1 sample_1.pt
# 2 sample_2.pt
# 3 sample_3.pt
# 4 sample_4.pt
# 5 sample_5.pt
# 6 sample_6.pt
# 7 sample_7.pt
# 8 sample_8.pt
# 9 sample_9.pt
# 10 sample_10.pt
# 11 sample_11.pt
# 12 sample_12.pt
# 13 sample_13.pt
# 14 sample_14.pt
# 15 sample_15.pt
# 16 sample_16.pt
# 17 sample_17.pt
# 18 sample_18.pt
# 19 sample_19.pt
# 20 sample_20.pt
# 21 sample_21.pt
# 22 sample_22.pt
# 23 sample_23.pt
# 24 sample_24.pt
# 25 sample_25.pt
# 26 sample_26.pt
# 27 sample_27.pt
# 28 sample_28.pt
# 29 sample_29.pt
# 30 sample_30.pt
# 31 sample_31.pt
# 32 sample_32.pt
# 33 sample_33.pt
# 34 sample_34.pt
# 35 sample_35.pt
# 36 sample_36.pt
# 37 sample_37.pt
# 38 sample_38.pt
# 39 sample_39.pt
# 40 sample_40.pt
# 41 sample_41.pt
# 42 sample_42.pt
# 43 sample_43.pt
# 44 sample_44.pt
# 45 sample_45.pt
# 46 sample_46.pt
# 47 sample_47.pt
# 48 sample_48.pt
# 49 sample_49.pt
# 50 sample_50.pt
# 51 sample_51.pt
# 52 sample_52.pt
# 53 sample_53.pt
# 54 sample_54.pt
# 55 sample_55.pt
# 56 sample_56.pt
# 57 sample_57.pt
# 58 sample_58.pt
# 59 sample_59.pt
# 60 sample_60.pt
# 61 sample_61.pt
# 62 sample_62.pt
# 63 sample_63.pt
# 64 sample_64.pt
# 65 sample_65.pt
# 66 sample_66.pt
# 67 sample_67.pt
# 68 sample_68.pt
# 69 sample_69.pt
# 70 sample_70.pt
# 71 sample_71.pt
# 72 sample_72.pt
# 73 sample_73.pt
# 74 sample_74.pt
# 75 sample_75.pt
# 76 sample_76.pt
# 77 sample_77.pt
# 78 sample_78.pt
# 79 sample_79.pt
# 80 sample_80.pt
# 81 sample_81.pt
# 82 sample_82.pt
# 83 sample_83.pt
# 84 sample_84.pt
# 85 sample_85.pt
# 86 sample_86.pt
# 87 sample_87.pt
# 88 sample_88.pt
# 89 sample_89.pt
# 90 sample_90.pt
# 91 sample_91.pt
# 92 sample_92.pt
# 93 sample_93.pt
# 94 sample_94.pt
# 95 sample_95.pt
# 96 sample_96.pt
# 97 sample_97.pt
# 98 sample_98.pt
# 99 sample_99.pt
# 100 sample_100.pt
# 101 sample_101.pt
# 102 sample_102.pt
# 103 sample_103.pt
# 104 sample_104.pt
# 105 sample_105.pt
# 106 sample_106.pt
# 107 sample_107.pt
# 108 sample_108.pt
# 109 sample_109.pt
# 110 sample_110.pt
# 111 sample_111.pt
# 112 sample_112.pt
# 113 sample_113.pt
# 114 sample_114.pt
# 115 sample_115.pt
# 116 sample_116.pt
# 117 sample_117.pt
# 118 sample_118.pt
# 119 sample_119.pt
# 120 sample_120.pt
# 121 sample_121.pt
# 122 sample_122.pt
# 123 sample_123.pt
# 124 sample_124.pt
# 125 sample_125.pt
# 126 sample_126.pt
# 127 sample_127.pt
# 128

# %%
trainfilelist = filelist[:64]
testfilelist = filelist[64:]

# %%
# read in sequence set + find MIN AND MAX AND MEAN AND STD Statistics

trainSequenceSet = []

TOTAL_LENGTH = 0

for fname in trainfilelist:
    sequence = torch.load(datapath+fname).to(torch.float32)
    print("type:",sequence.dtype)
    trainSequenceSet.append(sequence)

    TOTAL_LENGTH += sequence.shape[0]

print("TOTAL LENGTH:", TOTAL_LENGTH)

COMPWISE_MIN = None
COMPWISE_MAX = None
COMPWISE_MEAN = None
COMPWISE_MEAN_SQUARED = None

firstElement = True

for i in range(0, len(trainSequenceSet)):
    sequence = trainSequenceSet[i]
    print(sequence.shape[0])
    
    if firstElement:
        COMPWISE_MIN = torch.ones(sequence.shape[1:]) * 1e9
        COMPWISE_MAX = torch.ones(sequence.shape[1:]) * -1e9
        COMPWISE_MEAN = torch.zeros(sequence.shape[1:])
        COMPWISE_MEAN_SQUARED = torch.zeros(sequence.shape[1:])
        firstElement = False
    COMPWISE_MIN = torch.minimum(COMPWISE_MIN, torch.min(sequence, 0).values)
    COMPWISE_MAX = torch.maximum(COMPWISE_MAX, torch.max(sequence, 0).values)
    COMPWISE_MEAN += torch.mean(sequence, 0) * sequence.shape[0] / TOTAL_LENGTH
    COMPWISE_MEAN_SQUARED += torch.mean(torch.square(sequence), 0) * sequence.shape[0] / TOTAL_LENGTH
# Out:
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# TOTAL LENGTH: 8049
# 123
# 130
# 129
# 129
# 124
# 127
# 123
# 125
# 124
# 126
# 122
# 126
# 128
# 125
# 128
# 123
# 126
# 122
# 125
# 130
# 125
# 124
# 127
# 124
# 123
# 130
# 129
# 127
# 124
# 129
# 129
# 122
# 122
# 125
# 123
# 125
# 128
# 126
# 130
# 127
# 122
# 124
# 129
# 123
# 128
# 130
# 124
# 125
# 125
# 123
# 122
# 125
# 122
# 130
# 126
# 124
# 125
# 129
# 127
# 129
# 123
# 122
# 128
# 130

# %% [markdown]
# # Define model details

# %%
class Prnt(nn.Module):
    def __init__(self):
        super(Prnt, self).__init__()

    def forward(self, x):
        print(x)
        return x

class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()
        
        self.modules = []

        self.vectorDim = 6
        self.stateDim = 3

        self.internal = 8
        self.layers = 2

        # cumulatively, take 4-dim vector and output 4-dim vector
        # first two dims: actual vector
        # second two dims: state vector

        self.modules.append(nn.Linear(self.vectorDim + self.stateDim, self.internal, bias=False))
        self.modules.append(nn.LayerNorm(self.internal)) #1
        self.modules.append(nn.ReLU())
        for _ in range(self.layers):
            self.modules.append(nn.Linear(self.internal, self.internal, bias=False))
            self.modules.append(nn.LayerNorm(self.internal)) #4
            self.modules.append(nn.ReLU())
        self.modules.append(nn.Linear(self.internal, self.vectorDim + self.stateDim, bias=True))
        #self.modules.append(nn.Tanh())
        #self.modules.append(nn.LayerNorm(self.vectorDim + self.stateDim)) #10
        
        self.main = nn.Sequential(*self.modules)

        # consider BatchNorm modules.append(nn.BatchNorm2d(n_featmp_g[i]))
        # consider activation function at endpoint

    def forward(self, inputseq):
        # inputseq is a single list of vectors (or a batch of lists??)
        # output a single list of vectors (or a batch??)
        #print(inputseq.shape)
        
        batch_size = inputseq.shape[0]
        inputseqtr = torch.permute(inputseq, (1,0,2))
        states = []
        states.append(torch.zeros(batch_size, self.stateDim))
        outputseqtr = []
        outputseqtr.append(inputseqtr[0])
        # add a 0 vector beforehand so that the output generates itself
        # without having to feed an initial condition
         # do this in the data itself instead .. much faster

        #print("Output sequence transposed list", outputseqtr[0].grad_fn)
        for i in range(0, inputseqtr.shape[0]-1):
            input = inputseqtr[i].clone()
            output, outstate = self.forwardHelper(input, states[i])
            outputseqtr.append(output)
            states.append(outstate)
        
        outputseq = torch.permute(torch.stack(outputseqtr), (1,0,2))
        #print(outputseq.grad_fn)
        
        return outputseq
    
    # this should return the output and the next state
    def forwardHelper(self, input, state):
        concat_input_state = torch.cat((input, state), 1).clone()
        forward_input_state = self.main(concat_input_state).clone()
        outstate = forward_input_state[:, self.vectorDim:]
        output = forward_input_state[:, :self.vectorDim]
        return output, outstate

    def forwardAutoreg(self, inputseq, gen_length): # this time, inputseq is just the initial inputs
        # inputseq is a single list of vectors (or a batch of lists??)
        # output a single list of vectors (or a batch??)
        #print(inputseq.shape)

        batch_size = inputseq.shape[0]
        start_length = inputseq.shape[1]
        inputseqtr = torch.permute(inputseq, (1,0,2))
        states = []
        states.append(torch.zeros(batch_size, self.stateDim))
        outputseqtr = []
        outputseqtr.append(inputseqtr[0])
        # add a 0 vector beforehand so that the output generates itself
        # without having to feed an initial condition
         # do this in the data itself instead .. much faster
        
        for i in range(0, gen_length-1):
            input = outputseqtr[i].clone()
            output, outstate = self.forwardHelper(input, states[i])
            if i < start_length-1:
                outputseqtr.append(inputseqtr[i+1])
            else:
                outputseqtr.append(output)
            states.append(outstate)
        
        outputseq = torch.permute(torch.stack(outputseqtr), (1,0,2))
        #print(outputseq.grad_fn)
        
        return outputseq
    
    def __str__(self):
        ret = super().__str__()+"\n"
        ret += f"sequence vector dimension: {self.vectorDim}\n"
        ret += f"state vector dimension: {self.stateDim}\n"
        return ret

# %%
class SeqLoss(nn.Module):
    def __init__(self):
        super(SeqLoss, self).__init__()
        self.underlyingLoss = nn.MSELoss(reduction='sum')

    def forward(self, inputs, targets, lengthsInBatch):
        # input and target are 3-dim tensor (1: batch, 2:time, 3:dim), but each batch is of different effective length
        #print("Batch lengths:", lengthsInBatch)
        #print(lengthsInBatch.shape)
        # print(inputs.grad_fn)
        summedLoss = torch.Tensor(0)
        summedLoss.requires_grad_()
        #for i in range(0, len(inputs)):
        #    print(i)
        #    print(inputs[i,0:lengthsInBatch[i].item()].grad_fn)
        #    print(targets[i,0:lengthsInBatch[i].item()].grad_fn)
        elementLosses = [self.underlyingLoss(inputs[i,0:lengthsInBatch[i].item()], targets[i,0:lengthsInBatch[i].item()]) for i in range(0, len(lengthsInBatch))] # sum of errors in relevant inputs
        #print(elementLosses)
        summedLoss = sum(elementLosses)
        if summedLoss.grad_fn == None:
            raise Exception("No grad")
        else:
            # print(summedLoss.grad_fn)
            pass
        totalSamples = sum([lengthsInBatch[i].item() for i in range(0, len(lengthsInBatch))])
        print("Mean loss:", summedLoss, "/ (", totalSamples, "*", inputs.shape[2], ")")
        return summedLoss / (totalSamples*inputs.shape[2])

# %%
x = torch.zeros(2,)[:1]
print(x)
# Out:
# tensor([0.])

# %%
weight_spread = 0.05
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Linear') != -1:
        #nn.init.normal_(m.weight.data, 0.0, 1/16) # not tried yet
        nn.init.normal_(m.weight.data, 0.0, weight_spread)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, weight_spread)
        nn.init.normal_(m.bias.data, 0.0, weight_spread)
    m = m.to(torch.float32)

clip_value =  5
class WeightConstraint(object):
    def __init__(self):
        pass
    def __call__(self, module):
        # filter the variables to get the ones you want
        if hasattr(module, 'weight'):
            w = module.weight.data
            w = w.clamp(-clip_value, clip_value)
            module.weight.data = w

# %%
class StandardizeMinMax(nn.Module):
    def __init__(self, min, max):
        super(StandardizeMinMax, self).__init__()
        self.min = min
        self.max = max
    def forward(self, inputs):
        return 2 * ((inputs - self.min) / (self.max - self.min)) - 1

# %%
class StandardizeMeanSTD(nn.Module):
    def __init__(self, mean, std):
        super(StandardizeMeanSTD, self).__init__()
        self.mean = mean
        self.std = std
    def forward(self, inputs):
        return (inputs - self.mean) / self.std

# %%
# create dataset object

# adapted from https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
class SeqDataSet(Dataset):
    def __init__(self, sequenceSet, transform=None):
        self.sequenceSet = sequenceSet # should be a numpy array
        self.transform = transform

    def __len__(self):
        return len(self.sequenceSet)

    def __getitem__(self, index):
        # return (len(self.sequenceSet[index]), torch.stack(self.sequenceSet[index]))
        seq = self.sequenceSet[index]
        if transform != None:
            seqNorm = self.transform(seq)
        else:
            seqNorm = seq
        return (len(self.sequenceSet[index]), seqNorm)

padSeq = lambda seq, toLength: torch.nn.ConstantPad2d((0, 0, 0, toLength-len(seq)), 0)(seq)
def collate_fn(batchList):
    lengths = [b[0] for b in batchList]
    #print(lengths)
    maxLength = max(lengths)
    stackSeq = torch.stack([padSeq(b[1], maxLength) for b in batchList])
    return (torch.Tensor(lengths).to(dtype=torch.int32), stackSeq)

# %%
# instantiate generator, discriminator
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

# Set random seed for reproducibility
# manualSeed = 400
# #manualSeed = random.randint(1, 10000) # use if you want new results
# print("Random Seed: ", manualSeed)
# random.seed(manualSeed)
# torch.manual_seed(manualSeed)

# %% [markdown]
# # Continue from here to start the experiment

# %%
# MIN AND MAX Statistics
print("Min = ",COMPWISE_MIN)
print("Max = ",COMPWISE_MAX)
standardizeMM = StandardizeMinMax(COMPWISE_MIN, COMPWISE_MAX)
# Out:
# Min =  tensor([-0.1809, -0.1938, -0.1942, -0.1698, -0.1960, -0.1630])
# Max =  tensor([1.1391, 1.2139, 1.1676, 1.1301, 1.1516, 1.1841])

# %%
print("Mean = ",COMPWISE_MEAN)
COMPWISE_VAR = COMPWISE_MEAN_SQUARED - COMPWISE_MEAN**2
print("Variance = ",COMPWISE_VAR )
print("Standard dev = ",torch.sqrt(COMPWISE_VAR) )
standardizeMeanSTD = StandardizeMeanSTD(COMPWISE_MEAN, torch.sqrt(COMPWISE_VAR))
# Out:
# Mean =  tensor([0.0978, 0.0996, 0.1009, 0.1006, 0.1006, 0.1016])
# Variance =  tensor([0.0913, 0.0922, 0.0922, 0.0928, 0.0939, 0.0944])
# Standard dev =  tensor([0.3021, 0.3036, 0.3037, 0.3046, 0.3064, 0.3073])

# %%
# Set random seed for reproducibility
manualSeed = 499
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)

# make a dataset and a dataloader
trainseqdset = SeqDataSet(trainSequenceSet, transform=standardizeMM)
print(trainseqdset)

dataloader_batch_size = 8
trainseqdloader = torch.utils.data.DataLoader(trainseqdset, batch_size=dataloader_batch_size, shuffle=True, collate_fn=collate_fn)
print(trainseqdloader)

torch.use_deterministic_algorithms(True) # Needed for reproducible resultsStop playing
# Out:
# Random Seed:  499
# <__main__.SeqDataSet object at 0x1544272e0>
# <torch.utils.data.dataloader.DataLoader object at 0x1544270a0>

# %%
trial_number = 4

from datetime import datetime
import time

# instantiate generator, discriminator
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

if not os.path.exists(datapath+"/trial_"+str(trial_number)):
    os.mkdir(datapath+"/trial_"+str(trial_number))

device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")
print("device: ", device)

print("Instantiating RNN")
# Create the generator
rnn = RNN().to(device, dtype=torch.float32)
# initialize weights here !!!
rnn.apply(weights_init)
print(rnn)

# Setup Adam optimizers for both G and D
optimizerRNN = optim.Adam(rnn.parameters(), lr=0.0005, betas=(0.5, 0.999))
print(optimizerRNN)

criterion = SeqLoss()

clipper = WeightConstraint()
# Out:
# device:  cpu
# Instantiating RNN
# RNN(
#   (main): Sequential(
#     (0): Linear(in_features=9, out_features=8, bias=False)
#     (1): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=8, out_features=8, bias=False)
#     (4): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=8, out_features=8, bias=False)
#     (7): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=8, out_features=9, bias=True)
#   )
# )
# sequence vector dimension: 6
# state vector dimension: 3
#
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.5, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )

# %%
iters = 0
epoch = 0
num_epochs = 500
#k=500 # saving images of fixed_noise outputs
last_save = iters
break_flag = False

rnn_losses = []

# %%
# train the model
# borrowed from https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

#train_D_only = False
#train_G_only = False
print("Starting Training Loop...")
while (epoch < num_epochs) and (not break_flag):
    # For each batch in the dataloader
    for i, data in enumerate(trainseqdloader, 0):
        print("Epoch\t"+str(epoch)+", batch\t"+str(i)+".", end="\n")
         # Check how the generator is doing by saving G's output on fixed_noise
        #if (epoch % k == 0) and (i == len(dataloader)-1):

        dataseq = data[1].to(device, dtype=torch.float32)
        batch_size = dataseq.size(0)
        print(data[0])

        # print(dataseq.shape)

        outputseq = rnn(dataseq)

        rnn.zero_grad()

        errRNN = criterion(outputseq, dataseq, data[0])
        errRNN.backward()

        optimizerRNN.step()
        # rnn.apply(clipper)

        #time.sleep(1.00)

        ratio_sds = torch.std(outputseq, dim=2) / torch.std(dataseq, dim=2)
        #print(f"{torch.std(outputseq, dim=2)} / {torch.std(dataseq, dim=2)}")
        print("Ratio of stds between input and output:", torch.mean(ratio_sds).item(), "\t", ratio_sds.shape)
        
        print(f"Mean loss (per pixel): {errRNN.item()}")
        rnn_losses.append((epoch, i, iters, errRNN.item()))

        iters += 1
    
    epoch += 1
# Out:
# Starting Training Loop...
# Epoch	0, batch	0.
# tensor([123, 122, 129, 125, 122, 124, 125, 123], dtype=torch.int32)
# Mean loss: tensor(2997.4263, grad_fn=<AddBackward0>) / ( 993 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.5030927062034607
# Epoch	0, batch	1.
# tensor([125, 129, 130, 123, 130, 122, 127, 125], dtype=torch.int32)
# Mean loss: tensor(3005.2729, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4954290986061096
# Epoch	0, batch	2.
# tensor([127, 130, 126, 127, 130, 124, 129, 122], dtype=torch.int32)
# Mean loss: tensor(2973.3220, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.48823022842407227
# Epoch	0, batch	3.
# tensor([122, 123, 126, 128, 130, 124, 125, 128], dtype=torch.int32)
# Mean loss: tensor(2912.1589, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4824650287628174
# Epoch	0, batch	4.
# tensor([129, 123, 128, 130, 125, 129, 122, 127], dtype=torch.int32)
# Mean loss: tensor(2894.8271, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4762795567512512
# Epoch	0, batch	5.
# tensor([126, 123, 129, 124, 128, 122, 126, 125], dtype=torch.int32)
# Mean loss: tensor(2838.5217, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.4716719388961792
# Epoch	0, batch	6.
# tensor([127, 123, 122, 124, 129, 130, 124, 125], dtype=torch.int32)
# Mean loss: tensor(2797.7131, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.46442779898643494
# Epoch	0, batch	7.
# tensor([123, 125, 126, 124, 129, 128, 124, 125], dtype=torch.int32)
# Mean loss: tensor(2784.4517, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.46222636103630066
# Epoch	1, batch	0.
# tensor([124, 124, 125, 125, 122, 124, 127, 126], dtype=torch.int32)
# Mean loss: tensor(2741.6265, grad_fn=<AddBackward0>) / ( 997 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.4583126902580261
# Epoch	1, batch	1.
# tensor([126, 124, 127, 123, 122, 125, 127, 128], dtype=torch.int32)
# Mean loss: tensor(2730.1484, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.45411649346351624
# Epoch	1, batch	2.
# tensor([125, 123, 123, 122, 130, 130, 129, 124], dtype=torch.int32)
# Mean loss: tensor(2708.9521, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4487992227077484
# Epoch	1, batch	3.
# tensor([125, 129, 129, 130, 122, 130, 122, 122], dtype=torch.int32)
# Mean loss: tensor(2697.5964, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4455890953540802
# Epoch	1, batch	4.
# tensor([124, 125, 129, 123, 128, 123, 125, 129], dtype=torch.int32)
# Mean loss: tensor(2658.3198, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.440410852432251
# Epoch	1, batch	5.
# tensor([130, 124, 125, 126, 122, 127, 129, 123], dtype=torch.int32)
# Mean loss: tensor(2634.5767, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4364772439002991
# Epoch	1, batch	6.
# tensor([129, 130, 129, 130, 125, 125, 128, 122], dtype=torch.int32)
# Mean loss: tensor(2660.9221, grad_fn=<AddBackward0>) / ( 1018 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4356454014778137
# Epoch	1, batch	7.
# tensor([128, 126, 124, 126, 128, 123, 127, 123], dtype=torch.int32)
# Mean loss: tensor(2609.4702, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.4327479600906372
# Epoch	2, batch	0.
# tensor([128, 125, 122, 125, 129, 123, 125, 126], dtype=torch.int32)
# Mean loss: tensor(2593.8525, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.4310157001018524
# Epoch	2, batch	1.
# tensor([125, 129, 124, 130, 124, 128, 127, 130], dtype=torch.int32)
# Mean loss: tensor(2609.3313, grad_fn=<AddBackward0>) / ( 1017 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4276190400123596
# Epoch	2, batch	2.
# tensor([126, 126, 124, 124, 125, 122, 122, 125], dtype=torch.int32)
# Mean loss: tensor(2534.9773, grad_fn=<AddBackward0>) / ( 994 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 126])
# Mean loss (per pixel): 0.42504650354385376
# Epoch	2, batch	3.
# tensor([127, 130, 123, 129, 130, 122, 125, 129], dtype=torch.int32)
# Mean loss: tensor(2563.2517, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.42089518904685974
# Epoch	2, batch	4.
# tensor([126, 122, 123, 127, 130, 123, 123, 123], dtype=torch.int32)
# Mean loss: tensor(2504.3682, grad_fn=<AddBackward0>) / ( 997 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.41865065693855286
# Epoch	2, batch	5.
# tensor([123, 129, 124, 122, 130, 127, 129, 128], dtype=torch.int32)
# Mean loss: tensor(2532.4153, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4170644283294678
# Epoch	2, batch	6.
# tensor([122, 122, 124, 129, 128, 125, 125, 129], dtype=torch.int32)
# Mean loss: tensor(2500.0942, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.4150222837924957
# Epoch	2, batch	7.
# tensor([124, 124, 130, 125, 126, 123, 127, 128], dtype=torch.int32)
# Mean loss: tensor(2492.6934, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.41256096959114075
# Epoch	3, batch	0.
# tensor([125, 124, 125, 122, 125, 125, 123, 124], dtype=torch.int32)
# Mean loss: tensor(2445.5447, grad_fn=<AddBackward0>) / ( 993 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 125])
# Mean loss (per pixel): 0.41046401858329773
# Epoch	3, batch	1.
# tensor([130, 124, 130, 122, 129, 122, 127, 126], dtype=torch.int32)
# Mean loss: tensor(2467.8000, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4072277247905731
# Epoch	3, batch	2.
# tensor([129, 128, 124, 125, 125, 130, 126, 123], dtype=torch.int32)
# Mean loss: tensor(2441.0884, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.4028198719024658
# Epoch	3, batch	3.
# tensor([130, 123, 127, 124, 129, 123, 129, 127], dtype=torch.int32)
# Mean loss: tensor(2437.2192, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.401386559009552
# Epoch	3, batch	4.
# tensor([129, 122, 130, 122, 129, 126, 123, 124], dtype=torch.int32)
# Mean loss: tensor(2403.2544, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3985496461391449
# Epoch	3, batch	5.
# tensor([126, 129, 128, 124, 130, 125, 125, 126], dtype=torch.int32)
# Mean loss: tensor(2412.4478, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3969147205352783
# Epoch	3, batch	6.
# tensor([129, 122, 128, 123, 128, 128, 127, 125], dtype=torch.int32)
# Mean loss: tensor(2396.8201, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3955148756504059
# Epoch	3, batch	7.
# tensor([122, 127, 122, 130, 124, 123, 123, 125], dtype=torch.int32)
# Mean loss: tensor(2343.7148, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3921878933906555
# Epoch	4, batch	0.
# tensor([125, 125, 123, 129, 130, 130, 124, 130], dtype=torch.int32)
# Mean loss: tensor(2367.1768, grad_fn=<AddBackward0>) / ( 1016 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.38831639289855957
# Epoch	4, batch	1.
# tensor([129, 125, 125, 124, 126, 129, 128, 126], dtype=torch.int32)
# Mean loss: tensor(2343.0105, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3858712911605835
# Epoch	4, batch	2.
# tensor([130, 127, 126, 122, 125, 123, 130, 123], dtype=torch.int32)
# Mean loss: tensor(2317.8289, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3840008080005646
# Epoch	4, batch	3.
# tensor([128, 126, 122, 125, 129, 128, 123, 127], dtype=torch.int32)
# Mean loss: tensor(2322.6487, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3840358257293701
# Epoch	4, batch	4.
# tensor([124, 130, 123, 129, 122, 126, 122, 125], dtype=torch.int32)
# Mean loss: tensor(2280.0530, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3796291947364807
# Epoch	4, batch	5.
# tensor([127, 123, 122, 125, 127, 129, 123, 124], dtype=torch.int32)
# Mean loss: tensor(2288.0947, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.381349116563797
# Epoch	4, batch	6.
# tensor([127, 129, 130, 124, 125, 123, 128, 122], dtype=torch.int32)
# Mean loss: tensor(2272.2412, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.37570124864578247
# Epoch	4, batch	7.
# tensor([129, 124, 122, 128, 124, 122, 124, 125], dtype=torch.int32)
# Mean loss: tensor(2234.7783, grad_fn=<AddBackward0>) / ( 998 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.37320947647094727
# Epoch	5, batch	0.
# tensor([129, 125, 129, 123, 128, 126, 127, 129], dtype=torch.int32)
# Mean loss: tensor(2251.1494, grad_fn=<AddBackward0>) / ( 1016 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3692830502986908
# Epoch	5, batch	1.
# tensor([127, 125, 130, 124, 130, 125, 128, 124], dtype=torch.int32)
# Mean loss: tensor(2237.3049, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3680988848209381
# Epoch	5, batch	2.
# tensor([126, 129, 128, 124, 122, 124, 125, 125], dtype=torch.int32)
# Mean loss: tensor(2214.7559, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3680219054222107
# Epoch	5, batch	3.
# tensor([122, 129, 130, 130, 124, 126, 125, 129], dtype=torch.int32)
# Mean loss: tensor(2210.0220, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.36289358139038086
# Epoch	5, batch	4.
# tensor([124, 125, 123, 122, 127, 122, 127, 130], dtype=torch.int32)
# Mean loss: tensor(2170.9729, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3618288040161133
# Epoch	5, batch	5.
# tensor([127, 122, 122, 126, 126, 123, 129, 123], dtype=torch.int32)
# Mean loss: tensor(2151.4514, grad_fn=<AddBackward0>) / ( 998 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3592938184738159
# Epoch	5, batch	6.
# tensor([124, 129, 125, 123, 130, 125, 124, 125], dtype=torch.int32)
# Mean loss: tensor(2164.4121, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.35894066095352173
# Epoch	5, batch	7.
# tensor([130, 122, 122, 123, 123, 128, 128, 123], dtype=torch.int32)
# Mean loss: tensor(2143.0864, grad_fn=<AddBackward0>) / ( 999 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3575386106967926
# Epoch	6, batch	0.
# tensor([123, 125, 130, 124, 128, 129, 127, 126], dtype=torch.int32)
# Mean loss: tensor(2126.1975, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3501642942428589
# Epoch	6, batch	1.
# tensor([126, 126, 127, 124, 125, 125, 130, 123], dtype=torch.int32)
# Mean loss: tensor(2114.2671, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3502762019634247
# Epoch	6, batch	2.
# tensor([130, 124, 122, 128, 130, 126, 125, 124], dtype=torch.int32)
# Mean loss: tensor(2103.4575, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3474492132663727
# Epoch	6, batch	3.
# tensor([122, 125, 124, 130, 124, 129, 124, 128], dtype=torch.int32)
# Mean loss: tensor(2096.8081, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3473837077617645
# Epoch	6, batch	4.
# tensor([127, 122, 125, 122, 123, 129, 122, 125], dtype=torch.int32)
# Mean loss: tensor(2077.4045, grad_fn=<AddBackward0>) / ( 995 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3479739725589752
# Epoch	6, batch	5.
# tensor([130, 122, 130, 129, 126, 129, 127, 129], dtype=torch.int32)
# Mean loss: tensor(2100.7109, grad_fn=<AddBackward0>) / ( 1022 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.34258168935775757
# Epoch	6, batch	6.
# tensor([125, 122, 128, 125, 122, 125, 123, 127], dtype=torch.int32)
# Mean loss: tensor(2041.6079, grad_fn=<AddBackward0>) / ( 997 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.3412918746471405
# Epoch	6, batch	7.
# tensor([124, 129, 123, 129, 128, 123, 123, 123], dtype=torch.int32)
# Mean loss: tensor(2036.1145, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3386750817298889
# Epoch	7, batch	0.
# tensor([125, 130, 123, 129, 128, 124, 123, 122], dtype=torch.int32)
# Mean loss: tensor(2034.6011, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.337749183177948
# Epoch	7, batch	1.
# tensor([129, 126, 128, 124, 130, 123, 127, 127], dtype=torch.int32)
# Mean loss: tensor(2029.6772, grad_fn=<AddBackward0>) / ( 1014 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.333609014749527
# Epoch	7, batch	2.
# tensor([122, 125, 123, 128, 129, 122, 123, 130], dtype=torch.int32)
# Mean loss: tensor(1993.6063, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3316045105457306
# Epoch	7, batch	3.
# tensor([125, 126, 124, 130, 125, 125, 124, 126], dtype=torch.int32)
# Mean loss: tensor(1995.9922, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3310103118419647
# Epoch	7, batch	4.
# tensor([122, 130, 129, 126, 128, 129, 123, 130], dtype=torch.int32)
# Mean loss: tensor(2001.8430, grad_fn=<AddBackward0>) / ( 1017 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.328063428401947
# Epoch	7, batch	5.
# tensor([127, 124, 122, 129, 129, 125, 128, 124], dtype=torch.int32)
# Mean loss: tensor(1965.4393, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3249734342098236
# Epoch	7, batch	6.
# tensor([122, 123, 125, 127, 125, 126, 122, 125], dtype=torch.int32)
# Mean loss: tensor(1935.7310, grad_fn=<AddBackward0>) / ( 995 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.32424303889274597
# Epoch	7, batch	7.
# tensor([125, 123, 124, 127, 122, 130, 129, 124], dtype=torch.int32)
# Mean loss: tensor(1932.1624, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3207440972328186
# Epoch	8, batch	0.
# tensor([130, 129, 123, 123, 130, 129, 130, 129], dtype=torch.int32)
# Mean loss: tensor(1962.5298, grad_fn=<AddBackward0>) / ( 1023 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3197343945503235
# Epoch	8, batch	1.
# tensor([123, 130, 122, 122, 125, 130, 126, 124], dtype=torch.int32)
# Mean loss: tensor(1910.6680, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3178090453147888
# Epoch	8, batch	2.
# tensor([129, 124, 125, 122, 129, 126, 125, 126], dtype=torch.int32)
# Mean loss: tensor(1919.4635, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.3180025815963745
# Epoch	8, batch	3.
# tensor([127, 124, 128, 130, 128, 129, 123, 129], dtype=torch.int32)
# Mean loss: tensor(1901.1193, grad_fn=<AddBackward0>) / ( 1018 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3112506866455078
# Epoch	8, batch	4.
# tensor([127, 122, 128, 125, 124, 122, 126, 127], dtype=torch.int32)
# Mean loss: tensor(1883.5542, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.31361207365989685
# Epoch	8, batch	5.
# tensor([127, 124, 124, 124, 126, 123, 125, 128], dtype=torch.int32)
# Mean loss: tensor(1857.0137, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.30919307470321655
# Epoch	8, batch	6.
# tensor([125, 129, 125, 123, 122, 125, 122, 125], dtype=torch.int32)
# Mean loss: tensor(1838.8304, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.30770254135131836
# Epoch	8, batch	7.
# tensor([127, 124, 123, 123, 128, 130, 125, 122], dtype=torch.int32)
# Mean loss: tensor(1842.4121, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.3064557611942291
# Epoch	9, batch	0.
# tensor([122, 127, 127, 125, 123, 124, 122, 124], dtype=torch.int32)
# Mean loss: tensor(1811.7056, grad_fn=<AddBackward0>) / ( 994 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.30377358198165894
# Epoch	9, batch	1.
# tensor([130, 122, 128, 123, 125, 125, 128, 125], dtype=torch.int32)
# Mean loss: tensor(1828.7089, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.30296701192855835
# Epoch	9, batch	2.
# tensor([126, 130, 129, 125, 124, 126, 124, 128], dtype=torch.int32)
# Mean loss: tensor(1817.1204, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.29926225543022156
# Epoch	9, batch	3.
# tensor([130, 124, 122, 126, 126, 127, 125, 129], dtype=torch.int32)
# Mean loss: tensor(1808.5496, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2987363040447235
# Epoch	9, batch	4.
# tensor([123, 122, 127, 129, 126, 123, 124, 127], dtype=torch.int32)
# Mean loss: tensor(1795.3999, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.29893437027931213
# Epoch	9, batch	5.
# tensor([125, 124, 125, 129, 129, 129, 123, 125], dtype=torch.int32)
# Mean loss: tensor(1784.8973, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.29482942819595337
# Epoch	9, batch	6.
# tensor([130, 129, 125, 123, 129, 130, 123, 122], dtype=torch.int32)
# Mean loss: tensor(1774.8198, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2925848662853241
# Epoch	9, batch	7.
# tensor([122, 130, 128, 130, 122, 128, 123, 124], dtype=torch.int32)
# Mean loss: tensor(1762.4806, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.29170483350753784
# Epoch	10, batch	0.
# tensor([123, 124, 130, 124, 122, 123, 130, 127], dtype=torch.int32)
# Mean loss: tensor(1743.1857, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2896619737148285
# Epoch	10, batch	1.
# tensor([123, 124, 125, 124, 128, 124, 126, 127], dtype=torch.int32)
# Mean loss: tensor(1732.4805, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.28845828771591187
# Epoch	10, batch	2.
# tensor([129, 125, 122, 125, 130, 130, 129, 130], dtype=torch.int32)
# Mean loss: tensor(1751.3663, grad_fn=<AddBackward0>) / ( 1020 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.28617095947265625
# Epoch	10, batch	3.
# tensor([122, 125, 129, 122, 129, 126, 129, 124], dtype=torch.int32)
# Mean loss: tensor(1711.9160, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.28361761569976807
# Epoch	10, batch	4.
# tensor([125, 123, 123, 125, 127, 125, 126, 122], dtype=torch.int32)
# Mean loss: tensor(1688.7579, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.28259000182151794
# Epoch	10, batch	5.
# tensor([126, 125, 123, 122, 124, 128, 129, 129], dtype=torch.int32)
# Mean loss: tensor(1697.0721, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.2811584174633026
# Epoch	10, batch	6.
# tensor([129, 122, 130, 127, 128, 128, 123, 123], dtype=torch.int32)
# Mean loss: tensor(1685.5862, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2781495451927185
# Epoch	10, batch	7.
# tensor([122, 124, 125, 130, 126, 128, 125, 127], dtype=torch.int32)
# Mean loss: tensor(1684.6615, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.27882513403892517
# Epoch	11, batch	0.
# tensor([128, 125, 122, 124, 124, 130, 125, 124], dtype=torch.int32)
# Mean loss: tensor(1667.2816, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2773256301879883
# Epoch	11, batch	1.
# tensor([122, 122, 123, 129, 123, 130, 130, 129], dtype=torch.int32)
# Mean loss: tensor(1651.5490, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.27307358384132385
# Epoch	11, batch	2.
# tensor([125, 127, 127, 130, 129, 123, 123, 126], dtype=torch.int32)
# Mean loss: tensor(1647.1656, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.27180951833724976
# Epoch	11, batch	3.
# tensor([129, 125, 124, 122, 129, 123, 128, 130], dtype=torch.int32)
# Mean loss: tensor(1644.9767, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2714482843875885
# Epoch	11, batch	4.
# tensor([128, 126, 127, 127, 128, 129, 122, 124], dtype=torch.int32)
# Mean loss: tensor(1635.0287, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.26953983306884766
# Epoch	11, batch	5.
# tensor([128, 122, 126, 127, 123, 125, 129, 125], dtype=torch.int32)
# Mean loss: tensor(1614.4235, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.2677319049835205
# Epoch	11, batch	6.
# tensor([130, 129, 122, 122, 126, 123, 123, 124], dtype=torch.int32)
# Mean loss: tensor(1595.0604, grad_fn=<AddBackward0>) / ( 999 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.26610952615737915
# Epoch	11, batch	7.
# tensor([125, 125, 126, 124, 124, 125, 130, 125], dtype=torch.int32)
# Mean loss: tensor(1580.4602, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2623606026172638
# Epoch	12, batch	0.
# tensor([129, 125, 128, 124, 130, 129, 124, 122], dtype=torch.int32)
# Mean loss: tensor(1582.9468, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.26095396280288696
# Epoch	12, batch	1.
# tensor([128, 129, 126, 128, 124, 127, 122, 130], dtype=torch.int32)
# Mean loss: tensor(1575.8839, grad_fn=<AddBackward0>) / ( 1014 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.25902101397514343
# Epoch	12, batch	2.
# tensor([127, 125, 124, 127, 125, 129, 125, 123], dtype=torch.int32)
# Mean loss: tensor(1576.6709, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.26147112250328064
# Epoch	12, batch	3.
# tensor([127, 126, 127, 129, 123, 124, 125, 128], dtype=torch.int32)
# Mean loss: tensor(1556.7821, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.257149338722229
# Epoch	12, batch	4.
# tensor([124, 129, 123, 122, 123, 125, 125, 123], dtype=torch.int32)
# Mean loss: tensor(1536.2528, grad_fn=<AddBackward0>) / ( 994 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.2575876712799072
# Epoch	12, batch	5.
# tensor([126, 122, 125, 124, 126, 123, 122, 130], dtype=torch.int32)
# Mean loss: tensor(1522.6523, grad_fn=<AddBackward0>) / ( 998 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.25428396463394165
# Epoch	12, batch	6.
# tensor([125, 129, 129, 122, 128, 125, 123, 122], dtype=torch.int32)
# Mean loss: tensor(1520.8458, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.25271615386009216
# Epoch	12, batch	7.
# tensor([126, 122, 123, 130, 124, 130, 130, 130], dtype=torch.int32)
# Mean loss: tensor(1530.2784, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.25127723813056946
# Epoch	13, batch	0.
# tensor([122, 125, 129, 126, 126, 129, 122, 123], dtype=torch.int32)
# Mean loss: tensor(1501.2417, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.24970753490924835
# Epoch	13, batch	1.
# tensor([124, 122, 123, 127, 130, 129, 128, 122], dtype=torch.int32)
# Mean loss: tensor(1497.2146, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.24829429388046265
# Epoch	13, batch	2.
# tensor([126, 124, 128, 130, 123, 124, 123, 125], dtype=torch.int32)
# Mean loss: tensor(1479.6659, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.245873361825943
# Epoch	13, batch	3.
# tensor([125, 130, 130, 125, 123, 127, 130, 125], dtype=torch.int32)
# Mean loss: tensor(1491.1428, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2448510378599167
# Epoch	13, batch	4.
# tensor([129, 125, 128, 127, 125, 126, 127, 129], dtype=torch.int32)
# Mean loss: tensor(1482.5614, grad_fn=<AddBackward0>) / ( 1016 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.2432023286819458
# Epoch	13, batch	5.
# tensor([130, 125, 122, 123, 124, 129, 123, 126], dtype=torch.int32)
# Mean loss: tensor(1457.6821, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.24246209859848022
# Epoch	13, batch	6.
# tensor([128, 124, 125, 125, 127, 129, 124, 122], dtype=torch.int32)
# Mean loss: tensor(1450.7629, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.24083049595355988
# Epoch	13, batch	7.
# tensor([128, 129, 130, 124, 122, 122, 123, 124], dtype=torch.int32)
# Mean loss: tensor(1433.0912, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.23837178945541382
# Epoch	14, batch	0.
# tensor([122, 125, 128, 123, 130, 122, 129, 124], dtype=torch.int32)
# Mean loss: tensor(1435.7607, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2385777235031128
# Epoch	14, batch	1.
# tensor([128, 122, 124, 127, 126, 123, 129, 126], dtype=torch.int32)
# Mean loss: tensor(1417.4746, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.23507042229175568
# Epoch	14, batch	2.
# tensor([122, 129, 124, 124, 122, 122, 129, 130], dtype=torch.int32)
# Mean loss: tensor(1409.1486, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2343893200159073
# Epoch	14, batch	3.
# tensor([127, 125, 122, 130, 126, 127, 130, 125], dtype=torch.int32)
# Mean loss: tensor(1414.3135, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.23292382061481476
# Epoch	14, batch	4.
# tensor([128, 124, 124, 123, 122, 127, 123, 128], dtype=torch.int32)
# Mean loss: tensor(1395.4537, grad_fn=<AddBackward0>) / ( 999 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.2328084260225296
# Epoch	14, batch	5.
# tensor([125, 124, 123, 123, 123, 128, 129, 126], dtype=torch.int32)
# Mean loss: tensor(1376.1326, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.22912630438804626
# Epoch	14, batch	6.
# tensor([125, 125, 129, 124, 125, 123, 129, 130], dtype=torch.int32)
# Mean loss: tensor(1380.7214, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2278418242931366
# Epoch	14, batch	7.
# tensor([125, 130, 125, 129, 125, 126, 130, 127], dtype=torch.int32)
# Mean loss: tensor(1386.6841, grad_fn=<AddBackward0>) / ( 1017 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.22725075483322144
# Epoch	15, batch	0.
# tensor([124, 128, 128, 127, 123, 125, 126, 128], dtype=torch.int32)
# Mean loss: tensor(1363.9210, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.22529253363609314
# Epoch	15, batch	1.
# tensor([125, 130, 125, 129, 130, 123, 127, 124], dtype=torch.int32)
# Mean loss: tensor(1363.3656, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.22431154549121857
# Epoch	15, batch	2.
# tensor([130, 122, 123, 129, 128, 124, 125, 123], dtype=torch.int32)
# Mean loss: tensor(1348.8655, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.2239152491092682
# Epoch	15, batch	3.
# tensor([127, 129, 129, 123, 124, 124, 124, 127], dtype=torch.int32)
# Mean loss: tensor(1328.3218, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.21984802186489105
# Epoch	15, batch	4.
# tensor([122, 129, 125, 130, 126, 124, 125, 123], dtype=torch.int32)
# Mean loss: tensor(1338.8254, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.22224858403205872
# Epoch	15, batch	5.
# tensor([129, 128, 130, 122, 125, 125, 126, 122], dtype=torch.int32)
# Mean loss: tensor(1327.1722, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.219657763838768
# Epoch	15, batch	6.
# tensor([127, 125, 129, 125, 126, 130, 126, 123], dtype=torch.int32)
# Mean loss: tensor(1307.0728, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.21547523140907288
# Epoch	15, batch	7.
# tensor([123, 122, 122, 130, 124, 129, 122, 122], dtype=torch.int32)
# Mean loss: tensor(1295.3723, grad_fn=<AddBackward0>) / ( 994 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.21719858050346375
# Epoch	16, batch	0.
# tensor([125, 125, 128, 123, 126, 124, 122, 127], dtype=torch.int32)
# Mean loss: tensor(1284.5054, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.2140842229127884
# Epoch	16, batch	1.
# tensor([127, 129, 123, 124, 127, 127, 126, 124], dtype=torch.int32)
# Mean loss: tensor(1300.8726, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.21530495584011078
# Epoch	16, batch	2.
# tensor([124, 125, 126, 123, 122, 123, 130, 129], dtype=torch.int32)
# Mean loss: tensor(1279.5781, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.212837353348732
# Epoch	16, batch	3.
# tensor([127, 129, 125, 129, 122, 124, 125, 128], dtype=torch.int32)
# Mean loss: tensor(1272.3352, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.2101643830537796
# Epoch	16, batch	4.
# tensor([129, 130, 125, 123, 129, 124, 130, 129], dtype=torch.int32)
# Mean loss: tensor(1275.7706, grad_fn=<AddBackward0>) / ( 1019 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20866382122039795
# Epoch	16, batch	5.
# tensor([123, 128, 125, 122, 130, 126, 123, 130], dtype=torch.int32)
# Mean loss: tensor(1261.3335, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20876091718673706
# Epoch	16, batch	6.
# tensor([125, 122, 128, 122, 124, 128, 129, 130], dtype=torch.int32)
# Mean loss: tensor(1247.5925, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.206281840801239
# Epoch	16, batch	7.
# tensor([122, 125, 130, 125, 122, 123, 124, 126], dtype=torch.int32)
# Mean loss: tensor(1238.5671, grad_fn=<AddBackward0>) / ( 997 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20704899728298187
# Epoch	17, batch	0.
# tensor([124, 124, 130, 124, 123, 123, 130, 122], dtype=torch.int32)
# Mean loss: tensor(1231.0083, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20516805350780487
# Epoch	17, batch	1.
# tensor([130, 127, 125, 123, 122, 128, 123, 127], dtype=torch.int32)
# Mean loss: tensor(1230.2148, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20401573181152344
# Epoch	17, batch	2.
# tensor([130, 124, 128, 127, 129, 123, 125, 129], dtype=torch.int32)
# Mean loss: tensor(1223.7610, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20094597339630127
# Epoch	17, batch	3.
# tensor([129, 125, 130, 130, 125, 129, 124, 129], dtype=torch.int32)
# Mean loss: tensor(1227.3676, grad_fn=<AddBackward0>) / ( 1021 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.20035383105278015
# Epoch	17, batch	4.
# tensor([125, 125, 127, 122, 125, 127, 124, 124], dtype=torch.int32)
# Mean loss: tensor(1198.6174, grad_fn=<AddBackward0>) / ( 999 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.19996954500675201
# Epoch	17, batch	5.
# tensor([125, 126, 129, 126, 128, 123, 124, 126], dtype=torch.int32)
# Mean loss: tensor(1196.6550, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.19805611670017242
# Epoch	17, batch	6.
# tensor([123, 122, 129, 126, 129, 125, 122, 130], dtype=torch.int32)
# Mean loss: tensor(1191.7832, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1974458545446396
# Epoch	17, batch	7.
# tensor([126, 123, 122, 122, 125, 128, 122, 128], dtype=torch.int32)
# Mean loss: tensor(1179.8271, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.19742757081985474
# Epoch	18, batch	0.
# tensor([125, 128, 122, 124, 130, 126, 125, 123], dtype=torch.int32)
# Mean loss: tensor(1179.3918, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1959773749113083
# Epoch	18, batch	1.
# tensor([127, 130, 130, 124, 125, 127, 126, 129], dtype=torch.int32)
# Mean loss: tensor(1189.4498, grad_fn=<AddBackward0>) / ( 1018 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.19473637640476227
# Epoch	18, batch	2.
# tensor([123, 129, 123, 129, 127, 130, 122, 129], dtype=torch.int32)
# Mean loss: tensor(1174.8167, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.19348099827766418
# Epoch	18, batch	3.
# tensor([126, 122, 129, 126, 122, 130, 128, 125], dtype=torch.int32)
# Mean loss: tensor(1165.3534, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1926840990781784
# Epoch	18, batch	4.
# tensor([124, 125, 123, 128, 123, 125, 122, 123], dtype=torch.int32)
# Mean loss: tensor(1122.2637, grad_fn=<AddBackward0>) / ( 993 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.1883624792098999
# Epoch	18, batch	5.
# tensor([128, 125, 126, 124, 125, 122, 124, 122], dtype=torch.int32)
# Mean loss: tensor(1136.0033, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.1900942623615265
# Epoch	18, batch	6.
# tensor([130, 130, 124, 123, 129, 124, 127, 125], dtype=torch.int32)
# Mean loss: tensor(1134.5807, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1868545264005661
# Epoch	18, batch	7.
# tensor([129, 125, 123, 128, 122, 129, 127, 124], dtype=torch.int32)
# Mean loss: tensor(1124.9995, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.18619653582572937
# Epoch	19, batch	0.
# tensor([129, 130, 124, 125, 125, 123, 126, 126], dtype=torch.int32)
# Mean loss: tensor(1122.5082, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1855998933315277
# Epoch	19, batch	1.
# tensor([129, 128, 129, 127, 128, 125, 130, 125], dtype=torch.int32)
# Mean loss: tensor(1138.7439, grad_fn=<AddBackward0>) / ( 1021 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.18588702380657196
# Epoch	19, batch	2.
# tensor([122, 129, 130, 129, 127, 127, 125, 128], dtype=torch.int32)
# Mean loss: tensor(1124.9978, grad_fn=<AddBackward0>) / ( 1017 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1843654215335846
# Epoch	19, batch	3.
# tensor([124, 122, 128, 122, 130, 123, 122, 125], dtype=torch.int32)
# Mean loss: tensor(1097.5433, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.18365852534770966
# Epoch	19, batch	4.
# tensor([123, 130, 130, 124, 129, 129, 123, 122], dtype=torch.int32)
# Mean loss: tensor(1099.6047, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1814529299736023
# Epoch	19, batch	5.
# tensor([123, 128, 130, 125, 124, 126, 129, 127], dtype=torch.int32)
# Mean loss: tensor(1090.1958, grad_fn=<AddBackward0>) / ( 1012 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.17954476177692413
# Epoch	19, batch	6.
# tensor([125, 123, 126, 124, 125, 122, 125, 123], dtype=torch.int32)
# Mean loss: tensor(1068.8903, grad_fn=<AddBackward0>) / ( 993 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 126])
# Mean loss (per pixel): 0.17940419912338257
# Epoch	19, batch	7.
# tensor([124, 127, 123, 122, 126, 124, 122, 124], dtype=torch.int32)
# Mean loss: tensor(1060.5974, grad_fn=<AddBackward0>) / ( 992 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.17819176614284515
# Epoch	20, batch	0.
# tensor([130, 127, 130, 127, 130, 124, 122, 130], dtype=torch.int32)
# Mean loss: tensor(1090.5723, grad_fn=<AddBackward0>) / ( 1020 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.17819808423519135
# Epoch	20, batch	1.
# tensor([126, 125, 129, 122, 125, 125, 125, 129], dtype=torch.int32)
# Mean loss: tensor(1060.9702, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.1757737249135971
# Epoch	20, batch	2.
# tensor([122, 124, 126, 124, 128, 128, 124, 122], dtype=torch.int32)
# Mean loss: tensor(1039.8798, grad_fn=<AddBackward0>) / ( 998 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.17366062104701996
# Epoch	20, batch	3.
# tensor([123, 126, 130, 129, 129, 123, 127, 127], dtype=torch.int32)
# Mean loss: tensor(1057.7040, grad_fn=<AddBackward0>) / ( 1014 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.17385008931159973
# Epoch	20, batch	4.
# tensor([130, 125, 123, 125, 123, 125, 122, 130], dtype=torch.int32)
# Mean loss: tensor(1041.0089, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.17298254370689392
# Epoch	20, batch	5.
# tensor([129, 123, 124, 128, 126, 123, 122, 129], dtype=torch.int32)
# Mean loss: tensor(1052.0762, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.17464743554592133
# Epoch	20, batch	6.
# tensor([123, 127, 128, 123, 129, 125, 126, 122], dtype=torch.int32)
# Mean loss: tensor(1034.7101, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.17193587124347687
# Epoch	20, batch	7.
# tensor([128, 125, 124, 125, 129, 124, 124, 122], dtype=torch.int32)
# Mean loss: tensor(1028.6494, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.17127029597759247
# Epoch	21, batch	0.
# tensor([130, 124, 126, 125, 126, 125, 123, 123], dtype=torch.int32)
# Mean loss: tensor(1012.4962, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.16841255128383636
# Epoch	21, batch	1.
# tensor([128, 127, 127, 128, 130, 125, 130, 123], dtype=torch.int32)
# Mean loss: tensor(1029.7861, grad_fn=<AddBackward0>) / ( 1018 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1685962826013565
# Epoch	21, batch	2.
# tensor([130, 129, 122, 127, 122, 125, 125, 124], dtype=torch.int32)
# Mean loss: tensor(1015.5249, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1685798317193985
# Epoch	21, batch	3.
# tensor([127, 126, 125, 124, 129, 130, 125, 122], dtype=torch.int32)
# Mean loss: tensor(1015.7837, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.16795365512371063
# Epoch	21, batch	4.
# tensor([125, 129, 123, 124, 122, 124, 123, 123], dtype=torch.int32)
# Mean loss: tensor(990.6532, grad_fn=<AddBackward0>) / ( 993 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.16627277433872223
# Epoch	21, batch	5.
# tensor([128, 128, 125, 130, 128, 127, 129, 126], dtype=torch.int32)
# Mean loss: tensor(1011.0142, grad_fn=<AddBackward0>) / ( 1021 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.16503658890724182
# Epoch	21, batch	6.
# tensor([124, 129, 129, 122, 129, 123, 122, 129], dtype=torch.int32)
# Mean loss: tensor(986.7825, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.16332049667835236
# Epoch	21, batch	7.
# tensor([125, 130, 124, 123, 122, 122, 126, 124], dtype=torch.int32)
# Mean loss: tensor(972.0247, grad_fn=<AddBackward0>) / ( 996 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.16265474259853363
# Epoch	22, batch	0.
# tensor([126, 122, 129, 125, 129, 125, 124, 123], dtype=torch.int32)
# Mean loss: tensor(978.6797, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.16262540221214294
# Epoch	22, batch	1.
# tensor([126, 130, 126, 127, 122, 130, 130, 122], dtype=torch.int32)
# Mean loss: tensor(979.2206, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.16110901534557343
# Epoch	22, batch	2.
# tensor([123, 128, 122, 125, 124, 129, 124, 128], dtype=torch.int32)
# Mean loss: tensor(965.6844, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.1604660153388977
# Epoch	22, batch	3.
# tensor([130, 127, 122, 128, 122, 124, 129, 126], dtype=torch.int32)
# Mean loss: tensor(966.8245, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.1598585546016693
# Epoch	22, batch	4.
# tensor([130, 125, 127, 129, 123, 127, 125, 130], dtype=torch.int32)
# Mean loss: tensor(960.6031, grad_fn=<AddBackward0>) / ( 1016 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.157579243183136
# Epoch	22, batch	5.
# tensor([123, 129, 124, 122, 128, 125, 125, 125], dtype=torch.int32)
# Mean loss: tensor(953.6387, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# ...
# Mean loss (per pixel): 0.007062993478029966
# Epoch	492, batch	4.
# tensor([126, 125, 125, 123, 125, 129, 130, 122], dtype=torch.int32)
# Mean loss: tensor(40.0846, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006647523492574692
# Epoch	492, batch	5.
# tensor([123, 125, 127, 124, 128, 125, 129, 123], dtype=torch.int32)
# Mean loss: tensor(42.6136, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.007073977496474981
# Epoch	492, batch	6.
# tensor([124, 129, 123, 128, 122, 126, 130, 129], dtype=torch.int32)
# Mean loss: tensor(39.1422, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006452723406255245
# Epoch	492, batch	7.
# tensor([130, 125, 125, 122, 130, 125, 123, 127], dtype=torch.int32)
# Mean loss: tensor(42.7876, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007081697694957256
# Epoch	493, batch	0.
# tensor([123, 129, 124, 125, 122, 128, 125, 126], dtype=torch.int32)
# Mean loss: tensor(42.0430, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.006993182934820652
# Epoch	493, batch	1.
# tensor([127, 127, 129, 124, 128, 130, 125, 125], dtype=torch.int32)
# Mean loss: tensor(38.7288, grad_fn=<AddBackward0>) / ( 1015 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0063594039529562
# Epoch	493, batch	2.
# tensor([130, 129, 130, 123, 130, 128, 122, 125], dtype=torch.int32)
# Mean loss: tensor(40.2634, grad_fn=<AddBackward0>) / ( 1017 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.00659839017316699
# Epoch	493, batch	3.
# tensor([123, 123, 124, 124, 122, 122, 127, 122], dtype=torch.int32)
# Mean loss: tensor(47.1605, grad_fn=<AddBackward0>) / ( 987 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.007963611744344234
# Epoch	493, batch	4.
# tensor([122, 126, 126, 125, 122, 123, 129, 130], dtype=torch.int32)
# Mean loss: tensor(43.9782, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0073077743873000145
# Epoch	493, batch	5.
# tensor([129, 129, 123, 123, 126, 130, 126, 127], dtype=torch.int32)
# Mean loss: tensor(37.9488, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0062436386942863464
# Epoch	493, batch	6.
# tensor([125, 129, 122, 127, 129, 128, 123, 124], dtype=torch.int32)
# Mean loss: tensor(43.4620, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.007193305995315313
# Epoch	493, batch	7.
# tensor([128, 124, 124, 125, 125, 124, 125, 130], dtype=torch.int32)
# Mean loss: tensor(43.4596, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007207224611192942
# Epoch	494, batch	0.
# tensor([122, 126, 124, 126, 127, 124, 129, 123], dtype=torch.int32)
# Mean loss: tensor(38.1662, grad_fn=<AddBackward0>) / ( 1001 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.006354682147502899
# Epoch	494, batch	1.
# tensor([127, 128, 122, 128, 129, 130, 125, 129], dtype=torch.int32)
# Mean loss: tensor(50.1975, grad_fn=<AddBackward0>) / ( 1018 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.008218320086598396
# Epoch	494, batch	2.
# tensor([129, 125, 124, 125, 128, 125, 130, 123], dtype=torch.int32)
# Mean loss: tensor(39.7556, grad_fn=<AddBackward0>) / ( 1009 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006566837430000305
# Epoch	494, batch	3.
# tensor([126, 122, 122, 130, 124, 122, 125, 122], dtype=torch.int32)
# Mean loss: tensor(40.7292, grad_fn=<AddBackward0>) / ( 993 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0068360548466444016
# Epoch	494, batch	4.
# tensor([125, 126, 123, 130, 124, 124, 123, 124], dtype=torch.int32)
# Mean loss: tensor(39.3615, grad_fn=<AddBackward0>) / ( 999 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0065668197348713875
# Epoch	494, batch	5.
# tensor([126, 129, 128, 125, 123, 130, 125, 127], dtype=torch.int32)
# Mean loss: tensor(44.9173, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007390148006379604
# Epoch	494, batch	6.
# tensor([129, 129, 123, 130, 122, 130, 123, 127], dtype=torch.int32)
# Mean loss: tensor(38.8288, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006388422101736069
# Epoch	494, batch	7.
# tensor([129, 125, 125, 123, 127, 122, 128, 124], dtype=torch.int32)
# Mean loss: tensor(45.4972, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.0075601874850690365
# Epoch	495, batch	0.
# tensor([125, 125, 127, 127, 124, 122, 123, 127], dtype=torch.int32)
# Mean loss: tensor(40.2747, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 127])
# Mean loss (per pixel): 0.006712448317557573
# Epoch	495, batch	1.
# tensor([129, 122, 124, 123, 129, 127, 125, 125], dtype=torch.int32)
# Mean loss: tensor(42.3725, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.0070339469239115715
# Epoch	495, batch	2.
# tensor([130, 129, 124, 129, 123, 130, 123, 126], dtype=torch.int32)
# Mean loss: tensor(42.5880, grad_fn=<AddBackward0>) / ( 1014 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007000000216066837
# Epoch	495, batch	3.
# tensor([124, 130, 129, 122, 128, 123, 125, 126], dtype=torch.int32)
# Mean loss: tensor(42.5997, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007050588261336088
# Epoch	495, batch	4.
# tensor([128, 130, 123, 130, 122, 125, 124, 129], dtype=torch.int32)
# Mean loss: tensor(46.3166, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007635440211743116
# Epoch	495, batch	5.
# tensor([122, 124, 130, 126, 124, 127, 123, 129], dtype=torch.int32)
# Mean loss: tensor(43.1741, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0071598831564188
# Epoch	495, batch	6.
# tensor([125, 130, 126, 124, 122, 128, 125, 122], dtype=torch.int32)
# Mean loss: tensor(42.9317, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007141002919524908
# Epoch	495, batch	7.
# tensor([122, 128, 129, 126, 123, 128, 125, 125], dtype=torch.int32)
# Mean loss: tensor(38.4887, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.006376519333571196
# Epoch	496, batch	0.
# tensor([123, 123, 128, 122, 125, 122, 129, 130], dtype=torch.int32)
# Mean loss: tensor(42.0755, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006998581346124411
# Epoch	496, batch	1.
# tensor([125, 127, 123, 124, 130, 124, 122, 122], dtype=torch.int32)
# Mean loss: tensor(41.4718, grad_fn=<AddBackward0>) / ( 997 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0069327582605183125
# Epoch	496, batch	2.
# tensor([124, 128, 122, 125, 130, 126, 128, 123], dtype=torch.int32)
# Mean loss: tensor(42.7991, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007090635132044554
# Epoch	496, batch	3.
# tensor([126, 123, 128, 129, 125, 130, 122, 125], dtype=torch.int32)
# Mean loss: tensor(48.8206, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.008072183467447758
# Epoch	496, batch	4.
# tensor([125, 125, 127, 123, 129, 126, 125, 124], dtype=torch.int32)
# Mean loss: tensor(39.0395, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.006480660755187273
# Epoch	496, batch	5.
# tensor([124, 130, 129, 122, 130, 126, 129, 123], dtype=torch.int32)
# Mean loss: tensor(39.2445, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006456813309341669
# Epoch	496, batch	6.
# tensor([126, 129, 129, 122, 125, 130, 125, 127], dtype=torch.int32)
# Mean loss: tensor(39.7686, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006543045397847891
# Epoch	496, batch	7.
# tensor([129, 124, 128, 123, 127, 124, 127, 124], dtype=torch.int32)
# Mean loss: tensor(41.7103, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.006910253781825304
# Epoch	497, batch	0.
# tensor([129, 130, 125, 125, 130, 122, 129, 126], dtype=torch.int32)
# Mean loss: tensor(47.1295, grad_fn=<AddBackward0>) / ( 1016 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007731209974735975
# Epoch	497, batch	1.
# tensor([123, 124, 125, 127, 130, 127, 124, 123], dtype=torch.int32)
# Mean loss: tensor(38.8886, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006462050136178732
# Epoch	497, batch	2.
# tensor([129, 124, 130, 126, 122, 128, 123, 124], dtype=torch.int32)
# Mean loss: tensor(41.7382, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.00691487081348896
# Epoch	497, batch	3.
# tensor([126, 127, 125, 122, 128, 123, 127, 125], dtype=torch.int32)
# Mean loss: tensor(40.1799, grad_fn=<AddBackward0>) / ( 1003 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.0066766152158379555
# Epoch	497, batch	4.
# tensor([124, 130, 122, 129, 125, 125, 122, 128], dtype=torch.int32)
# Mean loss: tensor(38.9837, grad_fn=<AddBackward0>) / ( 1005 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006464959122240543
# Epoch	497, batch	5.
# tensor([124, 129, 124, 130, 123, 125, 124, 127], dtype=torch.int32)
# Mean loss: tensor(45.3761, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007517579942941666
# Epoch	497, batch	6.
# tensor([129, 125, 123, 122, 130, 126, 123, 126], dtype=torch.int32)
# Mean loss: tensor(37.2876, grad_fn=<AddBackward0>) / ( 1004 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006189841311424971
# Epoch	497, batch	7.
# tensor([122, 128, 128, 125, 122, 123, 129, 129], dtype=torch.int32)
# Mean loss: tensor(45.1758, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.0074843913316726685
# Epoch	498, batch	0.
# tensor([130, 122, 124, 128, 125, 128, 125, 125], dtype=torch.int32)
# Mean loss: tensor(40.1684, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006648192182183266
# Epoch	498, batch	1.
# tensor([122, 126, 130, 125, 123, 126, 122, 124], dtype=torch.int32)
# Mean loss: tensor(38.7767, grad_fn=<AddBackward0>) / ( 998 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006475736387073994
# Epoch	498, batch	2.
# tensor([128, 129, 123, 123, 122, 127, 125, 129], dtype=torch.int32)
# Mean loss: tensor(42.2998, grad_fn=<AddBackward0>) / ( 1006 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.007007924374192953
# Epoch	498, batch	3.
# tensor([126, 125, 127, 124, 123, 123, 124, 128], dtype=torch.int32)
# Mean loss: tensor(37.9301, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 128])
# Mean loss (per pixel): 0.006321691442281008
# Epoch	498, batch	4.
# tensor([122, 124, 126, 129, 129, 129, 125, 123], dtype=torch.int32)
# Mean loss: tensor(41.8104, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.006919958163052797
# Epoch	498, batch	5.
# tensor([129, 122, 124, 125, 124, 127, 127, 130], dtype=torch.int32)
# Mean loss: tensor(41.4618, grad_fn=<AddBackward0>) / ( 1008 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0068554626777768135
# Epoch	498, batch	6.
# tensor([130, 129, 126, 127, 122, 129, 122, 128], dtype=torch.int32)
# Mean loss: tensor(46.2502, grad_fn=<AddBackward0>) / ( 1013 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007609442807734013
# Epoch	498, batch	7.
# tensor([124, 130, 130, 130, 123, 125, 123, 125], dtype=torch.int32)
# Mean loss: tensor(44.8067, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0073938434943556786
# Epoch	499, batch	0.
# tensor([124, 123, 129, 125, 129, 126, 122, 129], dtype=torch.int32)
# Mean loss: tensor(41.5812, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.0068820202723145485
# Epoch	499, batch	1.
# tensor([126, 130, 124, 124, 128, 125, 129, 125], dtype=torch.int32)
# Mean loss: tensor(42.3278, grad_fn=<AddBackward0>) / ( 1011 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006977876182645559
# Epoch	499, batch	2.
# tensor([129, 130, 124, 125, 124, 123, 128, 127], dtype=torch.int32)
# Mean loss: tensor(41.2592, grad_fn=<AddBackward0>) / ( 1010 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.0068084439262747765
# Epoch	499, batch	3.
# tensor([126, 125, 123, 123, 126, 123, 122, 130], dtype=torch.int32)
# Mean loss: tensor(39.2302, grad_fn=<AddBackward0>) / ( 998 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006551461759954691
# Epoch	499, batch	4.
# tensor([123, 130, 125, 130, 124, 127, 128, 127], dtype=torch.int32)
# Mean loss: tensor(42.4376, grad_fn=<AddBackward0>) / ( 1014 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006975279189646244
# Epoch	499, batch	5.
# tensor([127, 123, 129, 129, 122, 128, 125, 124], dtype=torch.int32)
# Mean loss: tensor(42.3384, grad_fn=<AddBackward0>) / ( 1007 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 129])
# Mean loss (per pixel): 0.0070073483511805534
# Epoch	499, batch	6.
# tensor([130, 123, 129, 125, 124, 122, 125, 122], dtype=torch.int32)
# Mean loss: tensor(41.6541, grad_fn=<AddBackward0>) / ( 1000 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.006942356936633587
# Epoch	499, batch	7.
# tensor([126, 122, 122, 122, 128, 130, 125, 127], dtype=torch.int32)
# Mean loss: tensor(42.6974, grad_fn=<AddBackward0>) / ( 1002 * 6 )
# Ratio of stds between input and output: inf 	 torch.Size([8, 130])
# Mean loss (per pixel): 0.007102031726390123

# %%
plt.ylim(bottom=0)
plt.plot([k[2] for k in rnn_losses], [k[3] for k in rnn_losses])
plt.xlabel("Batch iterations")
plt.ylabel("MSE")
plt.savefig(f"{datapath}/trial_{trial_number}/loss.png")
plt.close()

plt.plot([k[2] for k in rnn_losses], [k[3] for k in rnn_losses])
plt.yscale('log')
plt.xlabel("Batch iterations")
plt.ylabel("log MSE")
plt.savefig(f"{datapath}/trial_{trial_number}/loss_log.png")
plt.close()

# %%
rnn.eval()
# Out:
# RNN(
#   (main): Sequential(
#     (0): Linear(in_features=9, out_features=8, bias=False)
#     (1): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=8, out_features=8, bias=False)
#     (4): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=8, out_features=8, bias=False)
#     (7): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=8, out_features=9, bias=True)
#   )
# )

# %% [markdown]
# # Output training results & comparison

# %%
def makeSpec(spec, valueRange):
    # expand each entry to rgb 0-255
    positiveVals = np.maximum(0, spec)
    negativeVals = -np.minimum(0, spec)
    
    redArea = np.minimum(positiveVals/valueRange, 1) * 255
    blueArea = np.minimum(negativeVals/valueRange, 1) * 255
    greenArea = np.zeros(shape=redArea.shape)
    
    imgRBG = np.stack((redArea, greenArea, blueArea), axis=2).astype(np.uint8)
    print(np.max(imgRBG))
    print(np.min(imgRBG))

    return imgRBG

# %%
def makeSpecSidebySide(realSpec, modelSpec, valueRange):
    max_length = max(realSpec.shape[0], modelSpec.shape[0])

    returnImage = np.zeros((max_length + 1, realSpec.shape[1] + modelSpec.shape[1] + 1, 3), dtype=np.uint8)
    # expand each entry to rgb 0-255

    # real spec
    positiveVals = np.maximum(0, realSpec)
    negativeVals = -np.minimum(0, realSpec)
    
    redArea = np.minimum(positiveVals/valueRange, 1) * 255
    blueArea = np.minimum(negativeVals/valueRange, 1) * 255
    greenArea = np.zeros(shape=redArea.shape)
    
    realimgRBG = np.stack((redArea, greenArea, blueArea), axis=2).astype(np.uint8)
    print("Real Image max: ", np.max(realimgRBG))
    print("Real Image min: ", np.min(realimgRBG))

    # model spec
    positiveVals = np.maximum(0, modelSpec)
    negativeVals = -np.minimum(0, modelSpec)
    
    redArea = np.minimum(positiveVals/valueRange, 1) * 255
    blueArea = np.minimum(negativeVals/valueRange, 1) * 255
    greenArea = np.zeros(shape=redArea.shape)
    
    modelimgRBG = np.stack((redArea, greenArea, blueArea), axis=2).astype(np.uint8)
    print("Model Image max: ", np.max(modelimgRBG))
    print("Model Image min: ", np.min(modelimgRBG))

    # dividing boundary between real and model
    returnImage[:, realSpec.shape[1]:realSpec.shape[1]+1, :] = np.tile(np.array([255, 255, 255], dtype=np.uint8), (max_length+1, 1, 1))

    # green header for real
    returnImage[0:1, 0:realSpec.shape[1], :] = np.tile(np.array([0, 255, 0], dtype=np.uint8), (1, realSpec.shape[1], 1))
    # red header for model
    returnImage[0:1, realSpec.shape[1]+1:, :] = np.tile(np.array([255, 0, 0], dtype=np.uint8), (1, modelSpec.shape[1], 1))

    # add actual images here
    returnImage[1:1+realSpec.shape[0], 0:realSpec.shape[1], :] = realimgRBG
    returnImage[1:1+modelSpec.shape[0], realSpec.shape[1]+1:, :] = modelimgRBG

    return returnImage

# %% [markdown]
# ## See how well RNN has learned training data

# %%
predictedsequenceSet = [] # this is without autoregression

for i in range(0, len(trainSequenceSet)):
    seq = standardizeMM(trainSequenceSet[i])
    seqWrapped = torch.stack([seq])
    predseqWrapped = rnn(seqWrapped).detach()
    predseq = predseqWrapped[0]
    predictedsequenceSet.append(predseq)
    stdpred = torch.std(predseq, dim=1)
    stdactual = torch.std(seq, dim=1)
    #print(ratio_sds.shape)
    plt.scatter(range(0, len(stdpred)), stdpred, c=np.tile(np.array([1, 0, 0]), (len(stdpred), 1)), s=1)
    plt.scatter(range(0, len(stdactual)), stdactual, c=np.tile(np.array([0, 1, 0]), (len(stdactual), 1)), s=1)
    #print("Actual: \t", torch.mean(seq[lower:upper]).item(), "\t",torch.std(seq[lower:upper]).item())
    #print("Predicted:\t", torch.mean(predseq[lower:upper]).item(), "\t",torch.std(predseq[lower:upper]).item())
    #print()
plt.savefig(f"{datapath}/trial_{trial_number}/prediction_variation.png")
plt.show()

# %%
# save the model
torch.save({
            'optimizer_state_dict': optimizerRNN.state_dict(),
            'model_state_dict': rnn.state_dict(),
            'loss': rnn_losses,
            }, 
            datapath+"/"+"trial_"+str(trial_number)+"/rnn_model.pt" )
# save the model information
with open(datapath+"/"+"trial_"+str(trial_number)+"/rnn_model_info.txt", "w") as f:
    f.write(str(rnn)+"\n")
    f.write(str(optimizerRNN)+"\n")
    f.write("Batch size: "+str(dataloader_batch_size)+"\n")

# %%
imageBounds = 2

for i in range(0, len(trainfilelist)):
    predseq = predictedsequenceSet[i]
    actseq = standardizeMM(trainSequenceSet[i])
    #saveSpec(predseq.numpy(), datapath+"sample_"+str(i)+"_rnn_trial"+str(trial_number)+".png", 2)
    #saveSpec(actseq.numpy(), datapath+"sample_"+str(i)+"_act.png", 2)
    matplotlib.image.imsave(datapath+"/"+"trial_"+str(trial_number)+"/sample_"+str(i)+".png",\
                            makeSpecSidebySide(actseq.numpy(), predseq.numpy(), imageBounds) )
    with open(datapath+"/"+"trial_"+str(trial_number)+"/sample_"+str(i)+".valuerange", "w") as f:
        f.write(f"actual sequence range: [{torch.min(actseq).item()}, {torch.max(actseq).item()}]\n")
        f.write(f"predicted sequence range: [{torch.min(predseq).item()}, {torch.max(predseq).item()}]\n")
        f.write(f"Image bounds: {imageBounds}\n")
    #torch.save(predseq, datapath+"/"+"trial_"+str(trial_number)+"/sample_"+str(i)+"_rnn_trial"+str(trial_number)+".pt")
# Out:
# Real Image max:  127
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  160
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  170
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  122
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  117
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  169
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  170
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  114
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  170
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  118
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  171
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  120
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  167
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  116
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  116
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  114
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  121
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  117
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  125
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0

# %% [markdown]
# ## See how well RNN can predict immediate next element in test set

# %%
testSequenceSet = []

TEST_LENGTH = 0

for fname in testfilelist:
    sequence = torch.load(datapath+fname).to(torch.float32)
    print("type:",sequence.dtype)
    testSequenceSet.append(sequence)

    TEST_LENGTH += sequence.shape[0]

print("TEST LENGTH:", TEST_LENGTH)
# Out:
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# type: torch.float32
# TEST LENGTH: 8072

# %%
predictedtestsequenceSet = [] # this is without autoregression

for i in range(0, len(testSequenceSet)):
    seq = standardizeMM(testSequenceSet[i])
    seqWrapped = torch.stack([seq])
    predseqWrapped = rnn(seqWrapped).detach()
    predseq = predseqWrapped[0]
    predictedtestsequenceSet.append(predseq)
    stdpred = torch.std(predseq, dim=1)
    stdactual = torch.std(seq, dim=1)
    #print(ratio_sds.shape)
    plt.scatter(range(0, len(stdpred)), stdpred, c=np.tile(np.array([1, 0, 0]), (len(stdpred), 1)), s=1)
    plt.scatter(range(0, len(stdactual)), stdactual, c=np.tile(np.array([0, 1, 0]), (len(stdactual), 1)), s=1)
    #print("Actual: \t", torch.mean(seq[lower:upper]).item(), "\t",torch.std(seq[lower:upper]).item())
    #print("Predicted:\t", torch.mean(predseq[lower:upper]).item(), "\t",torch.std(predseq[lower:upper]).item())
    #print()
plt.savefig(f"{datapath}/trial_{trial_number}/prediction_variation_test.png")
plt.show()

# %%
imageBounds = 2

if not os.path.isdir(f"{datapath}/trial_{trial_number}/test"):
    os.mkdir(f"{datapath}/trial_{trial_number}/test")

for i in range(0, len(testfilelist)):
    predseq = predictedtestsequenceSet[i]
    actseq = standardizeMM(testSequenceSet[i])
    #saveSpec(predseq.numpy(), datapath+"sample_"+str(i)+"_rnn_trial"+str(trial_number)+".png", 2)
    #saveSpec(actseq.numpy(), datapath+"sample_"+str(i)+"_act.png", 2)
    matplotlib.image.imsave(datapath+"/"+"trial_"+str(trial_number)+"/test/sample_"+str(i)+".png",\
                            makeSpecSidebySide(actseq.numpy(), predseq.numpy(), imageBounds) )
    with open(datapath+"/"+"trial_"+str(trial_number)+"/test/sample_"+str(i)+".valuerange", "w") as f:
        f.write(f"actual sequence range: [{torch.min(actseq).item()}, {torch.max(actseq).item()}]\n")
        f.write(f"predicted sequence range: [{torch.min(predseq).item()}, {torch.max(predseq).item()}]\n")
        f.write(f"Image bounds: {imageBounds}\n")
    #torch.save(predseq, datapath+"/"+"trial_"+str(trial_number)+"/sample_"+str(i)+"_rnn_trial"+str(trial_number)+".pt")
# Out:
# Real Image max:  130
# Real Image min:  0
# Model Image max:  116
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  122
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  109
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  119
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  170
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  168
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  109
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  118
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  132
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  109
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  168
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  170
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  119
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  114
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  147
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  117
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  141
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  120
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  167
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  114
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  168
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  116
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  113
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  112
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  116
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  170
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  145
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  115
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  167
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  114
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  118
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  110
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  111
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  122
# Model Image min:  0

# %% [markdown]
# ## See how well RNN can autoregress / generate next element on artificially generated elements

# %%
noise_std = 1.1

# %%
autoregsequenceSet = {1: [], 10: [], 50: []}

if not os.path.isdir(f"{datapath}/trial_{trial_number}/autoreg_{noise_std}"):
    os.mkdir(f"{datapath}/trial_{trial_number}/autoreg_{noise_std}")

for start_length in autoregsequenceSet:
    for i in range(0, len(testSequenceSet)):
        seq = standardizeMM(testSequenceSet[i][:start_length])
        seqWrapped = torch.stack([seq])
        seqWrapped = seqWrapped + torch.normal(mean=0, std=noise_std, size=seqWrapped.shape)
        predseqWrapped = rnn.forwardAutoreg(seqWrapped, 126).detach()
        predseq = predseqWrapped[0]
        autoregsequenceSet[start_length].append(predseq)
        stdpred = torch.std(predseq, dim=1)
        stdactual = torch.std(seq, dim=1)
        #print(ratio_sds.shape)
        plt.scatter(range(0, len(stdpred)), stdpred, c=np.tile(np.array([1, 0, 0]), (len(stdpred), 1)), s=1)
        plt.scatter(range(0, len(stdactual)), stdactual, c=np.tile(np.array([0, 1, 0]), (len(stdactual), 1)), s=1)
        #print("Actual: \t", torch.mean(seq[lower:upper]).item(), "\t",torch.std(seq[lower:upper]).item())
        #print("Predicted:\t", torch.mean(predseq[lower:upper]).item(), "\t",torch.std(predseq[lower:upper]).item())
        #print()
    plt.savefig(f"{datapath}/trial_{trial_number}/autoreg_{noise_std}/prediction_variation_autoreg_{start_length}.png")
    plt.show()

# %%
imageBounds = 2

for start_length in autoregsequenceSet:
    for i in range(0, len(testfilelist)):
        predseq = autoregsequenceSet[start_length][i]
        actseq = standardizeMM(testSequenceSet[i])
        #saveSpec(predseq.numpy(), datapath+"sample_"+str(i)+"_rnn_trial"+str(trial_number)+".png", 2)
        #saveSpec(actseq.numpy(), datapath+"sample_"+str(i)+"_act.png", 2)
        matplotlib.image.imsave(f"{datapath}/trial_{trial_number}/autoreg_{noise_std}/sample_{i}_st{start_length}.png",\
                                makeSpecSidebySide(actseq.numpy(), predseq.numpy(), imageBounds) )
        with open(f"{datapath}/trial_{trial_number}/autoreg_{noise_std}/sample_{i}_st{start_length}.valuerange", "w") as f:
            f.write(f"actual sequence range: [{torch.min(actseq).item()}, {torch.max(actseq).item()}]\n")
            f.write(f"predicted sequence range: [{torch.min(predseq).item()}, {torch.max(predseq).item()}]\n")
            f.write(f"Image bounds: {imageBounds}\n")
        #torch.save(predseq, datapath+"/"+"trial_"+str(trial_number)+"/sample_"+str(i)+"_rnn_trial"+str(trial_number)+".pt")
# Out:
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  181
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  221
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  190
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  137
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  194
# Model Image min:  0
# Real Image max:  132
# Real Image min:  0
# Model Image max:  245
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  192
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  131
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  227
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  246
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  191
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  241
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  204
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  246
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  239
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  231
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  251
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  108
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  218
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  239
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  239
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  132
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  132
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  130
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  128
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  119
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  129
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  126
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  123
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  121
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  125
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  122
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  120
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  127
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0
# Real Image max:  124
# Real Image min:  0
# Model Image max:  255
# Model Image min:  0

# %% [markdown]
# # Analyze LayerNorm Layers to determine why outputs seem to be muted

# %%
idx = 3
print(rnn.main[idx])
plt.hist(torch.flatten(rnn.main[idx].weight).detach().numpy(), bins=50)

# %%
sequencePred = rnn(newData[1]).detach().numpy()
print(sequencePred.shape)
for i in range(0, 5):
    print(sequencePred.shape)
    plt.plot([t[0] for t in sequencePred[i]][:newData[0][i]], [t[1] for t in sequencePred[i]][:newData[0][i]])
